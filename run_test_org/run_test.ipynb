# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# %cd /content/drive/MyDrive/NEXCO/src/run_test/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/NEXCO/src/run_test

# %%
# !ls
# Out:
# run.py	run_test.ipynb	sample_submit  train

# %%
# !python run.py  --exec-path ./sample_submit/src/ --data-dir ./train/
# Out:
# start date: 2021-04-08, end date:2022-07-31
#
# Loading Dataset...
# a  0    2021-04-08 00:00:00
# 1    2021-04-08 01:00:00
# 2    2021-04-08 02:00:00
# Name: datetime, dtype: object
# Done
#
# Moved to /content/drive/MyDrive/NEXCO/src/run_test/sample_submit/src
#
# Loaded the model.
# 100% 480/480 [03:07<00:00,  2.56it/s]
# b  0   2021-04-08 00:00:00
# 1   2021-04-08 01:00:00
# 2   2021-04-08 02:00:00
# Name: datetime, dtype: datetime64[ns]
# c  0   2021-04-09 00:00:00
# 1   2021-04-09 01:00:00
# 2   2021-04-09 02:00:00
# Name: datetime, dtype: datetime64[ns]
# d               datetime  ...  prediction
# 0 2021-04-09 00:00:00  ...           0
# 1 2021-04-09 01:00:00  ...           0
# 2 2021-04-09 02:00:00  ...           0
# 3 2021-04-09 03:00:00  ...           0
# 4 2021-04-09 04:00:00  ...           0
#
# [5 rows x 3 columns]
#
# ...
# f1_score: 0.012
# ...

# %%
"""

0% 0/480 [00:00<?, ?it/s]0      2021-04-08 00:00:00
1      2021-04-08 01:00:00
2      2021-04-08 02:00:00
3      2021-04-08 03:00:00
4      2021-04-08 04:00:00
               ...        
1891   2021-04-08 19:00:00
1892   2021-04-08 20:00:00
1893   2021-04-08 21:00:00
1894   2021-04-08 22:00:00
1895   2021-04-08 23:00:00
Name: datetime, Length: 1896, dtype: datetime64[ns]
0            0
1            1
2            2
3            3
4            4
         ...  
1891    714259
1892    714260
1893    714261
1894    714262
1895    714263
Name: traffic_index, Length: 1896, dtype: int64
0           24.0
1           25.0
2           26.0
3           27.0
4           28.0
          ...   
1891    714283.0
1892    714284.0
1893    714285.0
1894    714286.0
1895    714287.0
Name: search_spec_index, Length: 1896, dtype: float64
0           1.0
1           1.0
2           1.0
3           1.0
4           1.0
         ...   
1891    37441.0
1892    37441.0
1893    37441.0
1894    37441.0
1895    37441.0
Name: search_unspec_index, Length: 1896, dtype: float64
0        0
1        0
2        0
3        0
4        0
        ..
1891    78
1892    78
1893    78
1894    78
1895    78
Name: road_index, Length: 1896, dtype: int64 

"""
