# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# %cd /content/drive/MyDrive/NEXCO/src/run_test/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NEXCO/src/run_test

# %%
# !pip install japanize_matplotlib jpholiday
# !python run.py  --exec-path ./sample_submit/src/ --data-dir ./train/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting japanize_matplotlib
#   Downloading japanize-matplotlib-1.1.3.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 33.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jpholiday
#   Downloading jpholiday-0.1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from japanize_matplotlib) (3.7.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (4.39.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->japanize_matplotlib) (23.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->japanize_matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.16.0)
# Building wheels for collected packages: japanize_matplotlib
#   Building wheel for japanize_matplotlib (setup.py) ... done
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120274 sha256=cbb38abcc97f14378cc5bbefe08ccfcc90a07b158d082d365a354c464769eec5
#   Stored in directory: /root/.cache/pip/wheels/91/8f/c2/83055ad0c9591b0a094730aa7cb2cc12fedacbcd2241baf534
# Successfully built japanize_matplotlib
# Installing collected packages: jpholiday, japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3 jpholiday-0.1.8

# %%
"""
train_all = pd.DataFrame()
for d in tqdm(train['datetime'].dt.date.unique()):
    input = train[train['datetime'].dt.date==d]
    input = ScoringService.extract_dataset(input)
    train_all = pd.concat([train_all, input])

search_sec
    "過去7日間の中で", この時間にsection内を通る検索をした数
    >> この日の合計
search_unsec
    "昨日", このsectionを通る検索をした数


# search_secの合計, その日のall 検索hit section数
# search_sec 移動平均
# search_sec それより前or後の検索数 + 上り下り反対車線の
    行だけ or 帰り だけの検索
# *** 周りのsectionとの関連
# 正しく休日を捉える
    連休の中何日めなのか
# {館山, 関越} * {上り, 下り} → 4

# validationの回し方的にlag変数に限界がある
# 2つの車線でmodel分ける??
    館山道: 渋滞少ない 0.13%
    関越道: 渋滞多い 0.53%
# サグ部 下り坂から上り坂


原因: 減速の連鎖
サグや長い上り坂(高坂SAや東松山IC、嵐山PA、前橋IC)
勾配とスピードの変化にドライバーが気付きにくく
スピードが落ちると車間が詰まる
後続車はブレーキを踏んで速度を落とします

"""
# Out:
# '\ntrain_all = pd.DataFrame()\nfor d in tqdm(train[\'datetime\'].dt.date.unique()):\n    input = train[train[\'datetime\'].dt.date==d]\n    input = ScoringService.extract_dataset(input)\n    train_all = pd.concat([train_all, input])\n\nsearch_sec\n    "過去7日間の中で", この時間にsection内を通る検索をした数\n    >> この日の合計\nsearch_unsec\n    "昨日", このsectionを通る検索をした数\n\n\n# search_secの合計, その日のall 検索hit section数\n# search_sec 移動平均\n# search_sec それより前or後の検索数 + 上り下り反対車線の\n    行だけ or 帰り だけの検索\n# *** 周りのsectionとの関連\n# 正しく休日を捉える\n    連休の中何日めなのか\n# {館山, 関越} * {上り, 下り} → 4\n\n# validationの回し方的にlag変数に限界がある\n# 2つの車線でmodel分ける??\n    館山道: 渋滞少ない 0.13%\n    関越道: 渋滞多い 0.53%\n# サグ部 下り坂から上り坂\n\n\n原因: 減速の連鎖\nサグや長い上り坂(高坂SAや東松山IC、嵐山PA、前橋IC)\n勾配とスピードの変化にドライバーが気付きにくく\nスピードが落ちると車間が詰まる\n後続車はブレーキを踏んで速度を落とします\n\n'

# %%
# ========================================
# Library
# ========================================
import os
import math
import random
import pickle
import itertools
import warnings
warnings.filterwarnings('ignore')
import sys
import argparse

import numpy as np
import pandas as pd
import datetime
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import matplotlib.pyplot as plt
import seaborn as sns
import japanize_matplotlib
import jpholiday
from glob import glob
from tqdm import tqdm
from sklearn.model_selection import (
    TimeSeriesSplit,
    StratifiedKFold,
    KFold,
    GroupKFold,
    StratifiedGroupKFold
)# StratifiedGroupKFold, 
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, roc_auc_score, classification_report
from scipy.optimize import minimize
import lightgbm as lgb


pd.set_option('display.max_columns', None)

def set_seed(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    # torch.manual_seed(seed)
    # torch.cuda.manual_seed(seed)
    # torch.backends.cudnn.deterministic = True
set_seed()

class TestHoliday(jpholiday.OriginalHoliday):
    def _is_holiday(self, date):
        extra_holidays = [
            #GW
            datetime.date(2021, 4, 29), datetime.date(2022, 4, 29), datetime.date(2023, 4, 29),
            datetime.date(2021, 4, 30), datetime.date(2022, 4, 30), datetime.date(2023, 4, 30),
            datetime.date(2021, 5, 1), datetime.date(2022, 5, 1), datetime.date(2023, 5, 1),
            datetime.date(2021, 5, 2), datetime.date(2022, 5, 2), datetime.date(2023, 5, 2),
            datetime.date(2021, 5, 3), datetime.date(2022, 5, 3), datetime.date(2023, 5, 3),
            datetime.date(2021, 5, 4), datetime.date(2022, 5, 4), datetime.date(2023, 5, 4),
            datetime.date(2021, 5, 5), datetime.date(2022, 5, 5), datetime.date(2023, 5, 5),

            # お盆
            datetime.date(2021, 8, 13), datetime.date(2022, 8, 13), datetime.date(2023, 8, 13),
            datetime.date(2021, 8, 14), datetime.date(2022, 8, 14), datetime.date(2023, 8, 14),
            datetime.date(2021, 8, 15), datetime.date(2022, 8, 15), datetime.date(2023, 8, 15),

            #年末年始
            datetime.date(2021, 12, 31), datetime.date(2022, 12, 31), datetime.date(2023, 12, 31),
            datetime.date(2021, 1, 1), datetime.date(2022, 1, 1), datetime.date(2023, 1, 1),
            datetime.date(2021, 1, 2), datetime.date(2022, 1, 2), datetime.date(2023, 1, 2),
            datetime.date(2021, 1, 3), datetime.date(2022, 1, 3), datetime.date(2023, 1, 3),
        ]
        if date in extra_holidays:
            return True
        return False

# この中を変える
class ScoringService(object):

    @classmethod
    def get_model(cls, model_path, inference_df, TRAIN_MODE=False):
        """Get model method

        Args:
            model_path (str): Path to the trained model directory.
            inference_df: Past data not subject to prediction.

        Returns:
            bool: The return value. True for success.
        """
        if inference_df is not None:
            if len(inference_df) > 0:
                last_date = pd.to_datetime(str(inference_df['datetime'].iloc[-1].date())+' 00:00:00')
                cls.data = inference_df[inference_df['datetime']>=last_date]
                cls.data = cls.extract_row(cls.data)
                cls.data['is_inf_df'] = 1
            else:
                cls.data = pd.DataFrame()
        else:
            cls.data = pd.DataFrame()

        cls.cat_cols = ['road_code', 'start_code', 'end_code', 'section', 'direction', 'dayofweek', \
                        'is_holiday', 'is_holiday_1', 'is_holiday_2', 'is_holiday_3', 'is_holiday_-1', 'is_holiday_-2', 'is_holiday_-3', \
                        'holiday_pre_temperature', 'holiday_temperature',  'max_holiday_temperature', 'sum_holiday_temperature', \
                        'start_pref_code', 'end_pref_code', 'season', 'road_w_direction']#  'holiday_cat_temperature',
        cls.num_cols = ['year', 'month', 'day', 'year_td', 'month_td', 'day_td', 'hour', 'search_1h', 'search_unspec_1d', 'KP', 'start_KP', 'end_KP', 'limit_speed', \
                    'straight_dist', 'KP_se_dist', 'KP_te_dist', 'KP_st_dist', 'KP_max_dist', 'detour_rate', 'start_degree', 'end_degree', 'degree_diss_es', 'OCC', 'allCars', \

                    'search_1h_lag1', 'search_1h_lag2', 'search_1h_lag3', 'search_1h_lag-1', 'search_1h_lag-2', 'search_1h_lag-3', 
                    'search_1h_lag4', 'search_1h_lag5', 'search_1h_lag-4', 'search_1h_lag-5', 
                    'search_1h_lag9', 'search_1h_lag10', 'search_1h_lag-9', 'search_1h_lag-10', 
                    'search_1h_3mean', 'search_unspec_1d_lag24',
                    
                    'sum_search_1h', 'mean_search_1h', 'med_search_1h', 'rate_search_1h',
                    
                    'search_1h_kp1', 'search_1h_kp2', 'search_1h_kp3', 'search_1h_kp-1', 'search_1h_kp-2', 'search_1h_kp-3',
                    'search_unspec_1d_kp1', 'search_unspec_1d_kp2', 'search_unspec_1d_kp3', 'search_unspec_1d_kp-1', 'search_unspec_1d_kp-2', 'search_unspec_1d_kp-3',

                    
                    'search_1h_lag1_kp1', 'search_1h_lag2_kp1', 'search_1h_lag3_kp1', 'search_1h_lag-1_kp1', 'search_1h_lag-2_kp1', 'search_1h_lag-3_kp1', 
                    'search_1h_lag4_kp1', 'search_1h_lag5_kp1', 'search_1h_lag-4_kp1', 'search_1h_lag-5_kp1', 
                    'search_1h_lag9_kp1', 'search_1h_lag10_kp1', 'search_1h_lag-9_kp1', 'search_1h_lag-10_kp1', 
                    
                    'search_1h_lag1_kp2', 'search_1h_lag2_kp2', 'search_1h_lag3_kp2', 'search_1h_lag-1_kp2', 'search_1h_lag-2_kp2', 'search_1h_lag-3_kp2', 
                    'search_1h_lag4_kp2', 'search_1h_lag5_kp2', 'search_1h_lag-4_kp2', 'search_1h_lag-5_kp2', 
                    'search_1h_lag9_kp2', 'search_1h_lag10_kp2', 'search_1h_lag-9_kp2', 'search_1h_lag-10_kp2', 

                    'search_1h_lag1_kp3', 'search_1h_lag2_kp3', 'search_1h_lag3_kp3', 'search_1h_lag-1_kp3', 'search_1h_lag-2_kp3', 'search_1h_lag-3_kp3', 
                    'search_1h_lag4_kp3', 'search_1h_lag5_kp3', 'search_1h_lag-4_kp3', 'search_1h_lag-5_kp3', 
                    'search_1h_lag9_kp3', 'search_1h_lag10_kp3', 'search_1h_lag-9_kp3', 'search_1h_lag-10_kp3', 
                    
                    'search_1h_lag1_kp-1', 'search_1h_lag2_kp-1', 'search_1h_lag3_kp-1', 'search_1h_lag-1_kp-1', 'search_1h_lag-2_kp-1', 'search_1h_lag-3_kp-1', 
                    'search_1h_lag4_kp-1', 'search_1h_lag5_kp-1', 'search_1h_lag-4_kp-1', 'search_1h_lag-5_kp-1', 
                    'search_1h_lag9_kp-1', 'search_1h_lag10_kp-1', 'search_1h_lag-9_kp-1', 'search_1h_lag-10_kp-1', 
                    
                    'search_1h_lag1_kp-2', 'search_1h_lag2_kp-2', 'search_1h_lag3_kp-2', 'search_1h_lag-1_kp-2', 'search_1h_lag-2_kp-2', 'search_1h_lag-3_kp-2', 
                    'search_1h_lag4_kp-2', 'search_1h_lag5_kp-2', 'search_1h_lag-4_kp-2', 'search_1h_lag-5_kp-2', 
                    'search_1h_lag9_kp-2', 'search_1h_lag10_kp-2', 'search_1h_lag-9_kp-2', 'search_1h_lag-10_kp-2', 

                    'search_1h_lag1_kp-3', 'search_1h_lag2_kp-3', 'search_1h_lag3_kp-3', 'search_1h_lag-1_kp-3', 'search_1h_lag-2_kp-3', 'search_1h_lag-3_kp-3', 
                    'search_1h_lag4_kp-3', 'search_1h_lag5_kp-3', 'search_1h_lag-4_kp-3', 'search_1h_lag-5_kp-3', 
                    'search_1h_lag9_kp-3', 'search_1h_lag10_kp-3', 'search_1h_lag-9_kp-3', 'search_1h_lag-10_kp-3']
        cls.feature_cols = cls.cat_cols + cls.num_cols

        cls.TRAIN_MODE = TRAIN_MODE

        cls.N_SPLIT = 5
        if not TRAIN_MODE:
            with open('../src/features/le_dict.pkl', 'rb') as f:
                cls.le = pickle.load(f)
            print(cls.le)
            cls.le_keys = list(cls.le.keys())
            # modelのロード
            cls.models = {}
            for n in range(cls.N_SPLIT):
                cls.models[n] = pickle.load(open(f'{model_path}/lgb_fold{n}.pickle', 'rb'))
        else:
            cls.models = None

        cls.params = {
            'objective': 'binary',
            'verbose': -1,
            'metric': 'binary_logloss',
            'seed': 0,

            'num_leaves': 52, 
            'learning_rate': 0.01, 
            'max_depth': 9,
            'min_data_in_leaf': 10, 
            'feature_fraction': 0.9351779629995216, 
            'bagging_fraction': 0.6384393631575852, 
            'lambda_l1': 0.9764594650133958, 
            'lambda_l2': 0.4686512016477016
        }

        # 一応過去のレコードを貯めることはできる
        return True

    @classmethod
    def expand_datetime(cls, df):
        if 'datetime' in df.columns:
            df['year'] = df['datetime'].dt.year
            df['month'] = df['datetime'].dt.month
            df['day'] = df['datetime'].dt.day
            df['hour'] = df['datetime'].dt.hour
        if 'td' in df.columns:
            df['year_td'] = df['td'].dt.year
            df['month_td'] = df['td'].dt.month
            df['day_td'] = df['td'].dt.day
            df['hour_td'] = df['td'].dt.hour
        if 'date' in df.columns:
            df['year'] = df['date'].dt.year
            df['month'] = df['date'].dt.month
            df['day'] = df['date'].dt.day
        return df

    @classmethod
    def extract_row(cls, df):
        '''
        1行内で完結する特徴量抽出
        inference_dfにもinputにも共通して働く
        流れとしては
            inference_df > {ext_row} > inference_df'
            input > {ext_row} > input'
        で条件を揃える
        '''
        def is_jpholiday(date):
            if jpholiday.is_holiday(date) or 5<=date.weekday():
                return True
            else:
                return False
        # ========================================
        # 時間関連
        # 予測当日の日付
        # ========================================
        df['td'] = df['datetime'] + pd.to_timedelta(1, 'd')

        df['dayofweek'] = df['datetime'].dt.weekday
        df['dayofweek_td'] = df['td'].dt.weekday

        date = df.iloc[0]['td'].date()
        df['is_holiday'] = int(is_jpholiday(date))

        holi_lag = 3# 前後3日分を考慮
        for i in range(holi_lag):# 0,1,2
            lag = i+1# 1,2,3
            df[f'is_holiday_{lag}'] = int(is_jpholiday(date+pd.to_timedelta(lag, 'd')))
            df[f'is_holiday_{-lag}'] = int(is_jpholiday(date+pd.to_timedelta(-lag, 'd')))

        df['holiday_temperature'] = df['is_holiday_1']*4 + df['is_holiday_2']*2 + df['is_holiday_3']*1# 0, 1,2, 3, 4, 5, 6, 7
        df['holiday_pre_temperature'] = df['is_holiday_-1']*4 + df['is_holiday_-2']*2 + df['is_holiday_-3']*1

        # df['holiday_cat_temperature'] = df['holiday_temperature'].astype(str) + '_' + df['holiday_pre_temperature'].astype(str)

        df['max_holiday_temperature'] = df[['holiday_temperature', 'holiday_pre_temperature']].max(axis=1)
        df['sum_holiday_temperature'] = df[['holiday_temperature', 'holiday_pre_temperature']].sum(axis=1)

        df = cls.expand_datetime(df)
        df['season'] = df['month_td'].apply(lambda x: (x % 12 + 3) // 3)

        # ========================================
        # 道路関連
        # ========================================
        df['section'] = df['start_code'].astype(str)+'_'+df['end_code'].astype(str)
        df['straight_dist'] = np.sqrt( (df['end_lat']-df['start_lat'])**2 + (df['end_lng']-df['start_lng'])**2 ) * 100
        df['KP_se_dist'] = np.abs(df['end_KP']-df['start_KP'])
        df['KP_te_dist'] = np.abs(df['end_KP']-df['KP'])
        df['KP_st_dist'] = np.abs(df['KP']-df['start_KP'])
        df['KP_max_dist'] = np.max(df[['KP_te_dist', 'KP_st_dist']], axis=1) / df['KP_se_dist']
        df['detour_rate'] = df['KP_se_dist']/df['straight_dist']
        df['degree_diss_es'] = df['end_degree'] - df['start_degree']

        df['road_w_direction'] = df['road_code'].astype(str) + '_' + df['direction']

        return df

    @classmethod
    def extract_with_inference(cls, df):
        '''
        df = 推論対象1日分のデータ
        cls.data = 過去データ

        input'' = concat(input', inference_df').reset_index()
        sort(input'', by={'datetime'})
            input''.groupby('section')# section毎の操作, lag変数等
            ~~ # 他のsectionとの操作 
        '''
        replace_col = []
        df['is_inf_df'] = 0
        df = pd.concat([cls.data, df]).sort_values('datetime').reset_index()

        # ========================================
        # lag変数 group毎集計
        # ========================================
        df_g = df.groupby('section')
        lags_1h = [1,2,3,-1,-2,-3, 4, 5, -4, -5, 9, 10, -9, -10]# 3時間前から3時間後まで  789  17,18,19
        for lag in lags_1h:
            df[f'search_1h_lag{lag}'] = df_g.search_1h.shift(lag).reset_index().set_index('index')['search_1h']

        # 昨日のsearch_unspec
        lag = 24
        df[f'search_unspec_1d_lag{lag}'] = df_g.search_unspec_1d.shift(lag).reset_index().set_index('index')['search_unspec_1d']

        df['search_1h_3mean'] = df_g.search_1h.rolling(3, min_periods=1).mean().reset_index().set_index('level_1')['search_1h']
        replace_col.append('search_1h_3mean')

        # ========================================
        # drop inference_df + 登録
        # ========================================
        df = df[df['is_inf_df']==0]
        df['is_inf_df'] = 1
        df = df.set_index('index').sort_index()
        cls.data = df # pd.concat([cls.data, df])

        # ========================================
        # ルート検索 関連 inference関係なし
        # ========================================
        group_search = df.groupby('section').agg(
            mean_search_1h = ("search_1h", 'mean'),
            sum_search_1h = ("search_1h", 'sum'),
            med_search_1h = ("search_1h", 'median')
            ).reset_index()
        df = pd.merge(df.reset_index(), group_search, on='section', suffixes=('', '_grouped'), how='left').set_index('index')
        df['rate_search_1h'] = df['search_1h'] / df['sum_search_1h']
        replace_col.append('rate_search_1h')

        # ========================================
        # Groupby > {road_code, direction} ::::: Sortby > {datetime, KP}
        # 同時刻のn隣sectionの検索数, inference関係なし << 他のsectionのlag引っ張りたいならあらかじめ作っておくのが良し
        # ========================================
        df_g = df.sort_values('KP').groupby(['road_code', 'direction', 'datetime'])
        lags = [1,2,3,-1,-2,-3]# 3時間前から3時間後まで
        for lag in lags:
            df[f'search_1h_kp{lag}'] = df_g.search_1h.shift(lag).reset_index().set_index('index')['search_1h']
            df[f'search_unspec_1d_kp{lag}'] = df_g.search_unspec_1d.shift(lag).reset_index().set_index('index')['search_unspec_1d']
            replace_col.append(f'search_1h_kp{lag}')
            replace_col.append(f'search_unspec_1d_kp{lag}')

            for l in lags_1h:
                df[f'search_1h_lag{l}_kp{lag}'] = df_g[f'search_1h_lag{l}'].shift(lag).reset_index().set_index('index')[f'search_1h_lag{l}']
                replace_col.append(f'search_1h_lag{l}_kp{lag}')

        df[replace_col] = df[replace_col].replace([np.nan], -1)
        df[replace_col] = df[replace_col].replace([np.inf], 999999)
        df[replace_col] = df[replace_col].replace([-np.inf], -999999)

        return df


    @classmethod
    def extract_dataset(cls, df):
        '''
        input: df
            df = valid[valid['datetime'].dt.date==d]
            1日分のデータフレーム(1d*24h*79section)
            予測日前日のtraffic + 予測日のsearch + road >> 予測

        output: ~~
        '''

        df = cls.extract_row(df)# 1日分
        df = cls.extract_with_inference(df)

        # ========================================
        # カテゴリ変数の処理
        # ========================================
        if not cls.TRAIN_MODE:
            for c in cls.le_keys:
                df[c] = cls.le[c].transform(df[c])

        return df

    @classmethod
    def predict(cls, input):
        """Predict method

        Args:
            input: meta data of the sample you want to make inference from (DataFrame)

        Returns:
            prediction: Inference for the given input. Return columns must be ['datetime', 'start_code', 'end_code'](DataFrame).
        
        Tips:
            You can use past data by writing "cls.data".
        """
        
        prediction = input.copy()

        # ======================== ここから特徴量作成 ========================

        prediction = cls.extract_dataset(prediction)

        # ======================== ここから予測 =============================

        prediction['prediction'] = 0
        for n in range(cls.N_SPLIT):
            prediction['prediction'] += cls.models[n].predict(prediction[cls.feature_cols]) / cls.N_SPLIT
        prediction['prediction'] = prediction['prediction'].round()
        prediction['prediction'] = prediction['prediction'].astype(int)
        prediction['start_code'] = input["start_code"]
        prediction['end_code'] = input["end_code"]
        prediction['datetime'] = input["datetime"]
        prediction = prediction[['datetime', 'start_code', 'end_code', 'prediction']]

        '''if prediction['datetime'].iloc[0]==pd.to_datetime('2022-07-01 00:00:00'):
            raise ValueError("test. ", prediction.tail(5))'''

        return prediction

# %% [markdown]
# # -----

# %%
# 不変
def make_dataset(traffic, ic_master, search_spec, search_unspec):
    # 欠損値の除外
    traffic = traffic[traffic['speed'].isnull()==False]
    ic_master.dropna(inplace=True)
    search_spec.dropna(inplace=True)
    search_unspec.dropna(inplace=True)
    
    # datetimeからdateを作成
    traffic['date'] = traffic['datetime'].apply(lambda x: x.split()[0])

    # データのマージ
    traffic = traffic.merge(ic_master, on=['start_code', 'end_code'], how='left')
    traffic = traffic.merge(search_spec, on=['datetime', 'start_code', 'end_code'], how='left')
    traffic = traffic.merge(search_unspec, on=['date', 'start_code', 'end_code'], how='left')
    traffic.sort_values(['date', 'start_code', 'end_code'], inplace=True)
    traffic.reset_index(drop=True, inplace=True)
    traffic.drop(columns='date', inplace=True)

    # データ型の変更
    traffic['datetime'] = pd.to_datetime(traffic['datetime'])

    return traffic


def parse_args():
    parser = argparse.ArgumentParser()
    parser.add_argument('--exec-path', help = '/path/to/submit/src')
    parser.add_argument('--data-dir', help = '/path/to/train')
    parser.add_argument('--start-date', default = '2021-04-08', type = str, help='start date')
    parser.add_argument('--end-date', default = '2022-07-31', type = str, help='end date')
    args = parser.parse_args()

    return args

def train():

    # ========================================
    # training module
    # ========================================
    def f1(y_true, y_pred):
        y_pred = (y_pred > 0.5).astype(int)
        score = f1_score(y_true, y_pred)
        return 'f1', score, True

    def lgb_f1_score(y_hat, data):
        y_true = data.get_label()
        y_hat = np.where(y_hat < 0.5, 0, 1)   # scikits f1 doesn't like probabilities
        return 'f1', f1_score(y_true, y_hat), True

    def train_lgbm(X,
                y,
                cv,
                model_path = [],
                params: dict=None,
                verbose: int=100,
                weight_dict: dict=None,
                cat_cols: list=[]
                ):

        # パラメータがないときは、空の dict で置き換える
        if params is None:
            params = {}

        models = []

        n_records = len(X)
        # training data の target と同じだけのゼロ配列を用意
        oof_pred = np.zeros((n_records, ), dtype=np.float32)
        
        for i, (idx_train, idx_valid) in enumerate(cv):
            x_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
            x_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

            print(f'train shape = {x_train.shape}')
            print(f'valid shape = {x_valid.shape}')
            
            if weight_dict is None:
                print('Don\'t use sample weight.')
                lgb_train = lgb.Dataset(x_train, y_train)
            elif weight_dict[0] == 'balance':
                print('Using sample weight. {Balance}')
                lgb_train = lgb.Dataset(x_train, y_train, weight=compute_sample_weight(class_weight='balanced', y=y_train).astype('float32'))
            else:
                print('Using sample weight.')
                print(weight_dict)
                lgb_train = lgb.Dataset(x_train, y_train, weight=compute_sample_weight(class_weight=weight_dict, y=y_train).astype('float32'))
                
            lgb_eval = lgb.Dataset(x_valid, y_valid, reference=lgb_train)
            
            clf = lgb.train(params, lgb_train, 
                            valid_sets=[lgb_train, lgb_eval],
                            valid_names=['Train', 'Valid'],
                            feval=lgb_f1_score,
                            num_boost_round=100000,
                            verbose_eval=100,
                            categorical_feature=cat_cols,
                            callbacks = [lgb.early_stopping(stopping_rounds=100, verbose=True)]
                            )# categorical_feature=categories, verbose_eval=10
            
            pred_i = clf.predict(x_valid)
            oof_pred[idx_valid] = pred_i
            models.append(clf)
            score = f1_score(y_valid, (pred_i > 0.5).astype(int))
            print(f" - fold{i + 1} - {score:.4f} \n")
            
        score = f1_score(y, (oof_pred > 0.5).astype(int))

        print("=" * 50)
        print(f"FINISH: CV Score: {score:.4f}")
        return score, oof_pred, models

    # parse the arguments
    """
    args = parse_args()
    exec_path = os.path.abspath(args.exec_path)
    data_dir = os.path.abspath(args.data_dir)
    start_date = args.start_date
    end_date = args.end_date

    # !python run.py  --exec-path ./sample_submit/src/ --data-dir ./train/
    """
    exec_path = '/content/drive/MyDrive/NEXCO/src/run_test/sample_submit/src'
    data_dir = '/content/drive/MyDrive/NEXCO/src/run_test/train/'
    start_date = '2021-04-08'
    end_date = '2022-07-31'

    print('\nstart date: {}, end date:{}'.format(start_date, end_date))

    # load the input data
    print('\nLoading Dataset...')
    traffic = pd.read_csv(os.path.join(data_dir, 'train.csv'))
    search_spec = pd.read_csv(os.path.join(data_dir, 'search_data.csv'))
    search_unspec = pd.read_csv(os.path.join(data_dir, 'search_unspec_data.csv'))
    ic_master = pd.read_csv(os.path.join(data_dir, 'road.csv'))

    # 当日の検索数を使用できるように変更(search_spec, search_unspec)
    search_spec['datetime'] = pd.to_datetime(search_spec['datetime'])
    search_unspec['date'] = pd.to_datetime(search_unspec['date'])
    search_spec['datetime'] -= pd.to_timedelta(1, 'd')
    search_unspec['date'] -= pd.to_timedelta(1, 'd')
    search_spec['datetime'] = search_spec['datetime'].astype('str')
    search_unspec['date'] = search_unspec['date'].astype('str')

    df = make_dataset(traffic, ic_master, search_spec, search_unspec)
    inference_df = df[df['datetime']<start_date+' 00:00:00']
    train = df[(df['datetime']>=start_date+' 00:00:00') & (df['datetime']<=end_date+' 23:00:00')]
    print('Done')

    # change the working directory
    model_path = './sample_submit/model/'
    ScoringService.get_model(model_path, inference_df, TRAIN_MODE=True)

    # prepare training data
    train_all = pd.DataFrame()
    for d in tqdm(train['datetime'].dt.date.unique()):
        input = train[train['datetime'].dt.date==d]
        input = ScoringService.extract_dataset(input)
        train_all = pd.concat([train_all, input])

    le_dict = {}# only training
    for c in ScoringService.cat_cols:
        if train_all[c].dtype=='object':
            le = LabelEncoder()# only training
            print(c)
            print(train_all[c].value_counts())
            le.fit(train_all[c])# only training
            train_all[c] = le.transform(train_all[c])
            le_dict[c] = le# only training

    with open("./sample_submit/src/features/le_dict.pkl", "wb") as f:# only training
        pickle.dump(le_dict, f)# only training

    # training
    train_all.sort_values(['section', 'datetime'])
    train_all['is_congestion'] = train_all.groupby('section').shift(-24).reset_index()['is_congestion']
    train_all = train_all[~train_all['is_congestion'].isnull()].reset_index(drop=True)

    # ========================================
    # train-validation split
    # ========================================
    TARGET = 'is_congestion'
    N_SPLIT = ScoringService.N_SPLIT
    kf = StratifiedGroupKFold(N_SPLIT)
    cv_list = list(kf.split(train_all, y=train_all[TARGET], groups=train_all['datetime'].dt.date))

    X = train_all[ScoringService.feature_cols]
    y = train_all[TARGET]
    print('train all shape:', X.shape)
    print('train columns: \n', X.columns)

    weight = {0:1.0, 1:5.0}
    score, oof_pred, models = train_lgbm(X, y=y, params=ScoringService.params, cv=cv_list, weight_dict=weight, cat_cols=ScoringService.cat_cols)# 0.5814 <> shuffle 5810

    for i, m in enumerate(models):
        with open(f'./sample_submit/model/lgb_fold{i}.pickle', mode="wb") as f:
            pickle.dump(m, f)

    # ========================================
    # feature importance
    # ========================================
    def visualize_importance(models, feat_train_df):
        feature_importance_df = pd.DataFrame()
        for i, model in enumerate(models):
            _df = pd.DataFrame()
            importance_type = 'split'
            _df["feature_importance"] = model.feature_importance(importance_type=importance_type)
            _df["column"] = feat_train_df.columns
            _df["fold"] = i + 1
            feature_importance_df = pd.concat([feature_importance_df, _df],
                                            axis=0, ignore_index=True)

        order = feature_importance_df.groupby("column")\
            .sum()[["feature_importance"]]\
            .sort_values("feature_importance", ascending=False).index

        fig, ax = plt.subplots(figsize=(12, max(6, len(order) * .25)))
        sns.boxplot(data=feature_importance_df,
                    x="feature_importance",
                    y="column",
                    order=order,
                    ax=ax,
                    palette="viridis",
                    orient="h")
        ax.tick_params(axis="x", rotation=90)
        ax.set_title("Importance")
        ax.grid()
        fig.tight_layout()
        return fig, ax, feature_importance_df

    fig, ax, feature_importance_df = visualize_importance(models, X)

def main():

    # parse the arguments
    """
    args = parse_args()
    exec_path = os.path.abspath(args.exec_path)
    data_dir = os.path.abspath(args.data_dir)
    start_date = args.start_date
    end_date = args.end_date

    # !python run.py  --exec-path ./sample_submit/src/ --data-dir ./train/
    """
    exec_path = '/content/drive/MyDrive/NEXCO/src/run_test/sample_submit/src'
    data_dir = '/content/drive/MyDrive/NEXCO/src/run_test/train/'
    start_date = '2022-06-01'# '2021-04-08'
    end_date = '2022-07-31'

    print('\nstart date: {}, end date:{}'.format(start_date, end_date))

    # load the input data
    print('\nLoading Dataset...')
    traffic = pd.read_csv(os.path.join(data_dir, 'train.csv'))
    search_spec = pd.read_csv(os.path.join(data_dir, 'search_data.csv'))
    search_unspec = pd.read_csv(os.path.join(data_dir, 'search_unspec_data.csv'))
    ic_master = pd.read_csv(os.path.join(data_dir, 'road.csv'))

    # 当日の検索数を使用できるように変更(search_spec, search_unspec)
    search_spec['datetime'] = pd.to_datetime(search_spec['datetime'])
    search_unspec['date'] = pd.to_datetime(search_unspec['date'])
    search_spec['datetime'] -= pd.to_timedelta(1, 'd')
    search_unspec['date'] -= pd.to_timedelta(1, 'd')
    search_spec['datetime'] = search_spec['datetime'].astype('str')
    search_unspec['date'] = search_unspec['date'].astype('str')

    df = make_dataset(traffic, ic_master, search_spec, search_unspec)
    train = df[df['datetime']<start_date+' 00:00:00']
    valid = df[(df['datetime']>=start_date+' 00:00:00') & (df['datetime']<=end_date+' 23:00:00')]
    print('Done')

    # change the working directory
    os.chdir(exec_path)
    cwd = os.getcwd()
    print('\nMoved to {}'.format(cwd))
    model_path = os.path.join('..', 'model')
    print('Model papth = {}'.format(model_path))
    sys.path.append(cwd)

    # load the model
    # from predictor import ScoringService

    print('\nLoading the model...', end = '\r')
    model_flag = ScoringService.get_model(model_path, train)
    if model_flag:
        print('Loaded the model.')
    else:
        print('Could not load the model.')
        return None

    predictions = pd.DataFrame()
    for d in tqdm(valid['datetime'].dt.date.unique()):
        input = valid[valid['datetime'].dt.date==d]
        prediction = ScoringService.predict(input)
        if type(prediction)!= pd.DataFrame:
            print('Invalid data type in the prediction. Must be pandas.DataFrame')
            return None 
        elif set(prediction.columns) != set(['datetime', 'start_code', 'end_code', 'prediction']):
            print('Invalid columns name: {},  Excepted name: {}'.format(prediction.columns, {'datetime', 'start_code', 'end_code', 'prediction'}))
            return None
        predictions = pd.concat([predictions, prediction])

    results = valid[['datetime', 'start_code', 'end_code']]
    results = pd.merge(results, predictions, on=['datetime', 'start_code', 'end_code'], how='left')
    results['datetime'] = pd.to_datetime(results['datetime'])
    results['datetime'] += pd.to_timedelta(1, 'd')
    results = pd.merge(results, df[['datetime', 'start_code', 'end_code', 'is_congestion']], on=['datetime', 'start_code', 'end_code'], how='inner')

    #compute F1SCORE
    print('\n==================')
    print('f1_score:', round(f1_score(results['is_congestion'], results['prediction']), 4))
    print('==================')

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.3/365.3 KB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (6.0)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.0)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.4.47)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.2 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.0

# %%
def f1(y_true, y_pred):
        y_pred = (y_pred > 0.5).astype(int)
        score = f1_score(y_true, y_pred)
        return 'f1', score, True

def lgb_f1_score(y_hat, data):
    y_true = data.get_label()
    y_hat = np.where(y_hat < 0.5, 0, 1)   # scikits f1 doesn't like probabilities
    return 'f1', f1_score(y_true, y_hat), True

def train_lgbm(X,
            y,
            cv,
            model_path = [],
            params: dict=None,
            verbose: int=100,
            weight_dict: dict=None,
            cat_cols: list=[]
            ):

    # パラメータがないときは、空の dict で置き換える
    if params is None:
        params = {}

    models = []

    n_records = len(X)
    # training data の target と同じだけのゼロ配列を用意
    oof_pred = np.zeros((n_records, ), dtype=np.float32)
    
    for i, (idx_train, idx_valid) in enumerate(cv):
        x_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
        x_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

        print(f'train shape = {x_train.shape}')
        print(f'valid shape = {x_valid.shape}')
        
        if weight_dict is None:
            print('Don\'t use sample weight.')
            lgb_train = lgb.Dataset(x_train, y_train)
        elif weight_dict[0] == 'balance':
            print('Using sample weight. {Balance}')
            lgb_train = lgb.Dataset(x_train, y_train, weight=compute_sample_weight(class_weight='balanced', y=y_train).astype('float32'))
        else:
            print('Using sample weight.')
            print(weight_dict)
            lgb_train = lgb.Dataset(x_train, y_train, weight=compute_sample_weight(class_weight=weight_dict, y=y_train).astype('float32'))
            
        lgb_eval = lgb.Dataset(x_valid, y_valid, reference=lgb_train)
        
        clf = lgb.train(params, lgb_train, 
                        valid_sets=[lgb_train, lgb_eval],
                        valid_names=['Train', 'Valid'],
                        feval=lgb_f1_score,
                        num_boost_round=100000,
                        verbose_eval=100,
                        categorical_feature=cat_cols,
                        callbacks = [lgb.early_stopping(stopping_rounds=100, verbose=True)]
                        )# categorical_feature=categories, verbose_eval=10
        
        pred_i = clf.predict(x_valid)
        oof_pred[idx_valid] = pred_i
        models.append(clf)
        score = f1_score(y_valid, (pred_i > 0.5).astype(int))
        print(f" - fold{i + 1} - {score:.4f} \n")
        
    score = f1_score(y, (oof_pred > 0.5).astype(int))

    print("=" * 50)
    print(f"FINISH: CV Score: {score:.4f}")
    return score, oof_pred, models

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.9/dist-packages (3.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna) (6.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.10.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (23.0)
# Requirement already satisfied: cmaes>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from optuna) (0.9.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.9/dist-packages (from optuna) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from optuna) (1.4.47)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.9/dist-packages (from alembic>=1.5.0->optuna) (1.2.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)

# %%
# tuning
import optuna
TUNE_SEED_NUM = 1

exec_path = '/content/drive/MyDrive/NEXCO/src/run_test/sample_submit/src'
data_dir = '/content/drive/MyDrive/NEXCO/src/run_test/train/'
start_date = '2021-04-08'
end_date = '2022-07-31'

print('\nstart date: {}, end date:{}'.format(start_date, end_date))

# load the input data
print('\nLoading Dataset...')
traffic = pd.read_csv(os.path.join(data_dir, 'train.csv'))
search_spec = pd.read_csv(os.path.join(data_dir, 'search_data.csv'))
search_unspec = pd.read_csv(os.path.join(data_dir, 'search_unspec_data.csv'))
ic_master = pd.read_csv(os.path.join(data_dir, 'road.csv'))

# 当日の検索数を使用できるように変更(search_spec, search_unspec)
search_spec['datetime'] = pd.to_datetime(search_spec['datetime'])
search_unspec['date'] = pd.to_datetime(search_unspec['date'])
search_spec['datetime'] -= pd.to_timedelta(1, 'd')
search_unspec['date'] -= pd.to_timedelta(1, 'd')
search_spec['datetime'] = search_spec['datetime'].astype('str')
search_unspec['date'] = search_unspec['date'].astype('str')

df = make_dataset(traffic, ic_master, search_spec, search_unspec)
inference_df = df[df['datetime']<start_date+' 00:00:00']
train = df[(df['datetime']>=start_date+' 00:00:00') & (df['datetime']<=end_date+' 23:00:00')]
print('Done')

# change the working directory
model_path = './sample_submit/model/'
ScoringService.get_model(model_path, inference_df, TRAIN_MODE=True)

# prepare training data
train_all = pd.DataFrame()
for d in tqdm(train['datetime'].dt.date.unique()):
    input = train[train['datetime'].dt.date==d]
    input = ScoringService.extract_dataset(input)
    train_all = pd.concat([train_all, input])

le_dict = {}# only training
for c in ScoringService.cat_cols:
    if train_all[c].dtype=='object':
        le = LabelEncoder()# only training
        print(c)
        print(train_all[c].value_counts())
        le.fit(train_all[c])# only training
        train_all[c] = le.transform(train_all[c])
        le_dict[c] = le# only training

with open("./sample_submit/src/features/le_dict.pkl", "wb") as f:# only training
    pickle.dump(le_dict, f)# only training

# training
train_all.sort_values(['section', 'datetime'])
train_all['is_congestion'] = train_all.groupby('section').shift(-24).reset_index()['is_congestion']
train_all = train_all[~train_all['is_congestion'].isnull()].reset_index(drop=True)

# ========================================
# train-validation split
# ========================================
TARGET = 'is_congestion'
N_SPLIT = ScoringService.N_SPLIT
kf = StratifiedGroupKFold(N_SPLIT)
cv_list = list(kf.split(train_all, y=train_all[TARGET], groups=train_all['datetime'].dt.date))

X = train_all[ScoringService.feature_cols]
y = train_all[TARGET]
print('train all shape:', X.shape)
print('train columns: \n', X.columns)

def objective(trial):
    
    params = {
        'objective': 'binary',
        'verbose': -1,
        'metric': 'binary_logloss',
        'seed': 0,
        "force_col_wise":True,
        
        'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 0.1),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 100),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.6, 1.0),
        'lambda_l1': trial.suggest_uniform('lambda_l1', 0, 1),
        'lambda_l2': trial.suggest_uniform('lambda_l2', 0, 1),
    
    }
    weight = {0:'balance'}
    score, oof_pred, models = train_lgbm(X, y=y, params=params, cv=cv_list, weight_dict=weight)   
    return -score
    
study = optuna.create_study(sampler=optuna.samplers.RandomSampler(seed=0))
study.optimize(objective, n_trials=100)
print(study.best_params)
# Out:
# start date: 2021-04-08, end date:2022-07-31
#
# Loading Dataset...
# Done
# 100%|██████████| 480/480 [09:05<00:00,  1.14s/it]
# section
# 1110210_1800006    11520
# 1800086_1800081    11520
# 1800106_1800111    11520
# 1800106_1800096    11520
# 1800096_1800106    11520
# 1800096_1800091    11520
# 1800091_1800096    11520
# 1800091_1800086    11520
# 1800086_1800091    11520
# 1800081_1800086    11520
# 1800111_1800116    11520
# 1800081_1800076    11520
# 1800076_1800081    11520
# 1800076_1800073    11520
# 1800073_1800076    11520
# 1800073_1800072    11520
# 1800072_1800071    11520
# 1800071_1800072    11520
# 1800111_1800106    11520
# 1800116_1800111    11520
# 1800066_1800071    11520
# 1800156_1800151    11520
# 1800176_1800183    11520
# 1800176_1800171    11520
# 1800171_1800176    11520
# 1800171_1800161    11520
# 1800161_1800171    11520
# 1800161_1800156    11520
# 1800156_1800161    11520
# 1800151_1800156    11520
# 1800116_1800121    11520
# 1800146_1800141    11520
# 1800141_1800146    11520
# 1800141_1800131    11520
# 1800131_1800141    11520
# 1800131_1800121    11520
# 1800121_1800131    11520
# 1800121_1800116    11520
# 1800071_1800066    11520
# 1800066_1800061    11520
# 1130001_1130006    11520
# 1130031_1130026    11520
# 1800006_1110210    11520
# 1130046_1130041    11520
# 1130041_1130046    11520
# 1130041_1130039    11520
# 1130039_1130041    11520
# 1130036_1130031    11520
# 1130031_1130036    11520
# 1130026_1130031    11520
# 1800011_1800006    11520
# 1130026_1130021    11520
# 1130021_1130026    11520
# 1130021_1130016    11520
# 1130016_1130021    11520
# 1130016_1130006    11520
# 1130006_1130016    11520
# 1130006_1130001    11520
# 1800006_1800011    11520
# 1800011_1800016    11520
# 1800061_1800066    11520
# 1800036_1800041    11520
# 1800061_1800056    11520
# 1800056_1800061    11520
# 1800056_1800051    11520
# 1800051_1800056    11520
# 1800051_1800041    11520
# 1800041_1800051    11520
# 1800041_1800036    11520
# 1800036_1800028    11520
# 1800016_1800011    11520
# 1800028_1800036    11520
# 1800028_1800026    11520
# 1800026_1800028    11520
# 1800026_1800021    11520
# 1800021_1800026    11520
# 1800021_1800016    11520
# 1800016_1800021    11520
# 1800183_1800176    11520
# Name: section, dtype: int64
# direction
# 上り    460800
# 下り    449280
# Name: direction, dtype: int64
# road_w_direction
# 1800_上り    368640
# 1800_下り    357120
# 1130_下り     92160
# 1130_上り     92160
# Name: road_w_direction, dtype: int64
# [I 2023-03-28 10:30:13,332] A new study created in memory with name: no-name-8d2f2bd6-7c5b-453e-a580-d2f684f7c14d
# train all shape: (908184, 161)
# train columns:
#  Index(['road_code', 'start_code', 'end_code', 'section', 'direction',
#        'dayofweek', 'is_holiday', 'is_holiday_1', 'is_holiday_2',
#        'is_holiday_3',
#        ...
#        'search_1h_lag-2_kp-3', 'search_1h_lag-3_kp-3', 'search_1h_lag4_kp-3',
#        'search_1h_lag5_kp-3', 'search_1h_lag-4_kp-3', 'search_1h_lag-5_kp-3',
#        'search_1h_lag9_kp-3', 'search_1h_lag10_kp-3', 'search_1h_lag-9_kp-3',
#        'search_1h_lag-10_kp-3'],
#       dtype='object', length=161)
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0624428	Train's f1: 0.308345	Valid's binary_logloss: 0.0724397	Valid's f1: 0.261973
# [200]	Train's binary_logloss: 0.0295442	Train's f1: 0.449771	Valid's binary_logloss: 0.0373595	Valid's f1: 0.370242
# [300]	Train's binary_logloss: 0.016692	Train's f1: 0.583393	Valid's binary_logloss: 0.0237992	Valid's f1: 0.462992
# [400]	Train's binary_logloss: 0.00962244	Train's f1: 0.717269	Valid's binary_logloss: 0.0168703	Valid's f1: 0.543631
# [500]	Train's binary_logloss: 0.00583116	Train's f1: 0.817529	Valid's binary_logloss: 0.0139663	Valid's f1: 0.590012
# [600]	Train's binary_logloss: 0.00359825	Train's f1: 0.891881	Valid's binary_logloss: 0.0127198	Valid's f1: 0.617834
# [700]	Train's binary_logloss: 0.00227152	Train's f1: 0.945942	Valid's binary_logloss: 0.012276	Valid's f1: 0.631081
# [800]	Train's binary_logloss: 0.00146475	Train's f1: 0.977711	Valid's binary_logloss: 0.0121775	Valid's f1: 0.635977
# [900]	Train's binary_logloss: 0.000960623	Train's f1: 0.993116	Valid's binary_logloss: 0.0123497	Valid's f1: 0.642082
# Early stopping, best iteration is:
# [801]	Train's binary_logloss: 0.00145978	Train's f1: 0.978005	Valid's binary_logloss: 0.0121753	Valid's f1: 0.636428
#  - fold1 - 0.6364
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.066705	Train's f1: 0.303396	Valid's binary_logloss: 0.0740398	Valid's f1: 0.252697
# [200]	Train's binary_logloss: 0.0306931	Train's f1: 0.449102	Valid's binary_logloss: 0.0409469	Valid's f1: 0.350993
# [300]	Train's binary_logloss: 0.016643	Train's f1: 0.588483	Valid's binary_logloss: 0.0278962	Valid's f1: 0.436508
# [400]	Train's binary_logloss: 0.00903706	Train's f1: 0.729377	Valid's binary_logloss: 0.0216511	Valid's f1: 0.497551
# [500]	Train's binary_logloss: 0.00554553	Train's f1: 0.824949	Valid's binary_logloss: 0.0193981	Valid's f1: 0.525285
# [600]	Train's binary_logloss: 0.00340355	Train's f1: 0.901922	Valid's binary_logloss: 0.0184482	Valid's f1: 0.552693
# [700]	Train's binary_logloss: 0.00211379	Train's f1: 0.951451	Valid's binary_logloss: 0.0183224	Valid's f1: 0.568025
# Early stopping, best iteration is:
# [678]	Train's binary_logloss: 0.00233902	Train's f1: 0.944322	Valid's binary_logloss: 0.0182693	Valid's f1: 0.565594
#  - fold2 - 0.5656
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0649315	Train's f1: 0.322632	Valid's binary_logloss: 0.0680968	Valid's f1: 0.280266
# [200]	Train's binary_logloss: 0.0318396	Train's f1: 0.450114	Valid's binary_logloss: 0.0375062	Valid's f1: 0.367629
# [300]	Train's binary_logloss: 0.0170344	Train's f1: 0.588585	Valid's binary_logloss: 0.023985	Valid's f1: 0.447993
# [400]	Train's binary_logloss: 0.00971172	Train's f1: 0.720609	Valid's binary_logloss: 0.0178049	Valid's f1: 0.510183
# [500]	Train's binary_logloss: 0.00569636	Train's f1: 0.825076	Valid's binary_logloss: 0.0152103	Valid's f1: 0.553592
# [600]	Train's binary_logloss: 0.00331056	Train's f1: 0.90403	Valid's binary_logloss: 0.0142611	Valid's f1: 0.562582
# [700]	Train's binary_logloss: 0.00199449	Train's f1: 0.957325	Valid's binary_logloss: 0.0141541	Valid's f1: 0.574061
# Early stopping, best iteration is:
# [652]	Train's binary_logloss: 0.00252557	Train's f1: 0.936317	Valid's binary_logloss: 0.0141301	Valid's f1: 0.574966
#  - fold3 - 0.5750
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0719269	Train's f1: 0.289481	Valid's binary_logloss: 0.0868912	Valid's f1: 0.242342
# [200]	Train's binary_logloss: 0.0321612	Train's f1: 0.443335	Valid's binary_logloss: 0.0439242	Valid's f1: 0.342796
# [300]	Train's binary_logloss: 0.0173983	Train's f1: 0.59114	Valid's binary_logloss: 0.0281055	Valid's f1: 0.413526
# [400]	Train's binary_logloss: 0.0101047	Train's f1: 0.715389	Valid's binary_logloss: 0.0207448	Valid's f1: 0.458604
# [500]	Train's binary_logloss: 0.00624678	Train's f1: 0.811992	Valid's binary_logloss: 0.017322	Valid's f1: 0.502788
# [600]	Train's binary_logloss: 0.00381231	Train's f1: 0.89199	Valid's binary_logloss: 0.015779	Valid's f1: 0.523407
# [700]	Train's binary_logloss: 0.00235594	Train's f1: 0.948227	Valid's binary_logloss: 0.0152345	Valid's f1: 0.528986
# [800]	Train's binary_logloss: 0.00150687	Train's f1: 0.975729	Valid's binary_logloss: 0.0151533	Valid's f1: 0.530996
# Early stopping, best iteration is:
# [794]	Train's binary_logloss: 0.00155016	Train's f1: 0.974836	Valid's binary_logloss: 0.0151289	Valid's f1: 0.534666
#  - fold4 - 0.5347
#
# train shape = (728064, 161)
# valid shape = (180120, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0677128	Train's f1: 0.309578	Valid's binary_logloss: 0.0736957	Valid's f1: 0.262487
# [200]	Train's binary_logloss: 0.0319816	Train's f1: 0.450867	Valid's binary_logloss: 0.0385041	Valid's f1: 0.364772
# [300]	Train's binary_logloss: 0.017191	Train's f1: 0.590164	Valid's binary_logloss: 0.0239837	Valid's f1: 0.44427
# [400]	Train's binary_logloss: 0.00980997	Train's f1: 0.721348	Valid's binary_logloss: 0.0171081	Valid's f1: 0.529975
# [500]	Train's binary_logloss: 0.00599723	Train's f1: 0.81808	Valid's binary_logloss: 0.0142902	Valid's f1: 0.566215
# [600]	Train's binary_logloss: 0.00372209	Train's f1: 0.891793	Valid's binary_logloss: 0.0130491	Valid's f1: 0.594771
# [700]	Train's binary_logloss: 0.00229399	Train's f1: 0.946137	Valid's binary_logloss: 0.0125954	Valid's f1: 0.613445
# [800]	Train's binary_logloss: 0.00148033	Train's f1: 0.976017	Valid's binary_logloss: 0.0126219	Valid's f1: 0.609204
# Early stopping, best iteration is:
# [732]	Train's binary_logloss: 0.00200098	Train's f1: 0.956496	Valid's binary_logloss: 0.0125677	Valid's f1: 0.61462
#  - fold5 - 0.6146
# [I 2023-03-28 11:49:46,809] Trial 0 finished with value: -0.5833667067147243 and parameters: {'num_leaves': 141, 'learning_rate': 0.07436704297351776, 'max_depth': 7, 'min_data_in_leaf': 55, 'feature_fraction': 0.7694619197355619, 'bagging_fraction': 0.8583576452266624, 'lambda_l1': 0.4375872112626925, 'lambda_l2': 0.8917730007820798}. Best is trial 0 with value: -0.5833667067147243.
# ==================================================
# FINISH: CV Score: 0.5834
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0491506	Train's f1: 0.402057	Valid's binary_logloss: 0.0578101	Valid's f1: 0.320201
# [200]	Train's binary_logloss: 0.0206746	Train's f1: 0.5598	Valid's binary_logloss: 0.0283536	Valid's f1: 0.442136
# [300]	Train's binary_logloss: 0.0117177	Train's f1: 0.686185	Valid's binary_logloss: 0.0192816	Valid's f1: 0.525129
# [400]	Train's binary_logloss: 0.00670351	Train's f1: 0.805259	Valid's binary_logloss: 0.0150031	Valid's f1: 0.571901
# [500]	Train's binary_logloss: 0.00389784	Train's f1: 0.899418	Valid's binary_logloss: 0.0131273	Valid's f1: 0.608749
# [600]	Train's binary_logloss: 0.00229373	Train's f1: 0.95583	Valid's binary_logloss: 0.0124581	Valid's f1: 0.630655
# [700]	Train's binary_logloss: 0.00130336	Train's f1: 0.988429	Valid's binary_logloss: 0.012367	Valid's f1: 0.634989
# Early stopping, best iteration is:
# [674]	Train's binary_logloss: 0.00150476	Train's f1: 0.982594	Valid's binary_logloss: 0.0123445	Valid's f1: 0.629709
#  - fold1 - 0.6297
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0491785	Train's f1: 0.415938	Valid's binary_logloss: 0.0571806	Valid's f1: 0.332315
# [200]	Train's binary_logloss: 0.0234332	Train's f1: 0.53589	Valid's binary_logloss: 0.0335789	Valid's f1: 0.409172
# [300]	Train's binary_logloss: 0.0129783	Train's f1: 0.662612	Valid's binary_logloss: 0.0246298	Valid's f1: 0.462413
# [400]	Train's binary_logloss: 0.00755232	Train's f1: 0.782948	Valid's binary_logloss: 0.0206119	Valid's f1: 0.498249
# [500]	Train's binary_logloss: 0.00442888	Train's f1: 0.883817	Valid's binary_logloss: 0.0187846	Valid's f1: 0.531998
# [600]	Train's binary_logloss: 0.00258144	Train's f1: 0.946826	Valid's binary_logloss: 0.0182785	Valid's f1: 0.551806
# [700]	Train's binary_logloss: 0.00143826	Train's f1: 0.986646	Valid's binary_logloss: 0.0181942	Valid's f1: 0.569106
# Early stopping, best iteration is:
# [662]	Train's binary_logloss: 0.00178996	Train's f1: 0.976158	Valid's binary_logloss: 0.018175	Valid's f1: 0.560541
#  - fold2 - 0.5605
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0485966	Train's f1: 0.424806	Valid's binary_logloss: 0.0532338	Valid's f1: 0.338902
# [200]	Train's binary_logloss: 0.0215851	Train's f1: 0.557806	Valid's binary_logloss: 0.0281393	Valid's f1: 0.420763
# [300]	Train's binary_logloss: 0.0116961	Train's f1: 0.687665	Valid's binary_logloss: 0.0197922	Valid's f1: 0.481253
# [400]	Train's binary_logloss: 0.00627481	Train's f1: 0.824763	Valid's binary_logloss: 0.015752	Valid's f1: 0.522584
# [500]	Train's binary_logloss: 0.00363167	Train's f1: 0.913518	Valid's binary_logloss: 0.0145326	Valid's f1: 0.543949
# [600]	Train's binary_logloss: 0.00197807	Train's f1: 0.968115	Valid's binary_logloss: 0.0142454	Valid's f1: 0.558011
# Early stopping, best iteration is:
# [584]	Train's binary_logloss: 0.00220607	Train's f1: 0.962548	Valid's binary_logloss: 0.0142161	Valid's f1: 0.554953
#  - fold3 - 0.5550
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0546903	Train's f1: 0.394121	Valid's binary_logloss: 0.0691808	Valid's f1: 0.30254
# [200]	Train's binary_logloss: 0.0240727	Train's f1: 0.54197	Valid's binary_logloss: 0.0359775	Valid's f1: 0.387845
# [300]	Train's binary_logloss: 0.0122347	Train's f1: 0.691775	Valid's binary_logloss: 0.0230292	Valid's f1: 0.455212
# [400]	Train's binary_logloss: 0.0067071	Train's f1: 0.811889	Valid's binary_logloss: 0.0178515	Valid's f1: 0.492754
# [500]	Train's binary_logloss: 0.00387399	Train's f1: 0.905511	Valid's binary_logloss: 0.0156496	Valid's f1: 0.52269
# [600]	Train's binary_logloss: 0.00228399	Train's f1: 0.960048	Valid's binary_logloss: 0.0149376	Valid's f1: 0.536557
# [700]	Train's binary_logloss: 0.0012725	Train's f1: 0.98978	Valid's binary_logloss: 0.0148617	Valid's f1: 0.542161
# Early stopping, best iteration is:
# [677]	Train's binary_logloss: 0.0014658	Train's f1: 0.985203	Valid's binary_logloss: 0.0148337	Valid's f1: 0.536285
#  - fold4 - 0.5363
#
# train shape = (728064, 161)
# valid shape = (180120, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0515998	Train's f1: 0.420667	Valid's binary_logloss: 0.0572862	Valid's f1: 0.348442
# [200]	Train's binary_logloss: 0.0216978	Train's f1: 0.563952	Valid's binary_logloss: 0.0286453	Valid's f1: 0.4354
# [300]	Train's binary_logloss: 0.0112338	Train's f1: 0.707483	Valid's binary_logloss: 0.0188596	Valid's f1: 0.506741
# [400]	Train's binary_logloss: 0.00582652	Train's f1: 0.834969	Valid's binary_logloss: 0.0142814	Valid's f1: 0.568156
# [500]	Train's binary_logloss: 0.00324028	Train's f1: 0.92634	Valid's binary_logloss: 0.0126793	Valid's f1: 0.587776
# [600]	Train's binary_logloss: 0.0018895	Train's f1: 0.970235	Valid's binary_logloss: 0.0123681	Valid's f1: 0.611268
# Early stopping, best iteration is:
# [581]	Train's binary_logloss: 0.00208699	Train's f1: 0.964522	Valid's binary_logloss: 0.0123533	Valid's f1: 0.602359
#  - fold5 - 0.6024
# [I 2023-03-28 13:08:14,018] Trial 1 finished with value: -0.575049504950495 and parameters: {'num_leaves': 247, 'learning_rate': 0.04450973669432, 'max_depth': 9, 'min_data_in_leaf': 53, 'feature_fraction': 0.827217824437573, 'bagging_fraction': 0.9702386553170644, 'lambda_l1': 0.07103605819788694, 'lambda_l2': 0.08712929970154071}. Best is trial 0 with value: -0.5833667067147243.
# ==================================================
# FINISH: CV Score: 0.5750
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.18788	Train's f1: 0.120578	Valid's binary_logloss: 0.18319	Valid's f1: 0.114765
# [200]	Train's binary_logloss: 0.138339	Train's f1: 0.155326	Valid's binary_logloss: 0.142369	Valid's f1: 0.143517
# [300]	Train's binary_logloss: 0.111831	Train's f1: 0.183146	Valid's binary_logloss: 0.120044	Valid's f1: 0.167084
# [400]	Train's binary_logloss: 0.0938407	Train's f1: 0.20685	Valid's binary_logloss: 0.103793	Valid's f1: 0.186728
# [500]	Train's binary_logloss: 0.0809908	Train's f1: 0.228763	Valid's binary_logloss: 0.0922758	Valid's f1: 0.202234
# [600]	Train's binary_logloss: 0.0706705	Train's f1: 0.252389	Valid's binary_logloss: 0.0816382	Valid's f1: 0.221684
# [700]	Train's binary_logloss: 0.0625562	Train's f1: 0.273448	Valid's binary_logloss: 0.0736081	Valid's f1: 0.239563
# [800]	Train's binary_logloss: 0.0558636	Train's f1: 0.292621	Valid's binary_logloss: 0.0667816	Valid's f1: 0.254854
# [900]	Train's binary_logloss: 0.0500808	Train's f1: 0.313457	Valid's binary_logloss: 0.0603982	Valid's f1: 0.271405
# [1000]	Train's binary_logloss: 0.0451967	Train's f1: 0.335261	Valid's binary_logloss: 0.0551963	Valid's f1: 0.288
# [1100]	Train's binary_logloss: 0.0410754	Train's f1: 0.354677	Valid's binary_logloss: 0.0503541	Valid's f1: 0.302112
# [1200]	Train's binary_logloss: 0.0374487	Train's f1: 0.375868	Valid's binary_logloss: 0.0463889	Valid's f1: 0.316793
# [1300]	Train's binary_logloss: 0.0341969	Train's f1: 0.397672	Valid's binary_logloss: 0.0425297	Valid's f1: 0.334893
# [1400]	Train's binary_logloss: 0.0313668	Train's f1: 0.416554	Valid's binary_logloss: 0.0391979	Valid's f1: 0.3532
# [1500]	Train's binary_logloss: 0.0289768	Train's f1: 0.436936	Valid's binary_logloss: 0.0364173	Valid's f1: 0.367703
# [1600]	Train's binary_logloss: 0.0268545	Train's f1: 0.456444	Valid's binary_logloss: 0.034316	Valid's f1: 0.380545
# [1700]	Train's binary_logloss: 0.0248923	Train's f1: 0.473523	Valid's binary_logloss: 0.0322781	Valid's f1: 0.393716
# [1800]	Train's binary_logloss: 0.0231892	Train's f1: 0.491446	Valid's binary_logloss: 0.0306552	Valid's f1: 0.40626
# [1900]	Train's binary_logloss: 0.0215784	Train's f1: 0.507465	Valid's binary_logloss: 0.0289855	Valid's f1: 0.41922
# [2000]	Train's binary_logloss: 0.0200919	Train's f1: 0.524267	Valid's binary_logloss: 0.0275646	Valid's f1: 0.428108
# [2100]	Train's binary_logloss: 0.0187551	Train's f1: 0.541361	Valid's binary_logloss: 0.0262673	Valid's f1: 0.435754
# [2200]	Train's binary_logloss: 0.0175933	Train's f1: 0.557492	Valid's binary_logloss: 0.0250959	Valid's f1: 0.443418
# [2300]	Train's binary_logloss: 0.0164673	Train's f1: 0.571932	Valid's binary_logloss: 0.0241346	Valid's f1: 0.449686
# [2400]	Train's binary_logloss: 0.0154046	Train's f1: 0.58895	Valid's binary_logloss: 0.0231625	Valid's f1: 0.460414
# [2500]	Train's binary_logloss: 0.0144037	Train's f1: 0.608777	Valid's binary_logloss: 0.0222565	Valid's f1: 0.46402
# [2600]	Train's binary_logloss: 0.0135875	Train's f1: 0.623571	Valid's binary_logloss: 0.0216007	Valid's f1: 0.472328
# [2700]	Train's binary_logloss: 0.0127681	Train's f1: 0.640363	Valid's binary_logloss: 0.020951	Valid's f1: 0.483717
# [2800]	Train's binary_logloss: 0.0120458	Train's f1: 0.652922	Valid's binary_logloss: 0.0203251	Valid's f1: 0.488175
# [2900]	Train's binary_logloss: 0.0113237	Train's f1: 0.667215	Valid's binary_logloss: 0.0197131	Valid's f1: 0.499771
# [3000]	Train's binary_logloss: 0.0106637	Train's f1: 0.680503	Valid's binary_logloss: 0.0191457	Valid's f1: 0.508443
# [3100]	Train's binary_logloss: 0.0100804	Train's f1: 0.693516	Valid's binary_logloss: 0.0187411	Valid's f1: 0.514833
# [3200]	Train's binary_logloss: 0.00950392	Train's f1: 0.708347	Valid's binary_logloss: 0.0183175	Valid's f1: 0.521994
# [3300]	Train's binary_logloss: 0.00898827	Train's f1: 0.719574	Valid's binary_logloss: 0.0179481	Valid's f1: 0.526892
# [3400]	Train's binary_logloss: 0.00847713	Train's f1: 0.734555	Valid's binary_logloss: 0.0176017	Valid's f1: 0.532725
# [3500]	Train's binary_logloss: 0.00802118	Train's f1: 0.744239	Valid's binary_logloss: 0.0172325	Valid's f1: 0.54376
# [3600]	Train's binary_logloss: 0.00759971	Train's f1: 0.755851	Valid's binary_logloss: 0.0169275	Valid's f1: 0.545838
# [3700]	Train's binary_logloss: 0.00720774	Train's f1: 0.766199	Valid's binary_logloss: 0.0166189	Valid's f1: 0.548852
# [3800]	Train's binary_logloss: 0.0068485	Train's f1: 0.777113	Valid's binary_logloss: 0.0164397	Valid's f1: 0.55035
# [3900]	Train's binary_logloss: 0.00648635	Train's f1: 0.789589	Valid's binary_logloss: 0.0162286	Valid's f1: 0.556588
# [4000]	Train's binary_logloss: 0.00612448	Train's f1: 0.798917	Valid's binary_logloss: 0.0160187	Valid's f1: 0.560354
# [4100]	Train's binary_logloss: 0.00581257	Train's f1: 0.809375	Valid's binary_logloss: 0.0158424	Valid's f1: 0.569179
# [4200]	Train's binary_logloss: 0.00551802	Train's f1: 0.818044	Valid's binary_logloss: 0.0156935	Valid's f1: 0.571266
# [4300]	Train's binary_logloss: 0.00522858	Train's f1: 0.828378	Valid's binary_logloss: 0.0155392	Valid's f1: 0.569628
# Early stopping, best iteration is:
# [4206]	Train's binary_logloss: 0.00549625	Train's f1: 0.818767	Valid's binary_logloss: 0.0156744	Valid's f1: 0.573705
#  - fold1 - 0.5737
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.181356	Train's f1: 0.129311	Valid's binary_logloss: 0.179912	Valid's f1: 0.119082
# [200]	Train's binary_logloss: 0.135322	Train's f1: 0.16041	Valid's binary_logloss: 0.139322	Valid's f1: 0.144122
# [300]	Train's binary_logloss: 0.109428	Train's f1: 0.188397	Valid's binary_logloss: 0.11647	Valid's f1: 0.165526
# [400]	Train's binary_logloss: 0.0914006	Train's f1: 0.211834	Valid's binary_logloss: 0.0998086	Valid's f1: 0.183326
# [500]	Train's binary_logloss: 0.0785928	Train's f1: 0.235077	Valid's binary_logloss: 0.0884807	Valid's f1: 0.198686
# [600]	Train's binary_logloss: 0.0684421	Train's f1: 0.255563	Valid's binary_logloss: 0.0787896	Valid's f1: 0.215274
# [700]	Train's binary_logloss: 0.0600433	Train's f1: 0.279913	Valid's binary_logloss: 0.0702356	Valid's f1: 0.23364
# [800]	Train's binary_logloss: 0.053651	Train's f1: 0.298938	Valid's binary_logloss: 0.0641472	Valid's f1: 0.245579
# [900]	Train's binary_logloss: 0.0480173	Train's f1: 0.321602	Valid's binary_logloss: 0.0583688	Valid's f1: 0.263703
# [1000]	Train's binary_logloss: 0.0434153	Train's f1: 0.344148	Valid's binary_logloss: 0.0539297	Valid's f1: 0.279704
# [1100]	Train's binary_logloss: 0.0394183	Train's f1: 0.364316	Valid's binary_logloss: 0.0500445	Valid's f1: 0.293196
# [1200]	Train's binary_logloss: 0.0361091	Train's f1: 0.384266	Valid's binary_logloss: 0.0465399	Valid's f1: 0.307692
# [1300]	Train's binary_logloss: 0.0331537	Train's f1: 0.403845	Valid's binary_logloss: 0.0437806	Valid's f1: 0.31668
# [1400]	Train's binary_logloss: 0.0304368	Train's f1: 0.424066	Valid's binary_logloss: 0.0410267	Valid's f1: 0.333333
# [1500]	Train's binary_logloss: 0.0280289	Train's f1: 0.442304	Valid's binary_logloss: 0.0387673	Valid's f1: 0.342719
# [1600]	Train's binary_logloss: 0.025835	Train's f1: 0.460987	Valid's binary_logloss: 0.036727	Valid's f1: 0.358389
# [1700]	Train's binary_logloss: 0.0238854	Train's f1: 0.48067	Valid's binary_logloss: 0.0347327	Valid's f1: 0.372432
# [1800]	Train's binary_logloss: 0.0222559	Train's f1: 0.49903	Valid's binary_logloss: 0.0331755	Valid's f1: 0.384748
# [1900]	Train's binary_logloss: 0.0206059	Train's f1: 0.517677	Valid's binary_logloss: 0.0316589	Valid's f1: 0.396125
# [2000]	Train's binary_logloss: 0.0192063	Train's f1: 0.535488	Valid's binary_logloss: 0.0303123	Valid's f1: 0.407491
# [2100]	Train's binary_logloss: 0.0179923	Train's f1: 0.551618	Valid's binary_logloss: 0.0292312	Valid's f1: 0.416893
# [2200]	Train's binary_logloss: 0.0168613	Train's f1: 0.568497	Valid's binary_logloss: 0.0282152	Valid's f1: 0.421468
# [2300]	Train's binary_logloss: 0.0157482	Train's f1: 0.583939	Valid's binary_logloss: 0.0272935	Valid's f1: 0.43107
# [2400]	Train's binary_logloss: 0.0147554	Train's f1: 0.600019	Valid's binary_logloss: 0.0265676	Valid's f1: 0.439917
# [2500]	Train's binary_logloss: 0.0138594	Train's f1: 0.617246	Valid's binary_logloss: 0.0257496	Valid's f1: 0.448511
# [2600]	Train's binary_logloss: 0.0130119	Train's f1: 0.632553	Valid's binary_logloss: 0.0251669	Valid's f1: 0.453564
# [2700]	Train's binary_logloss: 0.0121831	Train's f1: 0.648638	Valid's binary_logloss: 0.0244974	Valid's f1: 0.459436
# [2800]	Train's binary_logloss: 0.0114664	Train's f1: 0.664668	Valid's binary_logloss: 0.023957	Valid's f1: 0.464865
# [2900]	Train's binary_logloss: 0.0108048	Train's f1: 0.679349	Valid's binary_logloss: 0.0234291	Valid's f1: 0.474389
# [3000]	Train's binary_logloss: 0.0101721	Train's f1: 0.693494	Valid's binary_logloss: 0.0230409	Valid's f1: 0.482564
# [3100]	Train's binary_logloss: 0.00959294	Train's f1: 0.706607	Valid's binary_logloss: 0.0225904	Valid's f1: 0.491313
# [3200]	Train's binary_logloss: 0.00906037	Train's f1: 0.71974	Valid's binary_logloss: 0.0222569	Valid's f1: 0.495332
# [3300]	Train's binary_logloss: 0.0085624	Train's f1: 0.731452	Valid's binary_logloss: 0.0219213	Valid's f1: 0.498756
# [3400]	Train's binary_logloss: 0.0080851	Train's f1: 0.745448	Valid's binary_logloss: 0.0215792	Valid's f1: 0.506586
# [3500]	Train's binary_logloss: 0.00767034	Train's f1: 0.756769	Valid's binary_logloss: 0.0213352	Valid's f1: 0.509463
# [3600]	Train's binary_logloss: 0.00725888	Train's f1: 0.766333	Valid's binary_logloss: 0.0210897	Valid's f1: 0.512635
# [3700]	Train's binary_logloss: 0.00688229	Train's f1: 0.778585	Valid's binary_logloss: 0.0208749	Valid's f1: 0.516936
# [3800]	Train's binary_logloss: 0.00651966	Train's f1: 0.788615	Valid's binary_logloss: 0.0206649	Valid's f1: 0.519221
# [3900]	Train's binary_logloss: 0.00617468	Train's f1: 0.801496	Valid's binary_logloss: 0.0204916	Valid's f1: 0.520621
# Early stopping, best iteration is:
# [3826]	Train's binary_logloss: 0.00641571	Train's f1: 0.791723	Valid's binary_logloss: 0.0205923	Valid's f1: 0.523305
#  - fold2 - 0.5233
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.18775	Train's f1: 0.12938	Valid's binary_logloss: 0.171642	Valid's f1: 0.125823
# [200]	Train's binary_logloss: 0.140032	Train's f1: 0.161838	Valid's binary_logloss: 0.135474	Valid's f1: 0.152706
# [300]	Train's binary_logloss: 0.112924	Train's f1: 0.188792	Valid's binary_logloss: 0.111948	Valid's f1: 0.177141
# [400]	Train's binary_logloss: 0.0940722	Train's f1: 0.212022	Valid's binary_logloss: 0.0957941	Valid's f1: 0.194857
# [500]	Train's binary_logloss: 0.0798416	Train's f1: 0.237282	Valid's binary_logloss: 0.0826664	Valid's f1: 0.213165
# [600]	Train's binary_logloss: 0.0692579	Train's f1: 0.263064	Valid's binary_logloss: 0.0731409	Valid's f1: 0.232602
# [700]	Train's binary_logloss: 0.0607881	Train's f1: 0.286795	Valid's binary_logloss: 0.0651978	Valid's f1: 0.249796
# [800]	Train's binary_logloss: 0.0539182	Train's f1: 0.308638	Valid's binary_logloss: 0.0586418	Valid's f1: 0.26652
# [900]	Train's binary_logloss: 0.0482299	Train's f1: 0.329182	Valid's binary_logloss: 0.0528821	Valid's f1: 0.282929
# [1000]	Train's binary_logloss: 0.0435915	Train's f1: 0.350196	Valid's binary_logloss: 0.048337	Valid's f1: 0.300813
# [1100]	Train's binary_logloss: 0.0395048	Train's f1: 0.371775	Valid's binary_logloss: 0.0443893	Valid's f1: 0.316442
# [1200]	Train's binary_logloss: 0.0361148	Train's f1: 0.390571	Valid's binary_logloss: 0.041456	Valid's f1: 0.323884
# [1300]	Train's binary_logloss: 0.0329584	Train's f1: 0.410928	Valid's binary_logloss: 0.0383382	Valid's f1: 0.340997
# [1400]	Train's binary_logloss: 0.0301699	Train's f1: 0.430607	Valid's binary_logloss: 0.0356778	Valid's f1: 0.35401
# [1500]	Train's binary_logloss: 0.0279551	Train's f1: 0.450424	Valid's binary_logloss: 0.0337919	Valid's f1: 0.36799
# [1600]	Train's binary_logloss: 0.0257925	Train's f1: 0.469235	Valid's binary_logloss: 0.0318026	Valid's f1: 0.380398
# [1700]	Train's binary_logloss: 0.0238546	Train's f1: 0.489355	Valid's binary_logloss: 0.0301401	Valid's f1: 0.391598
# [1800]	Train's binary_logloss: 0.0221785	Train's f1: 0.506361	Valid's binary_logloss: 0.0286878	Valid's f1: 0.400589
# [1900]	Train's binary_logloss: 0.0204893	Train's f1: 0.525477	Valid's binary_logloss: 0.0272066	Valid's f1: 0.404417
# [2000]	Train's binary_logloss: 0.0191393	Train's f1: 0.542779	Valid's binary_logloss: 0.0260888	Valid's f1: 0.411325
# [2100]	Train's binary_logloss: 0.0178871	Train's f1: 0.561066	Valid's binary_logloss: 0.0250556	Valid's f1: 0.417923
# [2200]	Train's binary_logloss: 0.0167586	Train's f1: 0.574446	Valid's binary_logloss: 0.0242621	Valid's f1: 0.426891
# [2300]	Train's binary_logloss: 0.0156906	Train's f1: 0.592593	Valid's binary_logloss: 0.0233594	Valid's f1: 0.436459
# [2400]	Train's binary_logloss: 0.0147926	Train's f1: 0.605903	Valid's binary_logloss: 0.0226721	Valid's f1: 0.443151
# [2500]	Train's binary_logloss: 0.0139058	Train's f1: 0.62201	Valid's binary_logloss: 0.0219834	Valid's f1: 0.451494
# [2600]	Train's binary_logloss: 0.0130968	Train's f1: 0.634341	Valid's binary_logloss: 0.0214261	Valid's f1: 0.456206
# [2700]	Train's binary_logloss: 0.0123102	Train's f1: 0.648198	Valid's binary_logloss: 0.0208715	Valid's f1: 0.463016
# [2800]	Train's binary_logloss: 0.0116027	Train's f1: 0.663954	Valid's binary_logloss: 0.0202739	Valid's f1: 0.470993
# [2900]	Train's binary_logloss: 0.0109459	Train's f1: 0.678798	Valid's binary_logloss: 0.019876	Valid's f1: 0.472764
# Early stopping, best iteration is:
# [2827]	Train's binary_logloss: 0.0114182	Train's f1: 0.667416	Valid's binary_logloss: 0.0201664	Valid's f1: 0.474023
#  - fold3 - 0.4740
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.194158	Train's f1: 0.121555	Valid's binary_logloss: 0.205814	Valid's f1: 0.114544
# [200]	Train's binary_logloss: 0.144977	Train's f1: 0.152283	Valid's binary_logloss: 0.163083	Valid's f1: 0.136434
# [300]	Train's binary_logloss: 0.115876	Train's f1: 0.180235	Valid's binary_logloss: 0.136987	Valid's f1: 0.157166
# [400]	Train's binary_logloss: 0.0971299	Train's f1: 0.204303	Valid's binary_logloss: 0.118735	Valid's f1: 0.1745
# [500]	Train's binary_logloss: 0.0828956	Train's f1: 0.228282	Valid's binary_logloss: 0.103979	Valid's f1: 0.18993
# [600]	Train's binary_logloss: 0.0720858	Train's f1: 0.252003	Valid's binary_logloss: 0.0933751	Valid's f1: 0.205238
# [700]	Train's binary_logloss: 0.0636393	Train's f1: 0.274161	Valid's binary_logloss: 0.0848368	Valid's f1: 0.219497
# [800]	Train's binary_logloss: 0.056649	Train's f1: 0.296059	Valid's binary_logloss: 0.076966	Valid's f1: 0.232806
# [900]	Train's binary_logloss: 0.0507577	Train's f1: 0.318223	Valid's binary_logloss: 0.0706067	Valid's f1: 0.246614
# [1000]	Train's binary_logloss: 0.0456857	Train's f1: 0.341894	Valid's binary_logloss: 0.0648171	Valid's f1: 0.262774
# [1100]	Train's binary_logloss: 0.0413297	Train's f1: 0.364175	Valid's binary_logloss: 0.0596262	Valid's f1: 0.277755
# [1200]	Train's binary_logloss: 0.0376606	Train's f1: 0.385734	Valid's binary_logloss: 0.0554861	Valid's f1: 0.292451
# [1300]	Train's binary_logloss: 0.0343086	Train's f1: 0.408696	Valid's binary_logloss: 0.051642	Valid's f1: 0.305683
# [1400]	Train's binary_logloss: 0.0314789	Train's f1: 0.429772	Valid's binary_logloss: 0.0481881	Valid's f1: 0.318588
# [1500]	Train's binary_logloss: 0.0289278	Train's f1: 0.450331	Valid's binary_logloss: 0.0450783	Valid's f1: 0.329844
# [1600]	Train's binary_logloss: 0.0267243	Train's f1: 0.46797	Valid's binary_logloss: 0.0423702	Valid's f1: 0.343009
# [1700]	Train's binary_logloss: 0.0246825	Train's f1: 0.487195	Valid's binary_logloss: 0.0396018	Valid's f1: 0.355381
# [1800]	Train's binary_logloss: 0.0228033	Train's f1: 0.505616	Valid's binary_logloss: 0.0373267	Valid's f1: 0.366881
# [1900]	Train's binary_logloss: 0.0211269	Train's f1: 0.524795	Valid's binary_logloss: 0.0353768	Valid's f1: 0.377703
# [2000]	Train's binary_logloss: 0.019618	Train's f1: 0.543168	Valid's binary_logloss: 0.0335898	Valid's f1: 0.386464
# [2100]	Train's binary_logloss: 0.018248	Train's f1: 0.561243	Valid's binary_logloss: 0.0320638	Valid's f1: 0.391914
# [2200]	Train's binary_logloss: 0.0169782	Train's f1: 0.577469	Valid's binary_logloss: 0.0304794	Valid's f1: 0.404875
# [2300]	Train's binary_logloss: 0.0158708	Train's f1: 0.594107	Valid's binary_logloss: 0.029286	Valid's f1: 0.413937
# [2400]	Train's binary_logloss: 0.0148643	Train's f1: 0.610798	Valid's binary_logloss: 0.0282322	Valid's f1: 0.421842
# [2500]	Train's binary_logloss: 0.013951	Train's f1: 0.624768	Valid's binary_logloss: 0.0274016	Valid's f1: 0.425906
# [2600]	Train's binary_logloss: 0.0130426	Train's f1: 0.641188	Valid's binary_logloss: 0.0264805	Valid's f1: 0.43679
# [2700]	Train's binary_logloss: 0.0122532	Train's f1: 0.654784	Valid's binary_logloss: 0.0256325	Valid's f1: 0.441689
# [2800]	Train's binary_logloss: 0.0114846	Train's f1: 0.66981	Valid's binary_logloss: 0.024795	Valid's f1: 0.446203
# [2900]	Train's binary_logloss: 0.0108414	Train's f1: 0.682104	Valid's binary_logloss: 0.0241689	Valid's f1: 0.447315
# [3000]	Train's binary_logloss: 0.0102054	Train's f1: 0.695993	Valid's binary_logloss: 0.0234759	Valid's f1: 0.453421
# [3100]	Train's binary_logloss: 0.00964808	Train's f1: 0.710459	Valid's binary_logloss: 0.0229505	Valid's f1: 0.457577
# [3200]	Train's binary_logloss: 0.00911055	Train's f1: 0.723077	Valid's binary_logloss: 0.0224921	Valid's f1: 0.461671
# [3300]	Train's binary_logloss: 0.00860362	Train's f1: 0.734375	Valid's binary_logloss: 0.0219935	Valid's f1: 0.465585
# [3400]	Train's binary_logloss: 0.0081171	Train's f1: 0.748828	Valid's binary_logloss: 0.0215592	Valid's f1: 0.469488
# [3500]	Train's binary_logloss: 0.00763733	Train's f1: 0.761678	Valid's binary_logloss: 0.0211581	Valid's f1: 0.468821
# Early stopping, best iteration is:
# [3441]	Train's binary_logloss: 0.00791409	Train's f1: 0.753685	Valid's binary_logloss: 0.0213443	Valid's f1: 0.473495
#  - fold4 - 0.4735
#
# train shape = (728064, 161)
# valid shape = (180120, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.192448	Train's f1: 0.126476	Valid's binary_logloss: 0.179306	Valid's f1: 0.125498
# [200]	Train's binary_logloss: 0.145018	Train's f1: 0.160143	Valid's binary_logloss: 0.141806	Valid's f1: 0.151351
# [300]	Train's binary_logloss: 0.117782	Train's f1: 0.186887	Valid's binary_logloss: 0.119566	Valid's f1: 0.174322
# [400]	Train's binary_logloss: 0.0990538	Train's f1: 0.20791	Valid's binary_logloss: 0.10453	Valid's f1: 0.18744
# [500]	Train's binary_logloss: 0.0854293	Train's f1: 0.228175	Valid's binary_logloss: 0.0925995	Valid's f1: 0.202973
# [600]	Train's binary_logloss: 0.074828	Train's f1: 0.249875	Valid's binary_logloss: 0.0831956	Valid's f1: 0.217918
# [700]	Train's binary_logloss: 0.0658966	Train's f1: 0.273978	Valid's binary_logloss: 0.074303	Valid's f1: 0.234611
# [800]	Train's binary_logloss: 0.0587588	Train's f1: 0.296055	Valid's binary_logloss: 0.0672768	Valid's f1: 0.251143
# [900]	Train's binary_logloss: 0.0526401	Train's f1: 0.317314	Valid's binary_logloss: 0.061035	Valid's f1: 0.266205
# [1000]	Train's binary_logloss: 0.0476269	Train's f1: 0.336571	Valid's binary_logloss: 0.0558987	Valid's f1: 0.28096
# [1100]	Train's binary_logloss: 0.0434916	Train's f1: 0.355797	Valid's binary_logloss: 0.0518058	Valid's f1: 0.290992
# [1200]	Train's binary_logloss: 0.0395313	Train's f1: 0.376119	Valid's binary_logloss: 0.0477358	Valid's f1: 0.305522
# [1300]	Train's binary_logloss: 0.0361669	Train's f1: 0.396754	Valid's binary_logloss: 0.0441781	Valid's f1: 0.319938
# [1400]	Train's binary_logloss: 0.0331151	Train's f1: 0.417671	Valid's binary_logloss: 0.0411045	Valid's f1: 0.333063
# [1500]	Train's binary_logloss: 0.0303467	Train's f1: 0.439968	Valid's binary_logloss: 0.0382823	Valid's f1: 0.347949
# [1600]	Train's binary_logloss: 0.0281203	Train's f1: 0.458567	Valid's binary_logloss: 0.0359761	Valid's f1: 0.360724
# [1700]	Train's binary_logloss: 0.0261907	Train's f1: 0.477238	Valid's binary_logloss: 0.033812	Valid's f1: 0.377264
# [1800]	Train's binary_logloss: 0.0242246	Train's f1: 0.497192	Valid's binary_logloss: 0.0316724	Valid's f1: 0.38934
# [1900]	Train's binary_logloss: 0.0224538	Train's f1: 0.514366	Valid's binary_logloss: 0.0298213	Valid's f1: 0.402589
# [2000]	Train's binary_logloss: 0.0208207	Train's f1: 0.532986	Valid's binary_logloss: 0.0280821	Valid's f1: 0.41492
# [2100]	Train's binary_logloss: 0.0192712	Train's f1: 0.551422	Valid's binary_logloss: 0.0263822	Valid's f1: 0.43022
# [2200]	Train's binary_logloss: 0.0179006	Train's f1: 0.570136	Valid's binary_logloss: 0.0250728	Valid's f1: 0.439062
# [2300]	Train's binary_logloss: 0.0167656	Train's f1: 0.584374	Valid's binary_logloss: 0.024	Valid's f1: 0.446633
# [2400]	Train's binary_logloss: 0.0156995	Train's f1: 0.60033	Valid's binary_logloss: 0.0231021	Valid's f1: 0.45668
# [2500]	Train's binary_logloss: 0.0147093	Train's f1: 0.617647	Valid's binary_logloss: 0.022237	Valid's f1: 0.46436
# [2600]	Train's binary_logloss: 0.0138625	Train's f1: 0.631457	Valid's binary_logloss: 0.0214534	Valid's f1: 0.473504
# [2700]	Train's binary_logloss: 0.0130059	Train's f1: 0.6466	Valid's binary_logloss: 0.0206211	Valid's f1: 0.481694
# [2800]	Train's binary_logloss: 0.0122473	Train's f1: 0.65942	Valid's binary_logloss: 0.0200325	Valid's f1: 0.489796
# [2900]	Train's binary_logloss: 0.0115243	Train's f1: 0.672483	Valid's binary_logloss: 0.0193995	Valid's f1: 0.495814
# [3000]	Train's binary_logloss: 0.0108257	Train's f1: 0.685212	Valid's binary_logloss: 0.0187928	Valid's f1: 0.500473
# [3100]	Train's binary_logloss: 0.0101819	Train's f1: 0.699925	Valid's binary_logloss: 0.0182393	Valid's f1: 0.512373
# [3200]	Train's binary_logloss: 0.00960177	Train's f1: 0.711478	Valid's binary_logloss: 0.0178065	Valid's f1: 0.516543
# [3300]	Train's binary_logloss: 0.00910014	Train's f1: 0.723338	Valid's binary_logloss: 0.017436	Valid's f1: 0.522177
# [3400]	Train's binary_logloss: 0.00859533	Train's f1: 0.734282	Valid's binary_logloss: 0.0170974	Valid's f1: 0.5261
# [3500]	Train's binary_logloss: 0.0081473	Train's f1: 0.744715	Valid's binary_logloss: 0.0167588	Valid's f1: 0.532292
# [3600]	Train's binary_logloss: 0.00769135	Train's f1: 0.756844	Valid's binary_logloss: 0.016425	Valid's f1: 0.54031
# [3700]	Train's binary_logloss: 0.00729946	Train's f1: 0.767303	Valid's binary_logloss: 0.016192	Valid's f1: 0.544269
# [3800]	Train's binary_logloss: 0.00692983	Train's f1: 0.777685	Valid's binary_logloss: 0.0159357	Valid's f1: 0.549779
# [3900]	Train's binary_logloss: 0.00657413	Train's f1: 0.787405	Valid's binary_logloss: 0.0156922	Valid's f1: 0.552381
# [4000]	Train's binary_logloss: 0.00624522	Train's f1: 0.799414	Valid's binary_logloss: 0.015548	Valid's f1: 0.554422
# [4100]	Train's binary_logloss: 0.00594615	Train's f1: 0.807991	Valid's binary_logloss: 0.0154142	Valid's f1: 0.55702
# [4200]	Train's binary_logloss: 0.00564949	Train's f1: 0.817161	Valid's binary_logloss: 0.0152287	Valid's f1: 0.559302
# [4300]	Train's binary_logloss: 0.00535088	Train's f1: 0.826959	Valid's binary_logloss: 0.0150611	Valid's f1: 0.565525
# [4400]	Train's binary_logloss: 0.0050841	Train's f1: 0.836034	Valid's binary_logloss: 0.0149313	Valid's f1: 0.571258
# [4500]	Train's binary_logloss: 0.00483034	Train's f1: 0.845528	Valid's binary_logloss: 0.0148279	Valid's f1: 0.572459
# [4600]	Train's binary_logloss: 0.00457932	Train's f1: 0.85357	Valid's binary_logloss: 0.0147242	Valid's f1: 0.572473
# [4700]	Train's binary_logloss: 0.00436554	Train's f1: 0.862105	Valid's binary_logloss: 0.014664	Valid's f1: 0.575646
# [4800]	Train's binary_logloss: 0.0041589	Train's f1: 0.869081	Valid's binary_logloss: 0.0145582	Valid's f1: 0.579078
# [4900]	Train's binary_logloss: 0.00394834	Train's f1: 0.875234	Valid's binary_logloss: 0.0144589	Valid's f1: 0.58097
# Early stopping, best iteration is:
# [4874]	Train's binary_logloss: 0.00400056	Train's f1: 0.874766	Valid's binary_logloss: 0.0144875	Valid's f1: 0.584751
#  - fold5 - 0.5848
# [I 2023-03-28 18:30:06,863] Trial 2 finished with value: -0.520730034813799 and parameters: {'num_leaves': 7, 'learning_rate': 0.08493578609931442, 'max_depth': 9, 'min_data_in_leaf': 88, 'feature_fraction': 0.9914473368931056, 'bagging_fraction': 0.9196634256866895, 'lambda_l1': 0.46147936225293185, 'lambda_l2': 0.7805291762864555}. Best is trial 0 with value: -0.5833667067147243.
# ==================================================
# FINISH: CV Score: 0.5207
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.177524	Train's f1: 0.152693	Valid's binary_logloss: 0.169768	Valid's f1: 0.145915
# [200]	Train's binary_logloss: 0.123953	Train's f1: 0.186984	Valid's binary_logloss: 0.127402	Valid's f1: 0.173383
# [300]	Train's binary_logloss: 0.0951658	Train's f1: 0.219883	Valid's binary_logloss: 0.102504	Valid's f1: 0.201811
# [400]	Train's binary_logloss: 0.0754333	Train's f1: 0.249448	Valid's binary_logloss: 0.0842528	Valid's f1: 0.227518
# [500]	Train's binary_logloss: 0.0632566	Train's f1: 0.279483	Valid's binary_logloss: 0.0724292	Valid's f1: 0.24941
# [600]	Train's binary_logloss: 0.0529699	Train's f1: 0.310526	Valid's binary_logloss: 0.0623979	Valid's f1: 0.271868
# [700]	Train's binary_logloss: 0.0454651	Train's f1: 0.339504	Valid's binary_logloss: 0.0547231	Valid's f1: 0.292768
# [800]	Train's binary_logloss: 0.0392666	Train's f1: 0.369957	Valid's binary_logloss: 0.0479294	Valid's f1: 0.319185
# [900]	Train's binary_logloss: 0.0342607	Train's f1: 0.398992	Valid's binary_logloss: 0.0424965	Valid's f1: 0.340939
# [1000]	Train's binary_logloss: 0.0301844	Train's f1: 0.430133	Valid's binary_logloss: 0.0379662	Valid's f1: 0.360034
# [1100]	Train's binary_logloss: 0.0267448	Train's f1: 0.459708	Valid's binary_logloss: 0.0344587	Valid's f1: 0.37729
# [1200]	Train's binary_logloss: 0.0239127	Train's f1: 0.484839	Valid's binary_logloss: 0.0315235	Valid's f1: 0.394904
# [1300]	Train's binary_logloss: 0.0213507	Train's f1: 0.512796	Valid's binary_logloss: 0.0287372	Valid's f1: 0.415171
# [1400]	Train's binary_logloss: 0.019241	Train's f1: 0.539561	Valid's binary_logloss: 0.0265466	Valid's f1: 0.433176
# [1500]	Train's binary_logloss: 0.0173233	Train's f1: 0.565702	Valid's binary_logloss: 0.0247246	Valid's f1: 0.443939
# [1600]	Train's binary_logloss: 0.0156376	Train's f1: 0.591203	Valid's binary_logloss: 0.0229667	Valid's f1: 0.459816
# [1700]	Train's binary_logloss: 0.014192	Train's f1: 0.613031	Valid's binary_logloss: 0.0216675	Valid's f1: 0.471967
# [1800]	Train's binary_logloss: 0.0129464	Train's f1: 0.637095	Valid's binary_logloss: 0.0205668	Valid's f1: 0.482999
# [1900]	Train's binary_logloss: 0.0117817	Train's f1: 0.658084	Valid's binary_logloss: 0.0196039	Valid's f1: 0.493861
# [2000]	Train's binary_logloss: 0.0107936	Train's f1: 0.679791	Valid's binary_logloss: 0.0187984	Valid's f1: 0.507477
# [2100]	Train's binary_logloss: 0.00986959	Train's f1: 0.701156	Valid's binary_logloss: 0.0180951	Valid's f1: 0.515815
# [2200]	Train's binary_logloss: 0.00906616	Train's f1: 0.719973	Valid's binary_logloss: 0.0174711	Valid's f1: 0.520958
# [2300]	Train's binary_logloss: 0.00831223	Train's f1: 0.740673	Valid's binary_logloss: 0.0169647	Valid's f1: 0.527495
# [2400]	Train's binary_logloss: 0.00762424	Train's f1: 0.760454	Valid's binary_logloss: 0.0165246	Valid's f1: 0.537736
# [2500]	Train's binary_logloss: 0.00698733	Train's f1: 0.778511	Valid's binary_logloss: 0.0160789	Valid's f1: 0.548405
# [2600]	Train's binary_logloss: 0.00643571	Train's f1: 0.79442	Valid's binary_logloss: 0.015728	Valid's f1: 0.553542
# [2700]	Train's binary_logloss: 0.00594884	Train's f1: 0.809274	Valid's binary_logloss: 0.0154164	Valid's f1: 0.562814
# [2800]	Train's binary_logloss: 0.00551797	Train's f1: 0.82198	Valid's binary_logloss: 0.0151817	Valid's f1: 0.571266
# [2900]	Train's binary_logloss: 0.0050804	Train's f1: 0.835306	Valid's binary_logloss: 0.014909	Valid's f1: 0.573903
# [3000]	Train's binary_logloss: 0.00469625	Train's f1: 0.848406	Valid's binary_logloss: 0.0146922	Valid's f1: 0.577465
# [3100]	Train's binary_logloss: 0.00432274	Train's f1: 0.862266	Valid's binary_logloss: 0.0145363	Valid's f1: 0.585714
# [3200]	Train's binary_logloss: 0.00400099	Train's f1: 0.871059	Valid's binary_logloss: 0.0144217	Valid's f1: 0.596491
# [3300]	Train's binary_logloss: 0.00366884	Train's f1: 0.885675	Valid's binary_logloss: 0.0143266	Valid's f1: 0.597687
# [3400]	Train's binary_logloss: 0.00338703	Train's f1: 0.895943	Valid's binary_logloss: 0.0142333	Valid's f1: 0.598513
# Early stopping, best iteration is:
# [3354]	Train's binary_logloss: 0.00351718	Train's f1: 0.890169	Valid's binary_logloss: 0.0142764	Valid's f1: 0.602588
#  - fold1 - 0.6026
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.173855	Train's f1: 0.153942	Valid's binary_logloss: 0.169004	Valid's f1: 0.1384
# [200]	Train's binary_logloss: 0.122316	Train's f1: 0.188109	Valid's binary_logloss: 0.126845	Valid's f1: 0.163755
# [300]	Train's binary_logloss: 0.0939951	Train's f1: 0.219452	Valid's binary_logloss: 0.102252	Valid's f1: 0.187896
# [400]	Train's binary_logloss: 0.075278	Train's f1: 0.248972	Valid's binary_logloss: 0.084715	Valid's f1: 0.2123
# [500]	Train's binary_logloss: 0.061733	Train's f1: 0.281681	Valid's binary_logloss: 0.0720709	Valid's f1: 0.236206
# [600]	Train's binary_logloss: 0.0513486	Train's f1: 0.312893	Valid's binary_logloss: 0.0620808	Valid's f1: 0.260173
# [700]	Train's binary_logloss: 0.0437959	Train's f1: 0.344868	Valid's binary_logloss: 0.0545344	Valid's f1: 0.282927
# [800]	Train's binary_logloss: 0.0377079	Train's f1: 0.377075	Valid's binary_logloss: 0.0484858	Valid's f1: 0.308005
# [900]	Train's binary_logloss: 0.0329727	Train's f1: 0.40699	Valid's binary_logloss: 0.0437735	Valid's f1: 0.331952
# [1000]	Train's binary_logloss: 0.0290536	Train's f1: 0.436537	Valid's binary_logloss: 0.0397656	Valid's f1: 0.351013
# [1100]	Train's binary_logloss: 0.026022	Train's f1: 0.464116	Valid's binary_logloss: 0.0369535	Valid's f1: 0.3653
# [1200]	Train's binary_logloss: 0.0233102	Train's f1: 0.491212	Valid's binary_logloss: 0.034432	Valid's f1: 0.381618
# [1300]	Train's binary_logloss: 0.0207644	Train's f1: 0.519225	Valid's binary_logloss: 0.0319481	Valid's f1: 0.399295
# [1400]	Train's binary_logloss: 0.0187124	Train's f1: 0.544792	Valid's binary_logloss: 0.0301073	Valid's f1: 0.413229
# [1500]	Train's binary_logloss: 0.0167974	Train's f1: 0.571784	Valid's binary_logloss: 0.0285367	Valid's f1: 0.426128
# [1600]	Train's binary_logloss: 0.0150741	Train's f1: 0.599739	Valid's binary_logloss: 0.0270868	Valid's f1: 0.441093
# [1700]	Train's binary_logloss: 0.013731	Train's f1: 0.620643	Valid's binary_logloss: 0.0259865	Valid's f1: 0.453006
# [1800]	Train's binary_logloss: 0.012545	Train's f1: 0.64203	Valid's binary_logloss: 0.0251085	Valid's f1: 0.463415
# [1900]	Train's binary_logloss: 0.0114485	Train's f1: 0.662407	Valid's binary_logloss: 0.0242132	Valid's f1: 0.471809
# [2000]	Train's binary_logloss: 0.0104762	Train's f1: 0.681654	Valid's binary_logloss: 0.0234036	Valid's f1: 0.481343
# [2100]	Train's binary_logloss: 0.00962478	Train's f1: 0.70213	Valid's binary_logloss: 0.0228447	Valid's f1: 0.490168
# [2200]	Train's binary_logloss: 0.00880943	Train's f1: 0.721356	Valid's binary_logloss: 0.0223647	Valid's f1: 0.494886
# [2300]	Train's binary_logloss: 0.00819409	Train's f1: 0.73919	Valid's binary_logloss: 0.021987	Valid's f1: 0.497751
# [2400]	Train's binary_logloss: 0.00753985	Train's f1: 0.75446	Valid's binary_logloss: 0.0216071	Valid's f1: 0.504082
# [2500]	Train's binary_logloss: 0.00692393	Train's f1: 0.772782	Valid's binary_logloss: 0.0212018	Valid's f1: 0.510727
# [2600]	Train's binary_logloss: 0.00635797	Train's f1: 0.789293	Valid's binary_logloss: 0.0208967	Valid's f1: 0.514682
# [2700]	Train's binary_logloss: 0.00587664	Train's f1: 0.80612	Valid's binary_logloss: 0.0206505	Valid's f1: 0.521456
# Early stopping, best iteration is:
# [2697]	Train's binary_logloss: 0.0058933	Train's f1: 0.805716	Valid's binary_logloss: 0.0206438	Valid's f1: 0.522258
#  - fold2 - 0.5223
#
# train shape = (726168, 161)
# ...
# [400]	Train's binary_logloss: 0.0248975	Train's f1: 0.503083	Valid's binary_logloss: 0.0307082	Valid's f1: 0.391149
# [500]	Train's binary_logloss: 0.0170131	Train's f1: 0.592377	Valid's binary_logloss: 0.0237407	Valid's f1: 0.440352
# [600]	Train's binary_logloss: 0.012213	Train's f1: 0.672435	Valid's binary_logloss: 0.0199829	Valid's f1: 0.483548
# [700]	Train's binary_logloss: 0.00902155	Train's f1: 0.741902	Valid's binary_logloss: 0.0177417	Valid's f1: 0.506821
# [800]	Train's binary_logloss: 0.00668809	Train's f1: 0.805031	Valid's binary_logloss: 0.0163137	Valid's f1: 0.529245
# [900]	Train's binary_logloss: 0.00499248	Train's f1: 0.859287	Valid's binary_logloss: 0.0154329	Valid's f1: 0.53146
# [1000]	Train's binary_logloss: 0.00368554	Train's f1: 0.90278	Valid's binary_logloss: 0.0149343	Valid's f1: 0.543338
# [1100]	Train's binary_logloss: 0.0026932	Train's f1: 0.939281	Valid's binary_logloss: 0.014731	Valid's f1: 0.545946
# [1200]	Train's binary_logloss: 0.00201922	Train's f1: 0.961272	Valid's binary_logloss: 0.0147246	Valid's f1: 0.557719
# Early stopping, best iteration is:
# [1167]	Train's binary_logloss: 0.0022086	Train's f1: 0.955084	Valid's binary_logloss: 0.0146866	Valid's f1: 0.555017
#  - fold3 - 0.5550
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.110924	Train's f1: 0.230227	Valid's binary_logloss: 0.12648	Valid's f1: 0.188324
# [200]	Train's binary_logloss: 0.0670904	Train's f1: 0.304065	Valid's binary_logloss: 0.0833241	Valid's f1: 0.237858
# [300]	Train's binary_logloss: 0.0421443	Train's f1: 0.394738	Valid's binary_logloss: 0.0569277	Valid's f1: 0.296097
# [400]	Train's binary_logloss: 0.0279513	Train's f1: 0.480385	Valid's binary_logloss: 0.040444	Valid's f1: 0.348451
# [500]	Train's binary_logloss: 0.0194043	Train's f1: 0.561342	Valid's binary_logloss: 0.0306882	Valid's f1: 0.392104
# [600]	Train's binary_logloss: 0.014206	Train's f1: 0.637606	Valid's binary_logloss: 0.0251288	Valid's f1: 0.423502
# [700]	Train's binary_logloss: 0.0103669	Train's f1: 0.710775	Valid's binary_logloss: 0.0212527	Valid's f1: 0.455342
# [800]	Train's binary_logloss: 0.00779974	Train's f1: 0.77686	Valid's binary_logloss: 0.0189734	Valid's f1: 0.482393
# [900]	Train's binary_logloss: 0.00585068	Train's f1: 0.8324	Valid's binary_logloss: 0.0174916	Valid's f1: 0.507216
# [1000]	Train's binary_logloss: 0.00441626	Train's f1: 0.875377	Valid's binary_logloss: 0.0165033	Valid's f1: 0.515917
# [1100]	Train's binary_logloss: 0.00328118	Train's f1: 0.919315	Valid's binary_logloss: 0.0159995	Valid's f1: 0.523947
# [1200]	Train's binary_logloss: 0.00248224	Train's f1: 0.946682	Valid's binary_logloss: 0.0156887	Valid's f1: 0.526567
# [1300]	Train's binary_logloss: 0.00184763	Train's f1: 0.970396	Valid's binary_logloss: 0.0155764	Valid's f1: 0.524631
# Early stopping, best iteration is:
# [1244]	Train's binary_logloss: 0.00218316	Train's f1: 0.958608	Valid's binary_logloss: 0.0155982	Valid's f1: 0.531155
#  - fold4 - 0.5312
#
# train shape = (728064, 161)
# valid shape = (180120, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.108081	Train's f1: 0.246407	Valid's binary_logloss: 0.108112	Valid's f1: 0.226603
# [200]	Train's binary_logloss: 0.0597015	Train's f1: 0.329681	Valid's binary_logloss: 0.0658875	Valid's f1: 0.280166
# [300]	Train's binary_logloss: 0.0374474	Train's f1: 0.415472	Valid's binary_logloss: 0.044371	Valid's f1: 0.334785
# [400]	Train's binary_logloss: 0.0243398	Train's f1: 0.507553	Valid's binary_logloss: 0.0310417	Valid's f1: 0.397997
# [500]	Train's binary_logloss: 0.016697	Train's f1: 0.601763	Valid's binary_logloss: 0.0234578	Valid's f1: 0.455095
# [600]	Train's binary_logloss: 0.0120304	Train's f1: 0.685714	Valid's binary_logloss: 0.0191961	Valid's f1: 0.494713
# [700]	Train's binary_logloss: 0.00891942	Train's f1: 0.751549	Valid's binary_logloss: 0.0165687	Valid's f1: 0.535433
# [800]	Train's binary_logloss: 0.00665601	Train's f1: 0.811092	Valid's binary_logloss: 0.0148603	Valid's f1: 0.562069
# [900]	Train's binary_logloss: 0.00514148	Train's f1: 0.852792	Valid's binary_logloss: 0.0140037	Valid's f1: 0.573512
# [1000]	Train's binary_logloss: 0.0039195	Train's f1: 0.891793	Valid's binary_logloss: 0.013374	Valid's f1: 0.586118
# [1100]	Train's binary_logloss: 0.00294262	Train's f1: 0.925424	Valid's binary_logloss: 0.0130181	Valid's f1: 0.600669
# [1200]	Train's binary_logloss: 0.00220865	Train's f1: 0.953434	Valid's binary_logloss: 0.0128359	Valid's f1: 0.604716
# [1300]	Train's binary_logloss: 0.00167031	Train's f1: 0.972395	Valid's binary_logloss: 0.0128482	Valid's f1: 0.615937
# Early stopping, best iteration is:
# [1218]	Train's binary_logloss: 0.00209103	Train's f1: 0.957195	Valid's binary_logloss: 0.0128139	Valid's f1: 0.607843
#  - fold5 - 0.6078
# [I 2023-03-29 07:39:31,725] Trial 6 finished with value: -0.576 and parameters: {'num_leaves': 82, 'learning_rate': 0.04273396938483604, 'max_depth': 7, 'min_data_in_leaf': 44, 'feature_fraction': 0.9953495352236905, 'bagging_fraction': 0.6408179242992113, 'lambda_l1': 0.2088767560948347, 'lambda_l2': 0.16130951788499626}. Best is trial 0 with value: -0.5833667067147243.
# ==================================================
# FINISH: CV Score: 0.5760
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.158964	Train's f1: 0.198578	Valid's binary_logloss: 0.157362	Valid's f1: 0.178788
# [200]	Train's binary_logloss: 0.101025	Train's f1: 0.238612	Valid's binary_logloss: 0.106647	Valid's f1: 0.21098
# [300]	Train's binary_logloss: 0.0726095	Train's f1: 0.280924	Valid's binary_logloss: 0.0808411	Valid's f1: 0.24737
# [400]	Train's binary_logloss: 0.0558642	Train's f1: 0.321966	Valid's binary_logloss: 0.0641352	Valid's f1: 0.28068
# [500]	Train's binary_logloss: 0.0451987	Train's f1: 0.357903	Valid's binary_logloss: 0.0528359	Valid's f1: 0.308479
# [600]	Train's binary_logloss: 0.0365447	Train's f1: 0.399926	Valid's binary_logloss: 0.0438928	Valid's f1: 0.341349
# [700]	Train's binary_logloss: 0.0302899	Train's f1: 0.443806	Valid's binary_logloss: 0.0371299	Valid's f1: 0.371362
# [800]	Train's binary_logloss: 0.0247729	Train's f1: 0.49011	Valid's binary_logloss: 0.0313949	Valid's f1: 0.404816
# [900]	Train's binary_logloss: 0.02069	Train's f1: 0.534189	Valid's binary_logloss: 0.0270396	Valid's f1: 0.438336
# [1000]	Train's binary_logloss: 0.0175813	Train's f1: 0.575532	Valid's binary_logloss: 0.0239176	Valid's f1: 0.463813
# [1100]	Train's binary_logloss: 0.0148593	Train's f1: 0.618345	Valid's binary_logloss: 0.021316	Valid's f1: 0.489434
# [1200]	Train's binary_logloss: 0.0126651	Train's f1: 0.658151	Valid's binary_logloss: 0.0193334	Valid's f1: 0.516453
# [1300]	Train's binary_logloss: 0.010838	Train's f1: 0.692628	Valid's binary_logloss: 0.0177647	Valid's f1: 0.537372
# [1400]	Train's binary_logloss: 0.00928425	Train's f1: 0.727966	Valid's binary_logloss: 0.0165369	Valid's f1: 0.558308
# [1500]	Train's binary_logloss: 0.00800032	Train's f1: 0.761079	Valid's binary_logloss: 0.0155841	Valid's f1: 0.575313
# [1600]	Train's binary_logloss: 0.00689906	Train's f1: 0.791418	Valid's binary_logloss: 0.0147696	Valid's f1: 0.583144
# [1700]	Train's binary_logloss: 0.00595737	Train's f1: 0.820837	Valid's binary_logloss: 0.0141355	Valid's f1: 0.593694
# [1800]	Train's binary_logloss: 0.00514709	Train's f1: 0.846084	Valid's binary_logloss: 0.0136678	Valid's f1: 0.599022
# [1900]	Train's binary_logloss: 0.00443818	Train's f1: 0.868147	Valid's binary_logloss: 0.0132592	Valid's f1: 0.604768
# [2000]	Train's binary_logloss: 0.00384814	Train's f1: 0.891636	Valid's binary_logloss: 0.0130022	Valid's f1: 0.618557
# [2100]	Train's binary_logloss: 0.00337109	Train's f1: 0.909881	Valid's binary_logloss: 0.0128213	Valid's f1: 0.625654
# [2200]	Train's binary_logloss: 0.00292746	Train's f1: 0.925314	Valid's binary_logloss: 0.012685	Valid's f1: 0.629482
# [2300]	Train's binary_logloss: 0.00254789	Train's f1: 0.938286	Valid's binary_logloss: 0.0126233	Valid's f1: 0.631081
# Early stopping, best iteration is:
# [2246]	Train's binary_logloss: 0.00275211	Train's f1: 0.93102	Valid's binary_logloss: 0.0126581	Valid's f1: 0.633267
#  - fold1 - 0.6333
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.153652	Train's f1: 0.202099	Valid's binary_logloss: 0.151721	Valid's f1: 0.174886
# [200]	Train's binary_logloss: 0.102639	Train's f1: 0.238206	Valid's binary_logloss: 0.105722	Valid's f1: 0.206065
# [300]	Train's binary_logloss: 0.075511	Train's f1: 0.274279	Valid's binary_logloss: 0.0827536	Valid's f1: 0.231083
# [400]	Train's binary_logloss: 0.0586673	Train's f1: 0.317805	Valid's binary_logloss: 0.0670434	Valid's f1: 0.262204
# [500]	Train's binary_logloss: 0.046108	Train's f1: 0.358923	Valid's binary_logloss: 0.0552312	Valid's f1: 0.295988
# [600]	Train's binary_logloss: 0.0368341	Train's f1: 0.407997	Valid's binary_logloss: 0.0463483	Valid's f1: 0.329002
# [700]	Train's binary_logloss: 0.0297736	Train's f1: 0.457607	Valid's binary_logloss: 0.0397078	Valid's f1: 0.360656
# [800]	Train's binary_logloss: 0.0246108	Train's f1: 0.500974	Valid's binary_logloss: 0.0349267	Valid's f1: 0.386662
# [900]	Train's binary_logloss: 0.0205195	Train's f1: 0.546088	Valid's binary_logloss: 0.0311822	Valid's f1: 0.409824
# [1000]	Train's binary_logloss: 0.0171263	Train's f1: 0.590266	Valid's binary_logloss: 0.0282404	Valid's f1: 0.433659
# [1100]	Train's binary_logloss: 0.0144329	Train's f1: 0.628471	Valid's binary_logloss: 0.025944	Valid's f1: 0.458316
# [1200]	Train's binary_logloss: 0.0120407	Train's f1: 0.671823	Valid's binary_logloss: 0.0240727	Valid's f1: 0.479287
# [1300]	Train's binary_logloss: 0.0102183	Train's f1: 0.708163	Valid's binary_logloss: 0.0227267	Valid's f1: 0.489873
# [1400]	Train's binary_logloss: 0.0087183	Train's f1: 0.741921	Valid's binary_logloss: 0.0216498	Valid's f1: 0.49828
# [1500]	Train's binary_logloss: 0.00741824	Train's f1: 0.773712	Valid's binary_logloss: 0.0207583	Valid's f1: 0.510507
# [1600]	Train's binary_logloss: 0.00636158	Train's f1: 0.807132	Valid's binary_logloss: 0.0201508	Valid's f1: 0.521277
# [1700]	Train's binary_logloss: 0.00540641	Train's f1: 0.83807	Valid's binary_logloss: 0.0196111	Valid's f1: 0.522976
# [1800]	Train's binary_logloss: 0.00466164	Train's f1: 0.863398	Valid's binary_logloss: 0.0192144	Valid's f1: 0.528787
# [1900]	Train's binary_logloss: 0.00403634	Train's f1: 0.885399	Valid's binary_logloss: 0.0189191	Valid's f1: 0.533865
# [2000]	Train's binary_logloss: 0.00346872	Train's f1: 0.901669	Valid's binary_logloss: 0.0186948	Valid's f1: 0.543757
# [2100]	Train's binary_logloss: 0.00301428	Train's f1: 0.921181	Valid's binary_logloss: 0.0185737	Valid's f1: 0.546856
# [2200]	Train's binary_logloss: 0.00261838	Train's f1: 0.935935	Valid's binary_logloss: 0.018469	Valid's f1: 0.552014
# [2300]	Train's binary_logloss: 0.00228394	Train's f1: 0.949483	Valid's binary_logloss: 0.0184532	Valid's f1: 0.554942
# [2400]	Train's binary_logloss: 0.00198961	Train's f1: 0.961987	Valid's binary_logloss: 0.0184714	Valid's f1: 0.558603
# Early stopping, best iteration is:
# [2352]	Train's binary_logloss: 0.00212786	Train's f1: 0.956832	Valid's binary_logloss: 0.018445	Valid's f1: 0.55886
#  - fold2 - 0.5589
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.157893	Train's f1: 0.207117	Valid's binary_logloss: 0.144434	Valid's f1: 0.200963
# [200]	Train's binary_logloss: 0.102969	Train's f1: 0.24621	Valid's binary_logloss: 0.0992947	Valid's f1: 0.228237
# [300]	Train's binary_logloss: 0.077223	Train's f1: 0.286834	Valid's binary_logloss: 0.0783799	Valid's f1: 0.251328
# [400]	Train's binary_logloss: 0.0579093	Train's f1: 0.327229	Valid's binary_logloss: 0.0617193	Valid's f1: 0.279348
# [500]	Train's binary_logloss: 0.0450951	Train's f1: 0.372178	Valid's binary_logloss: 0.0496682	Valid's f1: 0.314442
# [600]	Train's binary_logloss: 0.0362975	Train's f1: 0.416008	Valid's binary_logloss: 0.0413781	Valid's f1: 0.34721
# [700]	Train's binary_logloss: 0.0298227	Train's f1: 0.461082	Valid's binary_logloss: 0.0352498	Valid's f1: 0.373648
# [800]	Train's binary_logloss: 0.0244409	Train's f1: 0.507384	Valid's binary_logloss: 0.0303426	Valid's f1: 0.400144
# [900]	Train's binary_logloss: 0.0202757	Train's f1: 0.556048	Valid's binary_logloss: 0.0264802	Valid's f1: 0.425447
# [1000]	Train's binary_logloss: 0.0170105	Train's f1: 0.597529	Valid's binary_logloss: 0.0236908	Valid's f1: 0.450947
# [1100]	Train's binary_logloss: 0.014331	Train's f1: 0.636257	Valid's binary_logloss: 0.0215312	Valid's f1: 0.467307
# [1200]	Train's binary_logloss: 0.012158	Train's f1: 0.672851	Valid's binary_logloss: 0.0197761	Valid's f1: 0.48932
# [1300]	Train's binary_logloss: 0.0102383	Train's f1: 0.711731	Valid's binary_logloss: 0.0183224	Valid's f1: 0.505165
# [1400]	Train's binary_logloss: 0.00874202	Train's f1: 0.747167	Valid's binary_logloss: 0.0173691	Valid's f1: 0.51804
# [1500]	Train's binary_logloss: 0.0074295	Train's f1: 0.781984	Valid's binary_logloss: 0.0165278	Valid's f1: 0.525253
# [1600]	Train's binary_logloss: 0.00636059	Train's f1: 0.813864	Valid's binary_logloss: 0.0158871	Valid's f1: 0.533643
# [1700]	Train's binary_logloss: 0.00542215	Train's f1: 0.84352	Valid's binary_logloss: 0.0154022	Valid's f1: 0.541842
# [1800]	Train's binary_logloss: 0.00463324	Train's f1: 0.866817	Valid's binary_logloss: 0.0150343	Valid's f1: 0.541176
# Early stopping, best iteration is:
# [1781]	Train's binary_logloss: 0.00476853	Train's f1: 0.863264	Valid's binary_logloss: 0.0150937	Valid's f1: 0.545006
#  - fold3 - 0.5450
#
# train shape = (726168, 161)
# valid shape = (182016, 161)
# Using sample weight. {Balance}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.164886	Train's f1: 0.192884	Valid's binary_logloss: 0.174594	Valid's f1: 0.166499
# [200]	Train's binary_logloss: 0.108413	Train's f1: 0.22832	Valid's binary_logloss: 0.123491	Valid's f1: 0.192465
# [300]	Train's binary_logloss: 0.0793552	Train's f1: 0.27058	Valid's binary_logloss: 0.0957001	Valid's f1: 0.221013
# [400]	Train's binary_logloss: 0.0614779	Train's f1: 0.312344	Valid's binary_logloss: 0.0773173	Valid's f1: 0.251175
# [500]	Train's binary_logloss: 0.0487408	Train's f1: 0.358594	Valid's binary_logloss: 0.0629312	Valid's f1: 0.278439
# [600]	Train's binary_logloss: 0.0388452	Train's f1: 0.404173	Valid's binary_logloss: 0.0521261	Valid's f1: 0.303384
# [700]	Train's binary_logloss: 0.0319809	Train's f1: 0.444321	Valid's binary_logloss: 0.0444338	Valid's f1: 0.328194
# [800]	Train's binary_logloss: 0.026371	Train's f1: 0.490334	Valid's binary_logloss: 0.0384581	Valid's f1: 0.351452
# [900]	Train's binary_logloss: 0.0220597	Train's f1: 0.5336	Valid's binary_logloss: 0.0338664	Valid's f1: 0.375119
# [1000]	Train's binary_logloss: 0.0185825	Train's f1: 0.57513	Valid's binary_logloss: 0.0300361	Valid's f1: 0.396409
# [1100]	Train's binary_logloss: 0.015647	Train's f1: 0.61675	Valid's binary_logloss: 0.0268198	Valid's f1: 0.416977
# [1200]	Train's binary_logloss: 0.0132063	Train's f1: 0.657613	Valid's binary_logloss: 0.0243071	Valid's f1: 0.443373
# [1300]	Train's binary_logloss: 0.0112497	Train's f1: 0.695841	Valid's binary_logloss: 0.022302	Valid's f1: 0.463373
# [1400]	Train's binary_logloss: 0.00963418	Train's f1: 0.73018	Valid's binary_logloss: 0.0207538	Valid's f1: 0.474607
# [1500]	Train's binary_logloss: 0.00828161	Train's f1: 0.760409	Valid's binary_logloss: 0.0194901	Valid's f1: 0.487989
# [1600]	Train's binary_logloss: 0.00711498	Train's f1: 0.792462	Valid's binary_logloss: 0.0185604	Valid's f1: 0.498028
# [1700]	Train's binary_logloss: 0.00607669	Train's f1: 0.823393	Valid's binary_logloss: 0.0177866	Valid's f1: 0.506368

# %% [markdown]
#  # train & main

# %%
train()
# Out:
# start date: 2021-04-08, end date:2022-07-31
#
# Loading Dataset...
# Done
# 100%|██████████| 480/480 [08:15<00:00,  1.03s/it]
# section
# 1110210_1800006    11520
# 1800086_1800081    11520
# 1800106_1800111    11520
# 1800106_1800096    11520
# 1800096_1800106    11520
# 1800096_1800091    11520
# 1800091_1800096    11520
# 1800091_1800086    11520
# 1800086_1800091    11520
# 1800081_1800086    11520
# 1800111_1800116    11520
# 1800081_1800076    11520
# 1800076_1800081    11520
# 1800076_1800073    11520
# 1800073_1800076    11520
# 1800073_1800072    11520
# 1800072_1800071    11520
# 1800071_1800072    11520
# 1800111_1800106    11520
# 1800116_1800111    11520
# 1800066_1800071    11520
# 1800156_1800151    11520
# 1800176_1800183    11520
# 1800176_1800171    11520
# 1800171_1800176    11520
# 1800171_1800161    11520
# 1800161_1800171    11520
# 1800161_1800156    11520
# 1800156_1800161    11520
# 1800151_1800156    11520
# 1800116_1800121    11520
# 1800146_1800141    11520
# 1800141_1800146    11520
# 1800141_1800131    11520
# 1800131_1800141    11520
# 1800131_1800121    11520
# 1800121_1800131    11520
# 1800121_1800116    11520
# 1800071_1800066    11520
# 1800066_1800061    11520
# 1130001_1130006    11520
# 1130031_1130026    11520
# 1800006_1110210    11520
# 1130046_1130041    11520
# 1130041_1130046    11520
# 1130041_1130039    11520
# 1130039_1130041    11520
# 1130036_1130031    11520
# 1130031_1130036    11520
# 1130026_1130031    11520
# 1800011_1800006    11520
# 1130026_1130021    11520
# 1130021_1130026    11520
# 1130021_1130016    11520
# 1130016_1130021    11520
# 1130016_1130006    11520
# 1130006_1130016    11520
# 1130006_1130001    11520
# 1800006_1800011    11520
# 1800011_1800016    11520
# 1800061_1800066    11520
# 1800036_1800041    11520
# 1800061_1800056    11520
# 1800056_1800061    11520
# 1800056_1800051    11520
# 1800051_1800056    11520
# 1800051_1800041    11520
# 1800041_1800051    11520
# 1800041_1800036    11520
# 1800036_1800028    11520
# 1800016_1800011    11520
# 1800028_1800036    11520
# 1800028_1800026    11520
# 1800026_1800028    11520
# 1800026_1800021    11520
# 1800021_1800026    11520
# 1800021_1800016    11520
# 1800016_1800021    11520
# 1800183_1800176    11520
# Name: section, dtype: int64
# direction
# 上り    460800
# 下り    449280
# Name: direction, dtype: int64
# holiday_cat_temperature
# 6_0    111864
# 0_6    111864
# 1_1    102384
# 0_4    100488
# 0_3    100488
# 3_0     98592
# 4_0     98592
# 7_0     22752
# 0_7     17064
# 3_1     15168
# 1_3     13272
# 4_4     13272
# 4_1      5688
# 4_3      5688
# 4_6      5688
# 6_4      5688
# 7_1      5688
# 1_6      5688
# 6_7      5688
# 3_3      5688
# 1_7      3792
# 6_2      3792
# 3_4      3792
# 2_6      3792
# 1_4      3792
# 3_7      3792
# 0_5      3792
# 7_4      3792
# 7_6      3792
# 7_7      3792
# 4_2      1896
# 5_3      1896
# 2_7      1896
# 4_7      1896
# 5_0      1896
# 2_4      1896
# 1_5      1896
# 3_2      1896
# 6_1      1896
# 6_3      1896
# 5_7      1896
# Name: holiday_cat_temperature, dtype: int64
# road_w_direction
# 1800_上り    368640
# 1800_下り    357120
# 1130_下り     92160
# 1130_上り     92160
# Name: road_w_direction, dtype: int64
# train all shape: (908184, 162)
# train columns:
#  Index(['road_code', 'start_code', 'end_code', 'section', 'direction',
#        'dayofweek', 'is_holiday', 'is_holiday_1', 'is_holiday_2',
#        'is_holiday_3',
#        ...
#        'search_1h_lag-2_kp-3', 'search_1h_lag-3_kp-3', 'search_1h_lag4_kp-3',
#        'search_1h_lag5_kp-3', 'search_1h_lag-4_kp-3', 'search_1h_lag-5_kp-3',
#        'search_1h_lag9_kp-3', 'search_1h_lag10_kp-3', 'search_1h_lag-9_kp-3',
#        'search_1h_lag-10_kp-3'],
#       dtype='object', length=162)
# train shape = (726168, 162)
# valid shape = (182016, 162)
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0386001	Train's f1: 0.593551	Valid's binary_logloss: 0.0199959	Valid's f1: 0.531556
# [200]	Train's binary_logloss: 0.0269334	Train's f1: 0.699606	Valid's binary_logloss: 0.0155364	Valid's f1: 0.609626
# [300]	Train's binary_logloss: 0.0213402	Train's f1: 0.720538	Valid's binary_logloss: 0.0136741	Valid's f1: 0.619916
# Early stopping, best iteration is:
# [267]	Train's binary_logloss: 0.0228255	Train's f1: 0.716767	Valid's binary_logloss: 0.0141106	Valid's f1: 0.623734
#  - fold1 - 0.6237
#
# train shape = (726168, 162)
# valid shape = (182016, 162)
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0383698	Train's f1: 0.612492	Valid's binary_logloss: 0.0219638	Valid's f1: 0.551551
# [200]	Train's binary_logloss: 0.0266098	Train's f1: 0.705708	Valid's binary_logloss: 0.0180925	Valid's f1: 0.591978
# Early stopping, best iteration is:
# [176]	Train's binary_logloss: 0.0286362	Train's f1: 0.701419	Valid's binary_logloss: 0.0187031	Valid's f1: 0.59674
#  - fold2 - 0.5967
#
# train shape = (726168, 162)
# valid shape = (182016, 162)
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0385385	Train's f1: 0.610778	Valid's binary_logloss: 0.0206251	Valid's f1: 0.522686
# [200]	Train's binary_logloss: 0.0266065	Train's f1: 0.710518	Valid's binary_logloss: 0.0162675	Valid's f1: 0.559876
# [300]	Train's binary_logloss: 0.0212069	Train's f1: 0.72962	Valid's binary_logloss: 0.014637	Valid's f1: 0.564516
# Early stopping, best iteration is:
# [222]	Train's binary_logloss: 0.0250876	Train's f1: 0.71458	Valid's binary_logloss: 0.0157791	Valid's f1: 0.569678
#  - fold3 - 0.5697
#
# train shape = (726168, 162)
# valid shape = (182016, 162)
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0383836	Train's f1: 0.6113	Valid's binary_logloss: 0.0215542	Valid's f1: 0.471002
# [200]	Train's binary_logloss: 0.0266631	Train's f1: 0.707708	Valid's binary_logloss: 0.0173721	Valid's f1: 0.543742
# [300]	Train's binary_logloss: 0.0211845	Train's f1: 0.720806	Valid's binary_logloss: 0.015682	Valid's f1: 0.545566
# Early stopping, best iteration is:
# [291]	Train's binary_logloss: 0.0215325	Train's f1: 0.718515	Valid's binary_logloss: 0.0157723	Valid's f1: 0.550154
#  - fold4 - 0.5502
#
# train shape = (728064, 162)
# valid shape = (180120, 162)
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 100 rounds
# [100]	Train's binary_logloss: 0.0388356	Train's f1: 0.609988	Valid's binary_logloss: 0.0199782	Valid's f1: 0.52354
# [200]	Train's binary_logloss: 0.0271765	Train's f1: 0.703269	Valid's binary_logloss: 0.0155307	Valid's f1: 0.590873
# [300]	Train's binary_logloss: 0.0217725	Train's f1: 0.71817	Valid's binary_logloss: 0.0139105	Valid's f1: 0.589993
# Early stopping, best iteration is:
# [273]	Train's binary_logloss: 0.022906	Train's f1: 0.713038	Valid's binary_logloss: 0.014227	Valid's f1: 0.599849
#  - fold5 - 0.5998
#
# ==================================================
# FINISH: CV Score: 0.5869

# %%
# !pip list

# %%
main()

# %%
"""
start date: 2021-04-08, end date:2022-07-31

Loading Dataset...
Done
100%|██████████| 480/480 [02:20<00:00,  3.42it/s]
train all shape: (908184, 35)
train columns: 
 Index(['road_code', 'start_code', 'end_code', 'section', 'direction',
       'dayofweek', 'is_holiday', 'is_holiday_td', 'start_pref_code',
       'end_pref_code', 'season', 'year', 'month', 'day', 'year_td',
       'month_td', 'day_td', 'hour', 'search_1h', 'search_unspec_1d', 'KP',
       'start_KP', 'end_KP', 'limit_speed', 'straight_dist', 'KP_se_dist',
       'KP_te_dist', 'KP_st_dist', 'KP_max_dist', 'detour_rate',
       'start_degree', 'end_degree', 'degree_diss_es', 'OCC', 'allCars'],
      dtype='object')
train shape = (726168, 35)
valid shape = (182016, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0433048	Train's f1: 0.52973	Valid's binary_logloss: 0.0209946	Valid's f1: 0.522523
[200]	Train's binary_logloss: 0.0326132	Train's f1: 0.638095	Valid's binary_logloss: 0.0170196	Valid's f1: 0.584356
[300]	Train's binary_logloss: 0.0276619	Train's f1: 0.655167	Valid's binary_logloss: 0.0156014	Valid's f1: 0.584703
Early stopping, best iteration is:
[227]	Train's binary_logloss: 0.0309826	Train's f1: 0.646968	Valid's binary_logloss: 0.0165003	Valid's f1: 0.590604
 - fold1 - 0.5906 
 
train shape = (726168, 35)
valid shape = (182016, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0426736	Train's f1: 0.537978	Valid's binary_logloss: 0.0229667	Valid's f1: 0.5522
[200]	Train's binary_logloss: 0.0321598	Train's f1: 0.635226	Valid's binary_logloss: 0.0196726	Valid's f1: 0.554688
Early stopping, best iteration is:
[140]	Train's binary_logloss: 0.0373128	Train's f1: 0.616125	Valid's binary_logloss: 0.0212205	Valid's f1: 0.59816
 - fold2 - 0.5982 

train shape = (726168, 35)
valid shape = (182016, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0428572	Train's f1: 0.541676	Valid's binary_logloss: 0.02164	Valid's f1: 0.506641
[200]	Train's binary_logloss: 0.0321758	Train's f1: 0.648584	Valid's binary_logloss: 0.0174012	Valid's f1: 0.54786
[300]	Train's binary_logloss: 0.0270436	Train's f1: 0.660412	Valid's binary_logloss: 0.0156895	Valid's f1: 0.547322
Early stopping, best iteration is:
[218]	Train's binary_logloss: 0.030979	Train's f1: 0.647127	Valid's binary_logloss: 0.0169808	Valid's f1: 0.554455
 - fold3 - 0.5545 

train shape = (726168, 35)
valid shape = (182016, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0426093	Train's f1: 0.549933	Valid's binary_logloss: 0.0225878	Valid's f1: 0.446251
[200]	Train's binary_logloss: 0.032021	Train's f1: 0.644713	Valid's binary_logloss: 0.0190057	Valid's f1: 0.496251
Early stopping, best iteration is:
[162]	Train's binary_logloss: 0.0349298	Train's f1: 0.637367	Valid's binary_logloss: 0.0199217	Valid's f1: 0.503852
 - fold4 - 0.5039 

train shape = (728064, 35)
valid shape = (180120, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0438301	Train's f1: 0.529202	Valid's binary_logloss: 0.0209725	Valid's f1: 0.506718
[200]	Train's binary_logloss: 0.0330797	Train's f1: 0.638687	Valid's binary_logloss: 0.0167894	Valid's f1: 0.584235
[300]	Train's binary_logloss: 0.0282798	Train's f1: 0.651866	Valid's binary_logloss: 0.0151186	Valid's f1: 0.574483
Early stopping, best iteration is:
[218]	Train's binary_logloss: 0.0319759	Train's f1: 0.639012	Valid's binary_logloss: 0.016379	Valid's f1: 0.586989
 - fold5 - 0.5870 

==================================================
FINISH: CV Score: 0.5670
"""

# %%
data_dir = '/content/drive/MyDrive/NEXCO/src/run_test/train/'
road_df = pd.read_csv(os.path.join(data_dir, 'road.csv'))
road_df['section'] = road_df['start_code'].astype(str) + '_' +  road_df['end_code'].astype(str)

# %%
road_df

# %%
# 道路コード(関越道:1800, 館山道:1130)
kanetsu_road = road_df[road_df['road_code']==1800].sort_values('KP')
tateyama_road = road_df[road_df['road_code']==1130].sort_values('KP')

# %%
kanetsu_road

# %%
tateyama_road

# %%
# 関越道上り
kanetsu_nobori = kanetsu_road[kanetsu_road['direction']=='上り'].reset_index()
# 関越道上り
kanetsu_kudari = kanetsu_road[kanetsu_road['direction']=='下り'].reset_index()

# 館山道上り
tateyama_nobori = tateyama_road[tateyama_road['direction']=='上り'].reset_index()
# 関越道上り
tateyama_kudari = tateyama_road[tateyama_road['direction']=='下り'].reset_index()

# %%
# 関越道上り
kanetsu_nobori

# %%
# 関越道上り
kanetsu_kudari

# %%
# 館山道上り
tateyama_nobori

# %%
# 館山道上り
tateyama_kudari
