# %% [markdown]
# lag変数の追加

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# %cd /content/drive/MyDrive/NEXCO/src/run_test/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NEXCO/src/run_test

# %%
# !pip install jpholiday
# !python run.py  --exec-path ./sample_submit/src/ --data-dir ./train/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jpholiday
#   Downloading jpholiday-0.1.8-py3-none-any.whl (9.8 kB)
# Installing collected packages: jpholiday
# Successfully installed jpholiday-0.1.8

# %%
"""
train_all = pd.DataFrame()
for d in tqdm(train['datetime'].dt.date.unique()):
    input = train[train['datetime'].dt.date==d]
    input = ScoringService.extract_dataset(input)
    train_all = pd.concat([train_all, input])

search_sec
    "過去7日間の中で", この時間にsection内を通る検索をした数
    >> この日の合計
search_unsec
    "昨日", このsectionを通る検索をした数


# search_secの合計, その日のall 検索hit section数
# search_sec 移動平均
# search_sec それより前or後の検索数 + 上り下り反対車線の
    行だけ or 帰り だけの検索
# *** 周りのsectionとの関連
# 正しく休日を捉える
    連休の中何日めなのか
# {館山, 関越} * {上り, 下り} → 4

# validationの回し方的にlag変数に限界がある
# 2つの車線でmodel分ける??
    館山道: 渋滞少ない 0.13%
    関越道: 渋滞多い 0.53%
# サグ部 下り坂から上り坂


原因: 減速の連鎖
サグや長い上り坂(高坂SAや東松山IC、嵐山PA、前橋IC)
勾配とスピードの変化にドライバーが気付きにくく
スピードが落ちると車間が詰まる
後続車はブレーキを踏んで速度を落とします

"""
# Out:
# '\ntrain_all = pd.DataFrame()\nfor d in tqdm(train[\'datetime\'].dt.date.unique()):\n    input = train[train[\'datetime\'].dt.date==d]\n    input = ScoringService.extract_dataset(input)\n    train_all = pd.concat([train_all, input])\n\nsearch_sec\n    "過去7日間の中で", この時間にsection内を通る検索をした数\n    >> この日の合計\nsearch_unsec\n    "昨日", このsectionを通る検索をした数\n\n\n# search_secの合計, その日のall 検索hit section数\n# search_sec 移動平均\n# search_sec それより前or後の検索数 + 上り下り反対車線の\n    行だけ or 帰り だけの検索\n# *** 周りのsectionとの関連\n# 正しく休日を捉える\n    連休の中何日めなのか\n# {館山, 関越} * {上り, 下り} → 4\n\n# validationの回し方的にlag変数に限界がある\n# 2つの車線でmodel分ける??\n    館山道: 渋滞少ない 0.13%\n    関越道: 渋滞多い 0.53%\n# サグ部 下り坂から上り坂\n\n\n原因: 減速の連鎖\nサグや長い上り坂(高坂SAや東松山IC、嵐山PA、前橋IC)\n勾配とスピードの変化にドライバーが気付きにくく\nスピードが落ちると車間が詰まる\n後続車はブレーキを踏んで速度を落とします\n\n'

# %%
# ========================================
# Library
# ========================================
import os
import math
import random
import pickle
import itertools
import warnings
warnings.filterwarnings('ignore')
import sys
import argparse

import numpy as np
import pandas as pd
import datetime
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import matplotlib.pyplot as plt
import seaborn as sns
import jpholiday
from glob import glob
from tqdm import tqdm
from sklearn.model_selection import (
    TimeSeriesSplit,
    StratifiedKFold,
    KFold,
    GroupKFold,
    StratifiedGroupKFold
)# StratifiedGroupKFold, 
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, roc_auc_score, classification_report
from scipy.optimize import minimize
import lightgbm as lgb


pd.set_option('display.max_columns', None)

def set_seed(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    # torch.manual_seed(seed)
    # torch.cuda.manual_seed(seed)
    # torch.backends.cudnn.deterministic = True
set_seed()

class TestHoliday(jpholiday.OriginalHoliday):
    def _is_holiday(self, date):
        extra_holidays = [
            #GW
            datetime.date(2021, 4, 29), datetime.date(2022, 4, 29), datetime.date(2023, 4, 29),
            datetime.date(2021, 4, 30), datetime.date(2022, 4, 30), datetime.date(2023, 4, 30),
            datetime.date(2021, 5, 1), datetime.date(2022, 5, 1), datetime.date(2023, 5, 1),
            datetime.date(2021, 5, 2), datetime.date(2022, 5, 2), datetime.date(2023, 5, 2),
            datetime.date(2021, 5, 3), datetime.date(2022, 5, 3), datetime.date(2023, 5, 3),
            datetime.date(2021, 5, 4), datetime.date(2022, 5, 4), datetime.date(2023, 5, 4),
            datetime.date(2021, 5, 5), datetime.date(2022, 5, 5), datetime.date(2023, 5, 5),

            # お盆
            datetime.date(2021, 8, 13), datetime.date(2022, 8, 13), datetime.date(2023, 8, 13),
            datetime.date(2021, 8, 14), datetime.date(2022, 8, 14), datetime.date(2023, 8, 14),
            datetime.date(2021, 8, 15), datetime.date(2022, 8, 15), datetime.date(2023, 8, 15),

            #年末年始
            datetime.date(2021, 12, 31), datetime.date(2022, 12, 31), datetime.date(2023, 12, 31),
            datetime.date(2021, 1, 1), datetime.date(2022, 1, 1), datetime.date(2023, 1, 1),
            datetime.date(2021, 1, 2), datetime.date(2022, 1, 2), datetime.date(2023, 1, 2),
            datetime.date(2021, 1, 3), datetime.date(2022, 1, 3), datetime.date(2023, 1, 3),
        ]
        if date in extra_holidays:
            return True
        return False

# この中を変える
class ScoringService(object):

    @classmethod
    def get_model(cls, model_path, inference_df, TRAIN_MODE=False):
        """Get model method

        Args:
            model_path (str): Path to the trained model directory.
            inference_df: Past data not subject to prediction.

        Returns:
            bool: The return value. True for success.
        """
        if inference_df is not None:
            if len(inference_df) > 0:
                last_date = pd.to_datetime(str(inference_df['datetime'].iloc[-1].date())+' 00:00:00')
                cls.data = inference_df[inference_df['datetime']>=last_date]
                cls.data = cls.extract_row(cls.data)
                cls.data['is_inf_df'] = 1
            else:
                cls.data = pd.DataFrame()
        else:
            cls.data = pd.DataFrame()

        cls.cat_cols = ['road_code', 'start_code', 'end_code', 'section', 'direction', 'dayofweek', 'dayofweek_td',\
                            'is_holiday', 'is_holiday_1', 'is_holiday_2', 'is_holiday_3', 'is_holiday_-1', 'is_holiday_-2', 'is_holiday_-3', \
                            'start_pref_code', 'end_pref_code', 'season', 'road_w_direction', 'is_holiday_lag168']# 'holiday_cat_temperature', 
        cls.num_cols = ['OCC','allCars','speed',
                            'start_lat','end_lat','start_lng','end_lng','start_degree','end_degree','KP','start_KP','end_KP','limit_speed',
                            'search_1h','search_unspec_1d',

                            'holiday_temperature','holiday_pre_temperature','max_holiday_temperature','sum_holiday_temperature',
                            'year','month','day','hour',
                            'year_td','month_td','day_td','hour_td',
                            'straight_dist','KP_se_dist','KP_te_dist','KP_st_dist','KP_max_dist','detour_rate',
                            'degree_diss_es','search_1h_4week_mean','search_1h_4week_max','is_holiday_4week_count','allCars_lag144',
                            'OCC_lag144','allCars_lag312','OCC_lag312','allCars_lag480','OCC_lag480','search_1h_lag168',

                            'search_1h_lag24', 'search_1h_lag48','search_1h_lag72','search_1h_lag1','search_1h_4week_mean_lag1','search_1h_4week_max_lag1','search_1h_lag2',
                            'search_1h_4week_mean_lag2','search_1h_4week_max_lag2','search_1h_lag3','search_1h_4week_mean_lag3','search_1h_4week_max_lag3',
                            'search_1h_lag-1','search_1h_4week_mean_lag-1','search_1h_4week_max_lag-1','search_1h_lag-2','search_1h_4week_mean_lag-2',
                            'search_1h_4week_max_lag-2','search_1h_lag-3','search_1h_4week_mean_lag-3','search_1h_4week_max_lag-3','search_1h_lag4',
                            'search_1h_4week_mean_lag4','search_1h_4week_max_lag4','search_1h_lag5','search_1h_4week_mean_lag5','search_1h_4week_max_lag5',
                            'search_1h_lag-4','search_1h_4week_mean_lag-4','search_1h_4week_max_lag-4','search_1h_lag-5','search_1h_4week_mean_lag-5',
                            'search_1h_4week_max_lag-5','search_1h_lag9','search_1h_4week_mean_lag9','search_1h_4week_max_lag9','search_1h_lag10',
                            'search_1h_4week_mean_lag10','search_1h_4week_max_lag10','search_1h_lag-9','search_1h_4week_mean_lag-9','search_1h_4week_max_lag-9',
                            'search_1h_lag-10','search_1h_4week_mean_lag-10','search_1h_4week_max_lag-10','search_unspec_1d_lag24','search_1h_3mean','mean_search_1h',
                            'sum_search_1h','med_search_1h','rate_search_1h',
                        
                            'search_1h_kp1' , 'search_unspec_1d_kp1' , 'search_1h_kp2' , 'search_unspec_1d_kp2' , 'search_1h_kp3' , 'search_unspec_1d_kp3' , 'search_1h_kp-1' , 
                            'search_unspec_1d_kp-1' , 'search_1h_kp-2' , 'search_unspec_1d_kp-2' , 'search_1h_kp-3' , 'search_unspec_1d_kp-3'
                            
                            ]
        cls.feature_cols = cls.cat_cols + cls.num_cols

        cls.TRAIN_MODE = TRAIN_MODE

        cls.N_SPLIT = 8
        if not TRAIN_MODE:
            with open('../src/features/le_dict.pkl', 'rb') as f:
                cls.le = pickle.load(f)
            print(cls.le)
            cls.le_keys = list(cls.le.keys())
            # modelのロード
            cls.models = {}
            for n in range(cls.N_SPLIT):
                cls.models[n] = pickle.load(open(f'{model_path}/lgb_fold{n}.pickle', 'rb'))
        else:
            cls.models = None

        cls.params = {
            'objective': 'binary',
            'verbose': -1,
            'metric': 'binary_logloss',
            'seed': 0,

            'num_leaves': 52, 
            'learning_rate': 0.01, 
            'max_depth': 9,
            'min_data_in_leaf': 10, 
            'feature_fraction': 0.9351779629995216, 
            'bagging_fraction': 0.6384393631575852, 
            'lambda_l1': 0.9764594650133958, 
            'lambda_l2': 0.4686512016477016
        }

        # 一応過去のレコードを貯めることはできる
        return True

    @classmethod
    def expand_datetime(cls, df):
        if 'datetime' in df.columns:
            df['year'] = df['datetime'].dt.year
            df['month'] = df['datetime'].dt.month
            df['day'] = df['datetime'].dt.day
            df['hour'] = df['datetime'].dt.hour
        if 'td' in df.columns:
            df['year_td'] = df['td'].dt.year
            df['month_td'] = df['td'].dt.month
            df['day_td'] = df['td'].dt.day
            df['hour_td'] = df['td'].dt.hour
        if 'date' in df.columns:
            df['year'] = df['date'].dt.year
            df['month'] = df['date'].dt.month
            df['day'] = df['date'].dt.day
        return df

    @classmethod
    def extract_row(cls, df):
        '''
        1行内で完結する特徴量抽出
        inference_dfにもinputにも共通して働く
        流れとしては
            inference_df > {ext_row} > inference_df'
            input > {ext_row} > input'
        で条件を揃える
        '''
        def is_jpholiday(date):
            if jpholiday.is_holiday(date) or 5<=date.weekday():
                return True
            else:
                return False
        # ========================================
        # 時間関連
        # 予測当日の日付
        # ========================================
        df['td'] = df['datetime'] + pd.to_timedelta(1, 'd')

        df['dayofweek'] = df['datetime'].dt.weekday
        df['dayofweek_td'] = df['td'].dt.weekday

        date = df.iloc[0]['td'].date()
        df['is_holiday'] = int(is_jpholiday(date))

        holi_lag = 3# 前後3日分を考慮
        for i in range(holi_lag):# 0,1,2
            lag = i+1# 1,2,3
            df[f'is_holiday_{lag}'] = int(is_jpholiday(date+pd.to_timedelta(lag, 'd')))
            df[f'is_holiday_{-lag}'] = int(is_jpholiday(date+pd.to_timedelta(-lag, 'd')))

        df['holiday_temperature'] = df['is_holiday_1']*4 + df['is_holiday_2']*2 + df['is_holiday_3']*1
        df['holiday_pre_temperature'] = df['is_holiday_-1']*4 + df['is_holiday_-2']*2 + df['is_holiday_-3']*1

        # df['holiday_cat_temperature'] = df['holiday_temperature'].astype(str) + '_' + df['holiday_pre_temperature'].astype(str)

        df['max_holiday_temperature'] = df[['holiday_temperature', 'holiday_pre_temperature']].max(axis=1)
        df['sum_holiday_temperature'] = df[['holiday_temperature', 'holiday_pre_temperature']].sum(axis=1)

        df = cls.expand_datetime(df)
        df['season'] = df['month_td'].apply(lambda x: (x % 12 + 3) // 3)

        # ========================================
        # 道路関連
        # ========================================
        df['section'] = df['start_code'].astype(str)+'_'+df['end_code'].astype(str)
        df['straight_dist'] = np.sqrt( (df['end_lat']-df['start_lat'])**2 + (df['end_lng']-df['start_lng'])**2 ) * 100
        df['KP_se_dist'] = np.abs(df['end_KP']-df['start_KP'])
        df['KP_te_dist'] = np.abs(df['end_KP']-df['KP'])
        df['KP_st_dist'] = np.abs(df['KP']-df['start_KP'])
        df['KP_max_dist'] = np.max(df[['KP_te_dist', 'KP_st_dist']], axis=1) / df['KP_se_dist']
        df['detour_rate'] = df['KP_se_dist']/df['straight_dist']
        df['degree_diss_es'] = df['end_degree'] - df['start_degree']

        df['road_w_direction'] = df['road_code'].astype(str) + '_' + df['direction']

        return df

    @classmethod
    def extract_with_inference(cls, df):
        '''
        df = 推論対象1日分のデータ
        cls.data = 過去データ

        input'' = concat(input', inference_df').reset_index()
        sort(input'', by={'datetime'})
            input''.groupby('section')# section毎の操作, lag変数等
            ~~ # 他のsectionとの操作 
        '''
        replace_col = []
        df['is_inf_df'] = 0

        TODAY = df['datetime'].iloc[-1].date()
        YESTERDAY = pd.to_datetime(str(TODAY - pd.to_timedelta(1, 'd'))+' 00:00:00')
        ONE_WEEK_AGO = pd.to_datetime(str(TODAY - pd.to_timedelta(7, 'd'))+' 00:00:00')
        FOUR_WEEK_AGO = pd.to_datetime(str(TODAY - pd.to_timedelta(7*4, 'd'))+' 00:00:00')
        df_columns = df.columns
        df = pd.concat([cls.data, df]).sort_values('datetime').reset_index()

        # ========================================
        # lag変数 group毎集計 3週間分の追移動平均
        # ========================================
        df = df[df['datetime']>=FOUR_WEEK_AGO]
        # 先週の同じ時間
        df_g = df.groupby(['section', 'dayofweek', 'hour'])

        df = pd.merge(df, df_g.search_1h.mean().reset_index().rename(columns={'search_1h': 'search_1h_4week_mean'}), how='left', on=['section', 'dayofweek', 'hour'])
        replace_col.append('search_1h_4week_mean')
        df = pd.merge(df, df_g.search_1h.max().reset_index().rename(columns={'search_1h': 'search_1h_4week_max'}), how='left', on=['section', 'dayofweek', 'hour'])
        replace_col.append('search_1h_4week_max')

        df = pd.merge(df, df_g.is_holiday.sum().reset_index().rename(columns={'is_holiday': 'is_holiday_4week_count'}), how='left', on=['section', 'dayofweek', 'hour'])
        replace_col.append('is_holiday_4week_count')

        # 3週間分のOCCとallCars
        lags = [24*6, 24*(6+7*1), 24*(6+7*2)]
        df_g = df.groupby('section')
        for lag in lags:
            df[f'allCars_lag{lag}'] = df_g.allCars.shift(lag).reset_index().set_index('index')['allCars']
            df[f'OCC_lag{lag}'] = df_g.OCC.shift(lag).reset_index().set_index('index')['OCC']

        # ========================================
        # lag変数 group毎集計 1週間分の追加データで必要な分
        # ========================================
        df = df[df['datetime']>=ONE_WEEK_AGO]
        # 先週の同じ時間
        df_g = df.groupby('section')
        lags_1h = [7*24,1*24, 2*24, 3*24]# ちょうど一週間前
        for lag in lags_1h:
            df[f'search_1h_lag{lag}'] = df_g.search_1h.shift(lag).reset_index().set_index('index')['search_1h']
            replace_col.append(f'search_1h_lag{lag}')
            if lag > 3*24:# 既に三日分まではある
                df[f'is_holiday_lag{lag}'] = df_g.is_holiday.shift(lag).reset_index().set_index('index')['is_holiday']
                replace_col.append(f'is_holiday_lag{lag}')

        # ========================================
        # lag変数 group毎集計 1日分の追加データで必要な分
        # ========================================
        df = df[df['datetime']>=YESTERDAY]
        df_g = df.groupby('section')
        lags_1h = [1,2,3,-1,-2,-3, 4, 5, -4, -5, 9, 10, -9, -10]# 3時間前から3時間後まで  789  17,18,19
        for lag in lags_1h:
            df[f'search_1h_lag{lag}'] = df_g.search_1h.shift(lag).reset_index().set_index('index')['search_1h']
            replace_col.append(f'search_1h_lag{lag}')

            # 'search_1h_4week_mean'
            df[f'search_1h_4week_mean_lag{lag}'] = df_g.search_1h_4week_mean.shift(lag).reset_index().set_index('index')['search_1h_4week_mean']
            replace_col.append(f'search_1h_4week_mean_lag{lag}')
            df[f'search_1h_4week_max_lag{lag}'] = df_g.search_1h_4week_max.shift(lag).reset_index().set_index('index')['search_1h_4week_max']
            replace_col.append(f'search_1h_4week_max_lag{lag}')

        # 昨日のsearch_unspec
        lag = 24
        df[f'search_unspec_1d_lag{lag}'] = df_g.search_unspec_1d.shift(lag).reset_index().set_index('index')['search_unspec_1d']
        replace_col.append(f'search_unspec_1d_lag{lag}')
        df['search_1h_3mean'] = df_g.search_1h.rolling(3, min_periods=1).mean().reset_index().set_index('level_1')['search_1h']
        replace_col.append('search_1h_3mean')

        # ========================================
        # drop inference_df + 登録
        # ========================================
        df = df[df['is_inf_df']==0]
        df['is_inf_df'] = 1
        df = df.set_index('index').sort_index()
        cls.data = pd.concat([cls.data, df[df_columns]])# df

        # ========================================
        # ルート検索 関連 inference関係なし
        # ========================================
        group_search = df.groupby('section').agg(
            mean_search_1h = ("search_1h", 'mean'),
            sum_search_1h = ("search_1h", 'sum'),
            med_search_1h = ("search_1h", 'median')
            ).reset_index()
        df = pd.merge(df.reset_index(), group_search, on='section', suffixes=('', '_grouped'), how='left').set_index('index')
        df['rate_search_1h'] = df['search_1h'] / df['sum_search_1h']
        replace_col.append('rate_search_1h')

        # ========================================
        # Groupby > {road_code, direction} ::::: Sortby > {datetime, KP}
        # 同時刻のn隣sectionの検索数, inference関係なし << 他のsectionのlag引っ張りたいならあらかじめ作っておくのが良し
        # ========================================
        df_g = df.sort_values('KP').groupby(['road_code', 'direction', 'datetime'])
        lags = [1,2,3,-1,-2,-3]# 3時間前から3時間後まで
        for lag in lags:
            df[f'search_1h_kp{lag}'] = df_g.search_1h.shift(lag).reset_index().set_index('index')['search_1h']
            df[f'search_unspec_1d_kp{lag}'] = df_g.search_unspec_1d.shift(lag).reset_index().set_index('index')['search_unspec_1d']
            replace_col.append(f'search_1h_kp{lag}')
            replace_col.append(f'search_unspec_1d_kp{lag}')

            '''
            for l in lags_1h:
                df[f'search_1h_lag{l}_kp{lag}'] = df_g[f'search_1h_lag{l}'].shift(lag).reset_index().set_index('index')[f'search_1h_lag{l}']
                replace_col.append(f'search_1h_lag{l}_kp{lag}')

                # 'search_1h_4week_mean'
                df[f'search_1h_4week_mean_lag{l}_kp{lag}'] = df_g[f'search_1h_4week_mean_lag{l}'].shift(lag).reset_index().set_index('index')[f'search_1h_4week_mean_lag{l}']
                replace_col.append(f'search_1h_4week_mean_lag{l}_kp{lag}')

                df[f'search_1h_4week_max_lag{l}_kp{lag}'] = df_g[f'search_1h_4week_max_lag{l}'].shift(lag).reset_index().set_index('index')[f'search_1h_4week_max_lag{l}']
                replace_col.append(f'search_1h_4week_max_lag{l}_kp{lag}')'''
        
        df[replace_col] = df[replace_col].replace([np.nan], -1)
        df[replace_col] = df[replace_col].replace([np.inf], 999999)
        df[replace_col] = df[replace_col].replace([-np.inf], -999999)

        return df


    @classmethod
    def extract_dataset(cls, df):
        '''
        input: df
            df = valid[valid['datetime'].dt.date==d]
            1日分のデータフレーム(1d*24h*79section)
            予測日前日のtraffic + 予測日のsearch + road >> 予測

        output: ~~
        '''

        df = cls.extract_row(df)# 1日分
        df = cls.extract_with_inference(df)

        # ========================================
        # カテゴリ変数の処理
        # ========================================
        if not cls.TRAIN_MODE:
            for c in cls.le_keys:
                df[c] = cls.le[c].transform(df[c])

        return df

    @classmethod
    def predict(cls, input):
        """Predict method

        Args:
            input: meta data of the sample you want to make inference from (DataFrame)

        Returns:
            prediction: Inference for the given input. Return columns must be ['datetime', 'start_code', 'end_code'](DataFrame).
        
        Tips:
            You can use past data by writing "cls.data".
        """
        
        prediction = input.copy()

        # ======================== ここから特徴量作成 ========================

        prediction = cls.extract_dataset(prediction)

        # ======================== ここから予測 =============================

        prediction['prediction'] = 0
        for n in range(cls.N_SPLIT):
            prediction['prediction'] += cls.models[n].predict(prediction[cls.feature_cols]) / cls.N_SPLIT
        prediction['prediction'] = prediction['prediction'].round()
        prediction['prediction'] = prediction['prediction'].astype(int)
        prediction['start_code'] = input["start_code"]
        prediction['end_code'] = input["end_code"]
        prediction['datetime'] = input["datetime"]
        prediction = prediction[['datetime', 'start_code', 'end_code', 'prediction']]

        '''if prediction['datetime'].iloc[0]==pd.to_datetime('2022-07-01 00:00:00'):
            raise ValueError("test. ", prediction.tail(5))'''

        return prediction

# %% [markdown]
# # -----

# %%
# 不変
def make_dataset(traffic, ic_master, search_spec, search_unspec):
    # 欠損値の除外
    traffic = traffic[traffic['speed'].isnull()==False]
    ic_master.dropna(inplace=True)
    search_spec.dropna(inplace=True)
    search_unspec.dropna(inplace=True)
    
    # datetimeからdateを作成
    traffic['date'] = traffic['datetime'].apply(lambda x: x.split()[0])

    # データのマージ
    traffic = traffic.merge(ic_master, on=['start_code', 'end_code'], how='left')
    traffic = traffic.merge(search_spec, on=['datetime', 'start_code', 'end_code'], how='left')
    traffic = traffic.merge(search_unspec, on=['date', 'start_code', 'end_code'], how='left')
    traffic.sort_values(['date', 'start_code', 'end_code'], inplace=True)
    traffic.reset_index(drop=True, inplace=True)
    traffic.drop(columns='date', inplace=True)

    # データ型の変更
    traffic['datetime'] = pd.to_datetime(traffic['datetime'])

    return traffic


def parse_args():
    parser = argparse.ArgumentParser()
    parser.add_argument('--exec-path', help = '/path/to/submit/src')
    parser.add_argument('--data-dir', help = '/path/to/train')
    parser.add_argument('--start-date', default = '2021-04-08', type = str, help='start date')
    parser.add_argument('--end-date', default = '2022-07-31', type = str, help='end date')
    args = parser.parse_args()

    return args

def train():

    # ========================================
    # training module
    # ========================================
    def f1(y_true, y_pred):
        y_pred = (y_pred > 0.5).astype(int)
        score = f1_score(y_true, y_pred)
        return 'f1', score, True

    def lgb_f1_score(y_hat, data):
        y_true = data.get_label()
        y_hat = np.where(y_hat < 0.5, 0, 1)   # scikits f1 doesn't like probabilities
        return 'f1', f1_score(y_true, y_hat), True

    def train_lgbm(X,
                y,
                cv,
                model_path = [],
                params: dict=None,
                verbose: int=100,
                weight_dict: dict=None,
                cat_cols: list=[]
                ):

        # パラメータがないときは、空の dict で置き換える
        if params is None:
            params = {}

        models = []

        n_records = len(X)
        # training data の target と同じだけのゼロ配列を用意
        oof_pred = np.zeros((n_records, ), dtype=np.float32)
        
        for i, (idx_train, idx_valid) in enumerate(cv):
            x_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
            x_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

            print(f'train shape = {x_train.shape}')
            print(f'valid shape = {x_valid.shape}')

            print('Train:', y_train.value_counts(normalize=True))
            print('Valid:', y_valid.value_counts(normalize=True))
            
            if weight_dict is None:
                print('Don\'t use sample weight.')
                lgb_train = lgb.Dataset(x_train, y_train)
            elif weight_dict[0] == 'balance':
                print('Using sample weight. {Balance}')
                lgb_train = lgb.Dataset(x_train, y_train, weight=compute_sample_weight(class_weight='balanced', y=y_train).astype('float32'))
            else:
                print('Using sample weight.')
                print(weight_dict)
                lgb_train = lgb.Dataset(x_train, y_train, weight=compute_sample_weight(class_weight=weight_dict, y=y_train).astype('float32'))
                
            lgb_eval = lgb.Dataset(x_valid, y_valid, reference=lgb_train)
            
            clf = lgb.train(params, lgb_train, 
                            valid_sets=[lgb_train, lgb_eval],
                            valid_names=['Train', 'Valid'],
                            feval=lgb_f1_score,
                            num_boost_round=100000,
                            verbose_eval=100,
                            categorical_feature=cat_cols,
                            callbacks = [lgb.early_stopping(stopping_rounds=500, verbose=True)]
                            )# categorical_feature=categories, verbose_eval=10
            
            pred_i = clf.predict(x_valid)
            oof_pred[idx_valid] = pred_i
            models.append(clf)
            score = f1_score(y_valid, (pred_i > 0.5).astype(int))
            print(f" - fold{i + 1} - {score:.4f} \n")
            
        score = f1_score(y, (oof_pred > 0.5).astype(int))

        print("=" * 50)
        print(f"FINISH: CV Score: {score:.4f}")
        return score, oof_pred, models

    # parse the arguments
    """
    args = parse_args()
    exec_path = os.path.abspath(args.exec_path)
    data_dir = os.path.abspath(args.data_dir)
    start_date = args.start_date
    end_date = args.end_date

    # !python run.py  --exec-path ./sample_submit_8/src/ --data-dir ./train/
    """
    exec_path = '/content/drive/MyDrive/NEXCO/src/run_test/sample_submit_8/src'
    data_dir = '/content/drive/MyDrive/NEXCO/src/run_test/train/'
    start_date = '2021-04-08'
    end_date = '2022-07-31'

    print('\nstart date: {}, end date:{}'.format(start_date, end_date))

    # load the input data
    print('\nLoading Dataset...')
    traffic = pd.read_csv(os.path.join(data_dir, 'train.csv'))
    search_spec = pd.read_csv(os.path.join(data_dir, 'search_data.csv'))
    search_unspec = pd.read_csv(os.path.join(data_dir, 'search_unspec_data.csv'))
    ic_master = pd.read_csv(os.path.join(data_dir, 'road.csv'))

    # 当日の検索数を使用できるように変更(search_spec, search_unspec)
    search_spec['datetime'] = pd.to_datetime(search_spec['datetime'])
    search_unspec['date'] = pd.to_datetime(search_unspec['date'])
    search_spec['datetime'] -= pd.to_timedelta(1, 'd')
    search_unspec['date'] -= pd.to_timedelta(1, 'd')
    search_spec['datetime'] = search_spec['datetime'].astype('str')
    search_unspec['date'] = search_unspec['date'].astype('str')

    df = make_dataset(traffic, ic_master, search_spec, search_unspec)
    inference_df = df[df['datetime']<start_date+' 00:00:00']
    train = df[(df['datetime']>=start_date+' 00:00:00') & (df['datetime']<=end_date+' 23:00:00')]
    print('Done')

    # change the working directory
    model_path = './sample_submit_8/model/'
    ScoringService.get_model(model_path, inference_df, TRAIN_MODE=True)

    # prepare training data
    train_all = pd.DataFrame()
    for d in tqdm(train['datetime'].dt.date.unique()):
        input = train[train['datetime'].dt.date==d]
        input = ScoringService.extract_dataset(input)
        train_all = pd.concat([train_all, input])

    le_dict = {}# only training
    for c in ScoringService.cat_cols:
        if train_all[c].dtype=='object':
            le = LabelEncoder()# only training
            print(c)
            print(train_all[c].value_counts())
            le.fit(train_all[c])# only training
            train_all[c] = le.transform(train_all[c])
            le_dict[c] = le# only training

    with open("./sample_submit_8/src/features/le_dict.pkl", "wb") as f:# only training
        pickle.dump(le_dict, f)# only training

    # training
    train_all.sort_values(['section', 'datetime'])
    train_all['is_congestion'] = train_all.groupby('section').shift(-24).reset_index()['is_congestion']
    train_all = train_all[~train_all['is_congestion'].isnull()].reset_index(drop=True)

    # ========================================
    # train-validation split
    # ========================================
    TARGET = 'is_congestion'
    N_SPLIT = ScoringService.N_SPLIT
    kf = StratifiedGroupKFold(N_SPLIT, shuffle=True)
    cv_list = list(kf.split(train_all, y=train_all[TARGET], groups=train_all['datetime'].dt.date))

    X = train_all[ScoringService.feature_cols]
    y = train_all[TARGET]
    print('train all shape:', X.shape)
    print('train columns: \n', X.columns)

    weight = {0:1.0, 1:5.0}
    score, oof_pred, models = train_lgbm(X, y=y, params=ScoringService.params, cv=cv_list, weight_dict=weight, cat_cols=ScoringService.cat_cols)# 0.5814 <> shuffle 5810

    for i, m in enumerate(models):
        with open(f'./sample_submit_8/model/lgb_fold{i}.pickle', mode="wb") as f:
            pickle.dump(m, f)

    # ========================================
    # feature importance
    # ========================================
    def visualize_importance(models, feat_train_df):
        feature_importance_df = pd.DataFrame()
        for i, model in enumerate(models):
            _df = pd.DataFrame()
            importance_type = 'split'
            _df["feature_importance"] = model.feature_importance(importance_type=importance_type)
            _df["column"] = feat_train_df.columns
            _df["fold"] = i + 1
            feature_importance_df = pd.concat([feature_importance_df, _df],
                                            axis=0, ignore_index=True)

        order = feature_importance_df.groupby("column")\
            .sum()[["feature_importance"]]\
            .sort_values("feature_importance", ascending=False).index

        fig, ax = plt.subplots(figsize=(12, max(6, len(order) * .25)))
        sns.boxplot(data=feature_importance_df,
                    x="feature_importance",
                    y="column",
                    order=order,
                    ax=ax,
                    palette="viridis",
                    orient="h")
        ax.tick_params(axis="x", rotation=90)
        ax.set_title("Importance")
        ax.grid()
        fig.tight_layout()
        return fig, ax, feature_importance_df

    fig, ax, feature_importance_df = visualize_importance(models, X)

def main():

    # parse the arguments
    """
    args = parse_args()
    exec_path = os.path.abspath(args.exec_path)
    data_dir = os.path.abspath(args.data_dir)
    start_date = args.start_date
    end_date = args.end_date

    # !python run.py  --exec-path ./sample_submit/src/ --data-dir ./train/
    """
    exec_path = '/content/drive/MyDrive/NEXCO/src/run_test/sample_submit_8/src'
    data_dir = '/content/drive/MyDrive/NEXCO/src/run_test/train/'
    start_date = '2021-04-08'
    end_date = '2022-07-31'

    print('\nstart date: {}, end date:{}'.format(start_date, end_date))

    # load the input data
    print('\nLoading Dataset...')
    traffic = pd.read_csv(os.path.join(data_dir, 'train.csv'))
    search_spec = pd.read_csv(os.path.join(data_dir, 'search_data.csv'))
    search_unspec = pd.read_csv(os.path.join(data_dir, 'search_unspec_data.csv'))
    ic_master = pd.read_csv(os.path.join(data_dir, 'road.csv'))

    # 当日の検索数を使用できるように変更(search_spec, search_unspec)
    search_spec['datetime'] = pd.to_datetime(search_spec['datetime'])
    search_unspec['date'] = pd.to_datetime(search_unspec['date'])
    search_spec['datetime'] -= pd.to_timedelta(1, 'd')
    search_unspec['date'] -= pd.to_timedelta(1, 'd')
    search_spec['datetime'] = search_spec['datetime'].astype('str')
    search_unspec['date'] = search_unspec['date'].astype('str')

    df = make_dataset(traffic, ic_master, search_spec, search_unspec)
    train = df[df['datetime']<start_date+' 00:00:00']
    valid = df[(df['datetime']>=start_date+' 00:00:00') & (df['datetime']<=end_date+' 23:00:00')]
    print('Done')

    # change the working directory
    os.chdir(exec_path)
    cwd = os.getcwd()
    print('\nMoved to {}'.format(cwd))
    model_path = os.path.join('..', 'model')
    print('Model papth = {}'.format(model_path))
    sys.path.append(cwd)

    # load the model
    # from predictor import ScoringService

    print('\nLoading the model...', end = '\r')
    model_flag = ScoringService.get_model(model_path, train)
    if model_flag:
        print('Loaded the model.')
    else:
        print('Could not load the model.')
        return None

    predictions = pd.DataFrame()
    for d in tqdm(valid['datetime'].dt.date.unique()):
        input = valid[valid['datetime'].dt.date==d]
        prediction = ScoringService.predict(input)
        if type(prediction)!= pd.DataFrame:
            print('Invalid data type in the prediction. Must be pandas.DataFrame')
            return None 
        elif set(prediction.columns) != set(['datetime', 'start_code', 'end_code', 'prediction']):
            print('Invalid columns name: {},  Excepted name: {}'.format(prediction.columns, {'datetime', 'start_code', 'end_code', 'prediction'}))
            return None
        predictions = pd.concat([predictions, prediction])

    results = valid[['datetime', 'start_code', 'end_code']]
    results = pd.merge(results, predictions, on=['datetime', 'start_code', 'end_code'], how='left')
    results['datetime'] = pd.to_datetime(results['datetime'])
    results['datetime'] += pd.to_timedelta(1, 'd')
    results = pd.merge(results, df[['datetime', 'start_code', 'end_code', 'is_congestion']], on=['datetime', 'start_code', 'end_code'], how='inner')

    #compute F1SCORE
    print('\n==================')
    print('f1_score:', round(f1_score(results['is_congestion'], results['prediction']), 4))
    print('==================')

# %% [markdown]
#  # train & main

# %%
train()
# Out:
# start date: 2021-04-08, end date:2022-07-31
#
# Loading Dataset...
# Done
# 100%|██████████| 480/480 [15:16<00:00,  1.91s/it]
# section
# 1110210_1800006    11520
# 1800086_1800081    11520
# 1800106_1800111    11520
# 1800106_1800096    11520
# 1800096_1800106    11520
# 1800096_1800091    11520
# 1800091_1800096    11520
# 1800091_1800086    11520
# 1800086_1800091    11520
# 1800081_1800086    11520
# 1800111_1800116    11520
# 1800081_1800076    11520
# 1800076_1800081    11520
# 1800076_1800073    11520
# 1800073_1800076    11520
# 1800073_1800072    11520
# 1800072_1800071    11520
# 1800071_1800072    11520
# 1800111_1800106    11520
# 1800116_1800111    11520
# 1800066_1800071    11520
# 1800156_1800151    11520
# 1800176_1800183    11520
# 1800176_1800171    11520
# 1800171_1800176    11520
# 1800171_1800161    11520
# 1800161_1800171    11520
# 1800161_1800156    11520
# 1800156_1800161    11520
# 1800151_1800156    11520
# 1800116_1800121    11520
# 1800146_1800141    11520
# 1800141_1800146    11520
# 1800141_1800131    11520
# 1800131_1800141    11520
# 1800131_1800121    11520
# 1800121_1800131    11520
# 1800121_1800116    11520
# 1800071_1800066    11520
# 1800066_1800061    11520
# 1130001_1130006    11520
# 1130031_1130026    11520
# 1800006_1110210    11520
# 1130046_1130041    11520
# 1130041_1130046    11520
# 1130041_1130039    11520
# 1130039_1130041    11520
# 1130036_1130031    11520
# 1130031_1130036    11520
# 1130026_1130031    11520
# 1800011_1800006    11520
# 1130026_1130021    11520
# 1130021_1130026    11520
# 1130021_1130016    11520
# 1130016_1130021    11520
# 1130016_1130006    11520
# 1130006_1130016    11520
# 1130006_1130001    11520
# 1800006_1800011    11520
# 1800011_1800016    11520
# 1800061_1800066    11520
# 1800036_1800041    11520
# 1800061_1800056    11520
# 1800056_1800061    11520
# 1800056_1800051    11520
# 1800051_1800056    11520
# 1800051_1800041    11520
# 1800041_1800051    11520
# 1800041_1800036    11520
# 1800036_1800028    11520
# 1800016_1800011    11520
# 1800028_1800036    11520
# 1800028_1800026    11520
# 1800026_1800028    11520
# 1800026_1800021    11520
# 1800021_1800026    11520
# 1800021_1800016    11520
# 1800016_1800021    11520
# 1800183_1800176    11520
# Name: section, dtype: int64
# direction
# 上り    460800
# 下り    449280
# Name: direction, dtype: int64
# road_w_direction
# 1800_上り    368640
# 1800_下り    357120
# 1130_下り     92160
# 1130_上り     92160
# Name: road_w_direction, dtype: int64
# train all shape: (908184, 126)
# train columns:
#  Index(['road_code', 'start_code', 'end_code', 'section', 'direction',
#        'dayofweek', 'dayofweek_td', 'is_holiday', 'is_holiday_1',
#        'is_holiday_2',
#        ...
#        'search_1h_kp2', 'search_unspec_1d_kp2', 'search_1h_kp3',
#        'search_unspec_1d_kp3', 'search_1h_kp-1', 'search_unspec_1d_kp-1',
#        'search_1h_kp-2', 'search_unspec_1d_kp-2', 'search_1h_kp-3',
#        'search_unspec_1d_kp-3'],
#       dtype='object', length=126)
# train shape = (794424, 126)
# valid shape = (113760, 126)
# Train: 0.0    0.99564
# 1.0    0.00436
# Name: is_congestion, dtype: float64
# Valid: 0.0    0.994858
# 1.0    0.005142
# Name: is_congestion, dtype: float64
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 500 rounds
# [100]	Train's binary_logloss: 0.0373187	Train's f1: 0.60087	Valid's binary_logloss: 0.022634	Valid's f1: 0.45988
# [200]	Train's binary_logloss: 0.0260036	Train's f1: 0.698813	Valid's binary_logloss: 0.0186622	Valid's f1: 0.565826
# [300]	Train's binary_logloss: 0.0208473	Train's f1: 0.70922	Valid's binary_logloss: 0.0171697	Valid's f1: 0.584133
# [400]	Train's binary_logloss: 0.0179519	Train's f1: 0.729565	Valid's binary_logloss: 0.0163693	Valid's f1: 0.581138
# [500]	Train's binary_logloss: 0.0160023	Train's f1: 0.748122	Valid's binary_logloss: 0.0159699	Valid's f1: 0.581633
# [600]	Train's binary_logloss: 0.0143493	Train's f1: 0.768964	Valid's binary_logloss: 0.01565	Valid's f1: 0.580479
# [700]	Train's binary_logloss: 0.0130079	Train's f1: 0.7914	Valid's binary_logloss: 0.0154132	Valid's f1: 0.579585
# [800]	Train's binary_logloss: 0.0119184	Train's f1: 0.810543	Valid's binary_logloss: 0.0151893	Valid's f1: 0.574672
# [900]	Train's binary_logloss: 0.0109342	Train's f1: 0.830543	Valid's binary_logloss: 0.0150286	Valid's f1: 0.576991
# [1000]	Train's binary_logloss: 0.0100644	Train's f1: 0.848786	Valid's binary_logloss: 0.0148728	Valid's f1: 0.574506
# Early stopping, best iteration is:
# [538]	Train's binary_logloss: 0.0153736	Train's f1: 0.756597	Valid's binary_logloss: 0.0158403	Valid's f1: 0.585824
#  - fold1 - 0.5858
#
# train shape = (794424, 126)
# valid shape = (113760, 126)
# Train: 0.0    0.995643
# 1.0    0.004357
# Name: is_congestion, dtype: float64
# Valid: 0.0    0.994831
# 1.0    0.005169
# Name: is_congestion, dtype: float64
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 500 rounds
# [100]	Train's binary_logloss: 0.0377616	Train's f1: 0.61745	Valid's binary_logloss: 0.0233507	Valid's f1: 0.474359
# [200]	Train's binary_logloss: 0.0263425	Train's f1: 0.695626	Valid's binary_logloss: 0.0194667	Valid's f1: 0.534031
# [300]	Train's binary_logloss: 0.0210771	Train's f1: 0.7107	Valid's binary_logloss: 0.0181525	Valid's f1: 0.542205
# [400]	Train's binary_logloss: 0.0181213	Train's f1: 0.724515	Valid's binary_logloss: 0.0177833	Valid's f1: 0.548604
# [500]	Train's binary_logloss: 0.0161954	Train's f1: 0.745524	Valid's binary_logloss: 0.0177309	Valid's f1: 0.555024
# [600]	Train's binary_logloss: 0.0147145	Train's f1: 0.765206	Valid's binary_logloss: 0.0177351	Valid's f1: 0.559078
# [700]	Train's binary_logloss: 0.0132866	Train's f1: 0.785072	Valid's binary_logloss: 0.0177091	Valid's f1: 0.556202
# [800]	Train's binary_logloss: 0.0121083	Train's f1: 0.808379	Valid's binary_logloss: 0.01765	Valid's f1: 0.553606
# [900]	Train's binary_logloss: 0.0111227	Train's f1: 0.829091	Valid's binary_logloss: 0.0175984	Valid's f1: 0.554028
# [1000]	Train's binary_logloss: 0.0102747	Train's f1: 0.849371	Valid's binary_logloss: 0.017521	Valid's f1: 0.553106
# Early stopping, best iteration is:
# [590]	Train's binary_logloss: 0.0148713	Train's f1: 0.761661	Valid's binary_logloss: 0.0177378	Valid's f1: 0.560999
#  - fold2 - 0.5610
#
# train shape = (794424, 126)
# valid shape = (113760, 126)
# Train: 0.0    0.995529
# 1.0    0.004471
# Name: is_congestion, dtype: float64
# Valid: 0.0    0.995631
# 1.0    0.004369
# Name: is_congestion, dtype: float64
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 500 rounds
# [100]	Train's binary_logloss: 0.0387855	Train's f1: 0.597243	Valid's binary_logloss: 0.020276	Valid's f1: 0.54964
# [200]	Train's binary_logloss: 0.0273248	Train's f1: 0.697032	Valid's binary_logloss: 0.0159223	Valid's f1: 0.615716
# [300]	Train's binary_logloss: 0.0219371	Train's f1: 0.706473	Valid's binary_logloss: 0.0139728	Valid's f1: 0.611718
# [400]	Train's binary_logloss: 0.0189039	Train's f1: 0.723618	Valid's binary_logloss: 0.0129773	Valid's f1: 0.615534
# [500]	Train's binary_logloss: 0.0168165	Train's f1: 0.745016	Valid's binary_logloss: 0.0123536	Valid's f1: 0.618395
# [600]	Train's binary_logloss: 0.0152007	Train's f1: 0.767363	Valid's binary_logloss: 0.0119134	Valid's f1: 0.618577
# [700]	Train's binary_logloss: 0.013827	Train's f1: 0.788854	Valid's binary_logloss: 0.0115892	Valid's f1: 0.618762
# [800]	Train's binary_logloss: 0.0126648	Train's f1: 0.808544	Valid's binary_logloss: 0.0113142	Valid's f1: 0.621106
# [900]	Train's binary_logloss: 0.0116655	Train's f1: 0.825151	Valid's binary_logloss: 0.0110808	Valid's f1: 0.619919
# [1000]	Train's binary_logloss: 0.0107711	Train's f1: 0.842812	Valid's binary_logloss: 0.0108806	Valid's f1: 0.619487
# [1100]	Train's binary_logloss: 0.00999682	Train's f1: 0.860382	Valid's binary_logloss: 0.010718	Valid's f1: 0.623701
# [1200]	Train's binary_logloss: 0.00926146	Train's f1: 0.875049	Valid's binary_logloss: 0.0105619	Valid's f1: 0.621707
# [1300]	Train's binary_logloss: 0.00857133	Train's f1: 0.890329	Valid's binary_logloss: 0.010399	Valid's f1: 0.621421
# [1400]	Train's binary_logloss: 0.00800784	Train's f1: 0.902216	Valid's binary_logloss: 0.0102978	Valid's f1: 0.627409
# [1500]	Train's binary_logloss: 0.00749944	Train's f1: 0.912257	Valid's binary_logloss: 0.010198	Valid's f1: 0.632609
# [1600]	Train's binary_logloss: 0.00700421	Train's f1: 0.922626	Valid's binary_logloss: 0.0101092	Valid's f1: 0.631463
# [1700]	Train's binary_logloss: 0.00655763	Train's f1: 0.931371	Valid's binary_logloss: 0.0100243	Valid's f1: 0.632517
# [1800]	Train's binary_logloss: 0.00612917	Train's f1: 0.938858	Valid's binary_logloss: 0.00994815	Valid's f1: 0.63311
# [1900]	Train's binary_logloss: 0.00574235	Train's f1: 0.944086	Valid's binary_logloss: 0.00989713	Valid's f1: 0.635955
# [2000]	Train's binary_logloss: 0.00538963	Train's f1: 0.951147	Valid's binary_logloss: 0.00985608	Valid's f1: 0.63667
# [2100]	Train's binary_logloss: 0.00506287	Train's f1: 0.957605	Valid's binary_logloss: 0.00982058	Valid's f1: 0.636467
# [2200]	Train's binary_logloss: 0.00475966	Train's f1: 0.963557	Valid's binary_logloss: 0.00979634	Valid's f1: 0.630137
# [2300]	Train's binary_logloss: 0.00447636	Train's f1: 0.968323	Valid's binary_logloss: 0.00978196	Valid's f1: 0.629758
# [2400]	Train's binary_logloss: 0.00422954	Train's f1: 0.972329	Valid's binary_logloss: 0.00976166	Valid's f1: 0.628505
# [2500]	Train's binary_logloss: 0.0039889	Train's f1: 0.977019	Valid's binary_logloss: 0.00974285	Valid's f1: 0.629586
# Early stopping, best iteration is:
# [2087]	Train's binary_logloss: 0.00510492	Train's f1: 0.956687	Valid's binary_logloss: 0.00983353	Valid's f1: 0.638826
#  - fold3 - 0.6388
#
# train shape = (794424, 126)
# valid shape = (113760, 126)
# Train: 0.0    0.995533
# 1.0    0.004467
# Name: is_congestion, dtype: float64
# Valid: 0.0    0.995605
# 1.0    0.004395
# Name: is_congestion, dtype: float64
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 500 rounds
# [100]	Train's binary_logloss: 0.0388826	Train's f1: 0.592479	Valid's binary_logloss: 0.0198736	Valid's f1: 0.624495
# [200]	Train's binary_logloss: 0.0273265	Train's f1: 0.684538	Valid's binary_logloss: 0.0153199	Valid's f1: 0.636058
# [300]	Train's binary_logloss: 0.0220815	Train's f1: 0.69822	Valid's binary_logloss: 0.0136395	Valid's f1: 0.635887
# [400]	Train's binary_logloss: 0.0191501	Train's f1: 0.716618	Valid's binary_logloss: 0.0129282	Valid's f1: 0.633401
# [500]	Train's binary_logloss: 0.0171241	Train's f1: 0.739443	Valid's binary_logloss: 0.0124954	Valid's f1: 0.634441
# [600]	Train's binary_logloss: 0.0154844	Train's f1: 0.761471	Valid's binary_logloss: 0.0121513	Valid's f1: 0.636364
# Early stopping, best iteration is:
# [157]	Train's binary_logloss: 0.0310577	Train's f1: 0.679489	Valid's binary_logloss: 0.0167516	Valid's f1: 0.649351
#  - fold4 - 0.6494
#
# train shape = (794424, 126)
# valid shape = (113760, 126)
# Train: 0.0    0.995485
# 1.0    0.004515
# Name: is_congestion, dtype: float64
# Valid: 0.0    0.995939
# 1.0    0.004061
# Name: is_congestion, dtype: float64
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 500 rounds
# [100]	Train's binary_logloss: 0.0393168	Train's f1: 0.591821	Valid's binary_logloss: 0.0190508	Valid's f1: 0.573939
# [200]	Train's binary_logloss: 0.0279017	Train's f1: 0.695817	Valid's binary_logloss: 0.01475	Valid's f1: 0.617143
# [300]	Train's binary_logloss: 0.0225193	Train's f1: 0.702257	Valid's binary_logloss: 0.0130792	Valid's f1: 0.607864
# [400]	Train's binary_logloss: 0.0194055	Train's f1: 0.716842	Valid's binary_logloss: 0.0122166	Valid's f1: 0.608787
# [500]	Train's binary_logloss: 0.017217	Train's f1: 0.740895	Valid's binary_logloss: 0.0116828	Valid's f1: 0.61651
# [600]	Train's binary_logloss: 0.0155596	Train's f1: 0.759694	Valid's binary_logloss: 0.0112637	Valid's f1: 0.616684
# Early stopping, best iteration is:
# [130]	Train's binary_logloss: 0.0346717	Train's f1: 0.664085	Valid's binary_logloss: 0.0172657	Valid's f1: 0.641604
#  - fold5 - 0.6416
#
# train shape = (794424, 126)
# valid shape = (113760, 126)
# Train: 0.0    0.995539
# 1.0    0.004461
# Name: is_congestion, dtype: float64
# Valid: 0.0    0.995561
# 1.0    0.004439
# Name: is_congestion, dtype: float64
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 500 rounds
# [100]	Train's binary_logloss: 0.0386741	Train's f1: 0.608366	Valid's binary_logloss: 0.0199523	Valid's f1: 0.593792
# [200]	Train's binary_logloss: 0.0270244	Train's f1: 0.690968	Valid's binary_logloss: 0.0157343	Valid's f1: 0.617676
# [300]	Train's binary_logloss: 0.0217181	Train's f1: 0.706391	Valid's binary_logloss: 0.0140109	Valid's f1: 0.613485
# [400]	Train's binary_logloss: 0.0186658	Train's f1: 0.721135	Valid's binary_logloss: 0.0132916	Valid's f1: 0.618557
# [500]	Train's binary_logloss: 0.0167024	Train's f1: 0.740363	Valid's binary_logloss: 0.012925	Valid's f1: 0.620038
# [600]	Train's binary_logloss: 0.0150503	Train's f1: 0.761731	Valid's binary_logloss: 0.0126543	Valid's f1: 0.618911
# [700]	Train's binary_logloss: 0.0135693	Train's f1: 0.786941	Valid's binary_logloss: 0.0123967	Valid's f1: 0.621963
# [800]	Train's binary_logloss: 0.0123256	Train's f1: 0.807752	Valid's binary_logloss: 0.012195	Valid's f1: 0.618537
# [900]	Train's binary_logloss: 0.0113641	Train's f1: 0.826576	Valid's binary_logloss: 0.0120653	Valid's f1: 0.623762
# [1000]	Train's binary_logloss: 0.0104303	Train's f1: 0.843361	Valid's binary_logloss: 0.0119259	Valid's f1: 0.623506
# [1100]	Train's binary_logloss: 0.00966991	Train's f1: 0.861199	Valid's binary_logloss: 0.0118358	Valid's f1: 0.624874
# [1200]	Train's binary_logloss: 0.00896234	Train's f1: 0.877368	Valid's binary_logloss: 0.0117176	Valid's f1: 0.620266
# [1300]	Train's binary_logloss: 0.00832191	Train's f1: 0.893437	Valid's binary_logloss: 0.0116319	Valid's f1: 0.62268
# [1400]	Train's binary_logloss: 0.007781	Train's f1: 0.904951	Valid's binary_logloss: 0.0115508	Valid's f1: 0.621481
# [1500]	Train's binary_logloss: 0.00725387	Train's f1: 0.9167	Valid's binary_logloss: 0.0114817	Valid's f1: 0.629591
# [1600]	Train's binary_logloss: 0.00678171	Train's f1: 0.925827	Valid's binary_logloss: 0.0114211	Valid's f1: 0.632696
# [1700]	Train's binary_logloss: 0.00634221	Train's f1: 0.932799	Valid's binary_logloss: 0.0113761	Valid's f1: 0.633833
# [1800]	Train's binary_logloss: 0.00593159	Train's f1: 0.940513	Valid's binary_logloss: 0.0113504	Valid's f1: 0.637149
# [1900]	Train's binary_logloss: 0.005547	Train's f1: 0.947383	Valid's binary_logloss: 0.0113468	Valid's f1: 0.643881
# [2000]	Train's binary_logloss: 0.00520452	Train's f1: 0.954201	Valid's binary_logloss: 0.01133	Valid's f1: 0.644518
# [2100]	Train's binary_logloss: 0.00489446	Train's f1: 0.95975	Valid's binary_logloss: 0.0113444	Valid's f1: 0.642937
# [2200]	Train's binary_logloss: 0.00459808	Train's f1: 0.964529	Valid's binary_logloss: 0.0113632	Valid's f1: 0.639821
# [2300]	Train's binary_logloss: 0.00434188	Train's f1: 0.96866	Valid's binary_logloss: 0.0113846	Valid's f1: 0.640361
# [2400]	Train's binary_logloss: 0.00409644	Train's f1: 0.973196	Valid's binary_logloss: 0.0114052	Valid's f1: 0.640997
# Early stopping, best iteration is:
# [1979]	Train's binary_logloss: 0.00527817	Train's f1: 0.953013	Valid's binary_logloss: 0.0113325	Valid's f1: 0.64823
#  - fold6 - 0.6482
#
# train shape = (794424, 126)
# valid shape = (113760, 126)
# Train: 0.0    0.995443
# 1.0    0.004557
# Name: is_congestion, dtype: float64
# Valid: 0.0    0.996229
# 1.0    0.003771
# Name: is_congestion, dtype: float64
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 500 rounds
# [100]	Train's binary_logloss: 0.0390168	Train's f1: 0.622642	Valid's binary_logloss: 0.0198451	Valid's f1: 0.382189
# [200]	Train's binary_logloss: 0.0271949	Train's f1: 0.701016	Valid's binary_logloss: 0.0154509	Valid's f1: 0.509299
# [300]	Train's binary_logloss: 0.0217211	Train's f1: 0.719423	Valid's binary_logloss: 0.013714	Valid's f1: 0.525907
# [400]	Train's binary_logloss: 0.018827	Train's f1: 0.732836	Valid's binary_logloss: 0.0130152	Valid's f1: 0.540273
# [500]	Train's binary_logloss: 0.0167194	Train's f1: 0.752429	Valid's binary_logloss: 0.0125588	Valid's f1: 0.537313
# [600]	Train's binary_logloss: 0.0152112	Train's f1: 0.772346	Valid's binary_logloss: 0.0122364	Valid's f1: 0.53913
# [700]	Train's binary_logloss: 0.0137787	Train's f1: 0.794644	Valid's binary_logloss: 0.0119389	Valid's f1: 0.538847
# [800]	Train's binary_logloss: 0.0125627	Train's f1: 0.81192	Valid's binary_logloss: 0.0116871	Valid's f1: 0.539642
# [900]	Train's binary_logloss: 0.0115357	Train's f1: 0.832386	Valid's binary_logloss: 0.0114666	Valid's f1: 0.542373
# Early stopping, best iteration is:
# [466]	Train's binary_logloss: 0.017356	Train's f1: 0.743124	Valid's binary_logloss: 0.0126861	Valid's f1: 0.547708
#  - fold7 - 0.5477
#
# train shape = (796320, 126)
# valid shape = (111864, 126)
# Train: 0.0    0.995522
# 1.0    0.004478
# Name: is_congestion, dtype: float64
# Valid: 0.0    0.995682
# 1.0    0.004318
# Name: is_congestion, dtype: float64
# Using sample weight.
# {0: 1.0, 1: 5.0}
# Training until validation scores don't improve for 500 rounds
# [100]	Train's binary_logloss: 0.038347	Train's f1: 0.608894	Valid's binary_logloss: 0.0215286	Valid's f1: 0.43038
# [200]	Train's binary_logloss: 0.0268481	Train's f1: 0.698757	Valid's binary_logloss: 0.0174095	Valid's f1: 0.557191
# [300]	Train's binary_logloss: 0.0213848	Train's f1: 0.716894	Valid's binary_logloss: 0.0157253	Valid's f1: 0.546956
# [400]	Train's binary_logloss: 0.0184193	Train's f1: 0.733737	Valid's binary_logloss: 0.0148692	Valid's f1: 0.546939
# [500]	Train's binary_logloss: 0.0162327	Train's f1: 0.750391	Valid's binary_logloss: 0.0143487	Valid's f1: 0.548454
# [600]	Train's binary_logloss: 0.0145622	Train's f1: 0.770833	Valid's binary_logloss: 0.0139327	Valid's f1: 0.548287
# Early stopping, best iteration is:
# [191]	Train's binary_logloss: 0.0275243	Train's f1: 0.700205	Valid's binary_logloss: 0.0176517	Valid's f1: 0.562212
#  - fold8 - 0.5622
#
# ==================================================
# FINISH: CV Score: 0.6028

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.15.1
# astropy                       5.2.1
# astunparse                    1.6.3
# attrs                         22.2.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# bokeh                         2.4.3
# branca                        0.6.0
# CacheControl                  0.12.11
# cached-property               1.5.2
# cachetools                    5.3.0
# catalogue                     2.0.8
# certifi                       2022.12.7
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.12
# chex                          0.1.7
# click                         8.1.3
# cloudpickle                   2.2.1
# cmake                         3.25.2
# cmdstanpy                     1.1.0
# colorcet                      3.0.1
# colorlover                    0.3.0
# community                     1.0.0b1
# confection                    0.0.4
# cons                          0.4.5
# contextlib2                   0.6.0.post1
# contourpy                     1.0.7
# convertdate                   2.4.0
# cryptography                  40.0.1
# cufflinks                     0.17.3
# cvxopt                        1.3.0
# cvxpy                         1.3.1
# cycler                        0.11.0
# cymem                         2.0.7
# Cython                        0.29.33
# dask                          2022.12.1
# datascience                   0.17.6
# db-dtypes                     1.0.5
# dbus-python                   1.2.16
# debugpy                       1.6.6
# decorator                     4.4.2
# defusedxml                    0.7.1
# distributed                   2022.12.1
# dlib                          19.24.1
# dm-tree                       0.1.8
# docutils                      0.16
# dopamine-rl                   4.0.6
# earthengine-api               0.1.346
# easydict                      1.10
# ecos                          2.0.12
# editdistance                  0.6.2
# en-core-web-sm                3.5.0
# entrypoints                   0.4
# ephem                         4.1.4
# et-xmlfile                    1.1.0
# etils                         1.1.1
# etuples                       0.3.8
# exceptiongroup                1.1.1
# fastai                        2.7.12
# fastcore                      1.5.29
# fastdownload                  0.0.7
# fastjsonschema                2.16.3
# fastprogress                  1.0.3
# fastrlock                     0.8.1
# filelock                      3.10.7
# firebase-admin                5.3.0
# Flask                         2.2.3
# flatbuffers                   23.3.3
# flax                          0.6.8
# folium                        0.14.0
# fonttools                     4.39.3
# frozendict                    2.3.6
# fsspec                        2023.3.0
# future                        0.18.3
# gast                          0.4.0
# GDAL                          3.3.2
# gdown                         4.6.6
# gensim                        4.3.1
# geographiclib                 2.0
# geopy                         2.3.0
# gin-config                    0.5.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               2.11.0
# google-api-python-client      2.70.0
# google-auth                   2.17.0
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-cloud-bigquery         3.4.2
# google-cloud-bigquery-storage 2.19.1
# google-cloud-core             2.3.2
# google-cloud-datastore        2.11.1
# google-cloud-firestore        2.7.3
# google-cloud-language         2.6.1
# google-cloud-storage          2.7.0
# google-cloud-translate        3.8.4
# google-colab                  1.0.0
# google-crc32c                 1.5.0
# google-pasta                  0.2.0
# google-resumable-media        2.4.1
# googleapis-common-protos      1.59.0
# googledrivedownloader         0.4
# graphviz                      0.20.1
# greenlet                      2.0.2
# grpcio                        1.53.0
# grpcio-status                 1.48.2
# gspread                       3.4.2
# gspread-dataframe             3.0.8
# gym                           0.25.2
# gym-notices                   0.0.8
# h5netcdf                      1.1.0
# h5py                          3.8.0
# HeapDict                      1.0.1
# hijri-converter               2.2.4
# holidays                      0.21.13
# holoviews                     1.15.4
# html5lib                      1.1
# htmlmin                       0.1.12
# httpimport                    1.3.0
# httplib2                      0.21.0
# humanize                      4.6.0
# hyperopt                      0.2.7
# idna                          3.4
# ImageHash                     4.3.1
# imageio                       2.25.1
# imageio-ffmpeg                0.4.8
# imagesize                     1.4.1
# imbalanced-learn              0.10.1
# imgaug                        0.4.0
# importlib-metadata            6.1.0
# importlib-resources           5.12.0
# imutils                       0.5.4
# inflect                       6.0.2
# iniconfig                     2.0.0
# intel-openmp                  2023.0.0
# ipykernel                     5.5.6
# ipython                       7.34.0
# ipython-genutils              0.2.0
# ipython-sql                   0.4.1
# ipywidgets                    7.7.1
# itsdangerous                  2.1.2
# jax                           0.4.7
# jaxlib                        0.4.7+cuda11.cudnn86
# jieba                         0.42.1
# Jinja2                        3.1.2
# joblib                        1.1.1
# jpholiday                     0.1.8
# jsonpickle                    3.0.1
# jsonschema                    4.3.3
# jupyter-client                6.1.12
# jupyter-console               6.1.0
# jupyter_core                  5.3.0
# jupyterlab-pygments           0.2.2
# jupyterlab-widgets            3.0.7
# kaggle                        1.5.13
# keras                         2.12.0
# keras-vis                     0.4.1
# kiwisolver                    1.4.4
# korean-lunar-calendar         0.3.1
# langcodes                     3.3.0
# lazy_loader                   0.2
# libclang                      16.0.0
# librosa                       0.10.0.post2
# lightgbm                      3.3.5
# llvmlite                      0.39.1
# locket                        1.0.0
# logical-unification           0.4.5
# LunarCalendar                 0.0.9
# lxml                          4.9.2
# Markdown                      3.4.3
# markdown-it-py                2.2.0
# MarkupSafe                    2.1.2
# matplotlib                    3.7.1
# matplotlib-inline             0.1.6
# matplotlib-venn               0.11.9
# mdurl                         0.1.2
# miniKanren                    1.0.3
# missingno                     0.5.2
# mistune                       0.8.4
# mizani                        0.8.1
# mkl                           2019.0
# ml-dtypes                     0.0.4
# mlxtend                       0.14.0
# more-itertools                9.1.0
# moviepy                       1.0.3
# mpmath                        1.3.0
# msgpack                       1.0.5
# multimethod                   1.9.1
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.9
# music21                       8.1.0
# natsort                       8.3.1
# nbclient                      0.7.2
# nbconvert                     6.5.4
# nbformat                      5.8.0
# nest-asyncio                  1.5.6
# networkx                      3.0
# nibabel                       3.0.2
# nltk                          3.8.1
# notebook                      6.3.0
# numba                         0.56.4
# numexpr                       2.8.4
# numpy                         1.22.4
# oauth2client                  4.1.3
# oauthlib                      3.2.2
# opencv-contrib-python         4.7.0.72
# opencv-python                 4.7.0.72
# opencv-python-headless        4.7.0.72
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# optax                         0.1.4
# orbax                         0.1.6
# osqp                          0.6.2.post0
# packaging                     23.0
# palettable                    3.3.0
# pandas                        1.4.4
# pandas-datareader             0.10.0
# pandas-gbq                    0.17.9
# pandas-profiling              3.2.0
# pandocfilters                 1.5.0
# panel                         0.14.4
# param                         1.13.0
# parso                         0.8.3
# partd                         1.3.0
# pathlib                       1.0.1
# pathy                         0.10.1
# patsy                         0.5.3
# pep517                        0.13.0
# pexpect                       4.8.0
# phik                          0.12.3
# pickleshare                   0.7.5
# Pillow                        8.4.0
# pip                           22.0.4
# pip-tools                     6.6.2
# platformdirs                  3.2.0
# plotly                        5.13.1
# plotnine                      0.10.1
# pluggy                        1.0.0
# pooch                         1.6.0
# portpicker                    1.3.9
# prefetch-generator            1.0.3
# preshed                       3.0.8
# prettytable                   0.7.2
# proglog                       0.1.10
# progressbar2                  4.2.0
# prometheus-client             0.16.0
# promise                       2.3
# prompt-toolkit                3.0.38
# prophet                       1.1.2
# proto-plus                    1.22.2
# protobuf                      3.20.3
# psutil                        5.9.4
# psycopg2                      2.9.5
# ptyprocess                    0.7.0
# py4j                          0.10.9.7
# pyarrow                       9.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.6
# pycparser                     2.21
# pyct                          0.5.0
# pydantic                      1.10.7
# pydata-google-auth            1.7.0
# pydot                         1.4.2
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyerfa                        2.0.0.3
# pygame                        2.3.0
# Pygments                      2.14.0
# PyGObject                     3.36.0
# pymc                          5.1.2
# PyMeeus                       0.5.12
# pymystem3                     0.2.0
# PyOpenGL                      3.1.6
# pyparsing                     3.0.9
# pyrsistent                    0.19.3
# PySocks                       1.7.1
# pytensor                      2.10.1
# pytest                        7.2.2
# python-apt                    0.0.0
# python-dateutil               2.8.2
# python-louvain                0.16
# python-slugify                8.0.1
# python-utils                  3.5.2
# pytz                          2022.7.1
# pytz-deprecation-shim         0.1.0.post0
# pyviz-comms                   2.2.1
# PyWavelets                    1.4.1
# PyYAML                        6.0
# pyzmq                         23.2.1
# qdldl                         0.1.5.post3
# qudida                        0.0.4
# regex                         2022.10.31
# requests                      2.27.1
# requests-oauthlib             1.3.1
# requests-unixsocket           0.2.0
# rich                          13.3.3
# rpy2                          3.5.5
# rsa                           4.9
# scikit-image                  0.19.3
# scikit-learn                  1.2.2
# scipy                         1.10.1
# screen-resolution-extra       0.0.0
# scs                           3.2.2
# seaborn                       0.12.2
# Send2Trash                    1.8.0
# setuptools                    67.6.1
# shapely                       2.0.1
# six                           1.16.0
# sklearn-pandas                2.2.0
# smart-open                    6.3.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soundfile                     0.12.1
# soupsieve                     2.4
# soxr                          0.3.4
# spacy                         3.5.1
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.4
# Sphinx                        3.5.4
# sphinxcontrib-applehelp       1.0.4
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.1
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# SQLAlchemy                    1.4.47
# sqlparse                      0.4.3
# srsly                         2.4.6
# statsmodels                   0.13.5
# sympy                         1.11.1
# tables                        3.7.0
# tabulate                      0.8.10
# tangled-up-in-unicode         0.2.0
# tblib                         1.7.0
# tenacity                      8.2.2
# tensorboard                   2.12.0
# tensorboard-data-server       0.7.0
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.12.0
# tensorflow-datasets           4.8.3
# tensorflow-estimator          2.12.0
# tensorflow-gcs-config         2.12.0
# tensorflow-hub                0.13.0
# tensorflow-io-gcs-filesystem  0.32.0
# tensorflow-metadata           1.12.0
# tensorflow-probability        0.19.0
# tensorstore                   0.1.35
# termcolor                     2.2.0
# terminado                     0.17.1
# text-unidecode                1.3
# textblob                      0.17.1
# tf-slim                       1.1.0
# thinc                         8.1.9
# threadpoolctl                 3.1.0
# tifffile                      2023.3.21
# tinycss2                      1.2.1
# toml                          0.10.2
# tomli                         2.0.1
# toolz                         0.12.0
# torch                         1.13.1+cu116
# torchaudio                    0.13.1+cu116
# torchsummary                  1.5.1
# torchtext                     0.14.1
# torchvision                   0.14.1+cu116
# tornado                       6.2
# tqdm                          4.65.0
# traitlets                     5.7.1
# tweepy                        4.13.0
# typer                         0.7.0
# typing_extensions             4.5.0
# tzdata                        2023.3
# tzlocal                       4.3
# uritemplate                   4.1.1
# urllib3                       1.26.15
# vega-datasets                 0.9.0
# visions                       0.7.4
# wasabi                        1.1.1
# wcwidth                       0.2.6
# webcolors                     1.13
# webencodings                  0.5.1
# Werkzeug                      2.2.3
# wheel                         0.40.0
# widgetsnbextension            3.6.4
# wordcloud                     1.8.2.2
# wrapt                         1.14.1
# xarray                        2022.12.0
# xarray-einstats               0.5.1
# xgboost                       1.7.4
# xkit                          0.0.0
# xlrd                          2.0.1
# yellowbrick                   1.5
# yfinance                      0.2.14
# zict                          2.2.0
# zipp                          3.15.0

# %%
main()
# Out:
# start date: 2021-04-08, end date:2022-07-31
#
# Loading Dataset...
# Done
#
# Moved to /content/drive/MyDrive/NEXCO/src/run_test/sample_submit_8/src
# Model papth = ../model
#
# {'section': LabelEncoder(), 'direction': LabelEncoder(), 'road_w_direction': LabelEncoder()}
# Loaded the model.
# 100%|██████████| 480/480 [23:54<00:00,  2.99s/it]
# ==================
# f1_score: 0.7908
# ==================

# %%
"""
start date: 2021-04-08, end date:2022-07-31

Loading Dataset...
Done
100%|██████████| 480/480 [02:20<00:00,  3.42it/s]
train all shape: (908184, 35)
train columns: 
 Index(['road_code', 'start_code', 'end_code', 'section', 'direction',
       'dayofweek', 'is_holiday', 'is_holiday_td', 'start_pref_code',
       'end_pref_code', 'season', 'year', 'month', 'day', 'year_td',
       'month_td', 'day_td', 'hour', 'search_1h', 'search_unspec_1d', 'KP',
       'start_KP', 'end_KP', 'limit_speed', 'straight_dist', 'KP_se_dist',
       'KP_te_dist', 'KP_st_dist', 'KP_max_dist', 'detour_rate',
       'start_degree', 'end_degree', 'degree_diss_es', 'OCC', 'allCars'],
      dtype='object')
train shape = (726168, 35)
valid shape = (182016, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0433048	Train's f1: 0.52973	Valid's binary_logloss: 0.0209946	Valid's f1: 0.522523
[200]	Train's binary_logloss: 0.0326132	Train's f1: 0.638095	Valid's binary_logloss: 0.0170196	Valid's f1: 0.584356
[300]	Train's binary_logloss: 0.0276619	Train's f1: 0.655167	Valid's binary_logloss: 0.0156014	Valid's f1: 0.584703
Early stopping, best iteration is:
[227]	Train's binary_logloss: 0.0309826	Train's f1: 0.646968	Valid's binary_logloss: 0.0165003	Valid's f1: 0.590604
 - fold1 - 0.5906 
 
train shape = (726168, 35)
valid shape = (182016, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0426736	Train's f1: 0.537978	Valid's binary_logloss: 0.0229667	Valid's f1: 0.5522
[200]	Train's binary_logloss: 0.0321598	Train's f1: 0.635226	Valid's binary_logloss: 0.0196726	Valid's f1: 0.554688
Early stopping, best iteration is:
[140]	Train's binary_logloss: 0.0373128	Train's f1: 0.616125	Valid's binary_logloss: 0.0212205	Valid's f1: 0.59816
 - fold2 - 0.5982 

train shape = (726168, 35)
valid shape = (182016, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0428572	Train's f1: 0.541676	Valid's binary_logloss: 0.02164	Valid's f1: 0.506641
[200]	Train's binary_logloss: 0.0321758	Train's f1: 0.648584	Valid's binary_logloss: 0.0174012	Valid's f1: 0.54786
[300]	Train's binary_logloss: 0.0270436	Train's f1: 0.660412	Valid's binary_logloss: 0.0156895	Valid's f1: 0.547322
Early stopping, best iteration is:
[218]	Train's binary_logloss: 0.030979	Train's f1: 0.647127	Valid's binary_logloss: 0.0169808	Valid's f1: 0.554455
 - fold3 - 0.5545 

train shape = (726168, 35)
valid shape = (182016, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0426093	Train's f1: 0.549933	Valid's binary_logloss: 0.0225878	Valid's f1: 0.446251
[200]	Train's binary_logloss: 0.032021	Train's f1: 0.644713	Valid's binary_logloss: 0.0190057	Valid's f1: 0.496251
Early stopping, best iteration is:
[162]	Train's binary_logloss: 0.0349298	Train's f1: 0.637367	Valid's binary_logloss: 0.0199217	Valid's f1: 0.503852
 - fold4 - 0.5039 

train shape = (728064, 35)
valid shape = (180120, 35)
Using sample weight.
{0: 1.0, 1: 5.0}
Training until validation scores don't improve for 100 rounds.
[100]	Train's binary_logloss: 0.0438301	Train's f1: 0.529202	Valid's binary_logloss: 0.0209725	Valid's f1: 0.506718
[200]	Train's binary_logloss: 0.0330797	Train's f1: 0.638687	Valid's binary_logloss: 0.0167894	Valid's f1: 0.584235
[300]	Train's binary_logloss: 0.0282798	Train's f1: 0.651866	Valid's binary_logloss: 0.0151186	Valid's f1: 0.574483
Early stopping, best iteration is:
[218]	Train's binary_logloss: 0.0319759	Train's f1: 0.639012	Valid's binary_logloss: 0.016379	Valid's f1: 0.586989
 - fold5 - 0.5870 

==================================================
FINISH: CV Score: 0.5670
"""
# Out:
# "\nstart date: 2021-04-08, end date:2022-07-31\n\nLoading Dataset...\nDone\n100%|██████████| 480/480 [02:20<00:00,  3.42it/s]\ntrain all shape: (908184, 35)\ntrain columns: \n Index(['road_code', 'start_code', 'end_code', 'section', 'direction',\n       'dayofweek', 'is_holiday', 'is_holiday_td', 'start_pref_code',\n       'end_pref_code', 'season', 'year', 'month', 'day', 'year_td',\n       'month_td', 'day_td', 'hour', 'search_1h', 'search_unspec_1d', 'KP',\n       'start_KP', 'end_KP', 'limit_speed', 'straight_dist', 'KP_se_dist',\n       'KP_te_dist', 'KP_st_dist', 'KP_max_dist', 'detour_rate',\n       'start_degree', 'end_degree', 'degree_diss_es', 'OCC', 'allCars'],\n      dtype='object')\ntrain shape = (726168, 35)\nvalid shape = (182016, 35)\nUsing sample weight.\n{0: 1.0, 1: 5.0}\nTraining until validation scores don't improve for 100 rounds.\n[100]\tTrain's binary_logloss: 0.0433048\tTrain's f1: 0.52973\tValid's binary_logloss: 0.0209946\tValid's f1: 0.522523\n[200]\tTrain's binary_logloss: 0.0326132\tTrain's f1: 0.638095\tValid's binary_logloss: 0.0170196\tValid's f1: 0.584356\n[300]\tTrain's binary_logloss: 0.0276619\tTrain's f1: 0.655167\tValid's binary_logloss: 0.0156014\tValid's f1: 0.584703\nEarly stopping, best iteration is:\n[227]\tTrain's binary_logloss: 0.0309826\tTrain's f1: 0.646968\tValid's binary_logloss: 0.0165003\tValid's f1: 0.590604\n - fold1 - 0.5906 \n \ntrain shape = (726168, 35)\nvalid shape = (182016, 35)\nUsing sample weight.\n{0: 1.0, 1: 5.0}\nTraining until validation scores don't improve for 100 rounds.\n[100]\tTrain's binary_logloss: 0.0426736\tTrain's f1: 0.537978\tValid's binary_logloss: 0.0229667\tValid's f1: 0.5522\n[200]\tTrain's binary_logloss: 0.0321598\tTrain's f1: 0.635226\tValid's binary_logloss: 0.0196726\tValid's f1: 0.554688\nEarly stopping, best iteration is:\n[140]\tTrain's binary_logloss: 0.0373128\tTrain's f1: 0.616125\tValid's binary_logloss: 0.0212205\tValid's f1: 0.59816\n - fold2 - 0.5982 \n\ntrain shape = (726168, 35)\nvalid shape = (182016, 35)\nUsing sample weight.\n{0: 1.0, 1: 5.0}\nTraining until validation scores don't improve for 100 rounds.\n[100]\tTrain's binary_logloss: 0.0428572\tTrain's f1: 0.541676\tValid's binary_logloss: 0.02164\tValid's f1: 0.506641\n[200]\tTrain's binary_logloss: 0.0321758\tTrain's f1: 0.648584\tValid's binary_logloss: 0.0174012\tValid's f1: 0.54786\n[300]\tTrain's binary_logloss: 0.0270436\tTrain's f1: 0.660412\tValid's binary_logloss: 0.0156895\tValid's f1: 0.547322\nEarly stopping, best iteration is:\n[218]\tTrain's binary_logloss: 0.030979\tTrain's f1: 0.647127\tValid's binary_logloss: 0.0169808\tValid's f1: 0.554455\n - fold3 - 0.5545 \n\ntrain shape = (726168, 35)\nvalid shape = (182016, 35)\nUsing sample weight.\n{0: 1.0, 1: 5.0}\nTraining until validation scores don't improve for 100 rounds.\n[100]\tTrain's binary_logloss: 0.0426093\tTrain's f1: 0.549933\tValid's binary_logloss: 0.0225878\tValid's f1: 0.446251\n[200]\tTrain's binary_logloss: 0.032021\tTrain's f1: 0.644713\tValid's binary_logloss: 0.0190057\tValid's f1: 0.496251\nEarly stopping, best iteration is:\n[162]\tTrain's binary_logloss: 0.0349298\tTrain's f1: 0.637367\tValid's binary_logloss: 0.0199217\tValid's f1: 0.503852\n - fold4 - 0.5039 \n\ntrain shape = (728064, 35)\nvalid shape = (180120, 35)\nUsing sample weight.\n{0: 1.0, 1: 5.0}\nTraining until validation scores don't improve for 100 rounds.\n[100]\tTrain's binary_logloss: 0.0438301\tTrain's f1: 0.529202\tValid's binary_logloss: 0.0209725\tValid's f1: 0.506718\n[200]\tTrain's binary_logloss: 0.0330797\tTrain's f1: 0.638687\tValid's binary_logloss: 0.0167894\tValid's f1: 0.584235\n[300]\tTrain's binary_logloss: 0.0282798\tTrain's f1: 0.651866\tValid's binary_logloss: 0.0151186\tValid's f1: 0.574483\nEarly stopping, best iteration is:\n[218]\tTrain's binary_logloss: 0.0319759\tTrain's f1: 0.639012\tValid's binary_logloss: 0.016379\tValid's f1: 0.586989\n - fold5 - 0.5870 \n\n==================================== ...

# %%
data_dir = '/content/drive/MyDrive/NEXCO/src/run_test/train/'
road_df = pd.read_csv(os.path.join(data_dir, 'road.csv'))
road_df['section'] = road_df['start_code'].astype(str) + '_' +  road_df['end_code'].astype(str)

# %%
road_df
# Out:
#         start_name        end_name  start_code  end_code  start_pref_code  \
# 0            大泉ＪＣＴ              所沢     1110210   1800006               13
# 1   京葉道路・館山自動車道接続部              市原     1130001   1130006               12
# 2               市原  京葉道路・館山自動車道接続部     1130006   1130001               12
# 3               市原           姉崎袖ヶ浦     1130006   1130016               12
# 4            姉崎袖ヶ浦              市原     1130016   1130006               12
# 5            姉崎袖ヶ浦            木更津北     1130016   1130021               12
# 6             木更津北           姉崎袖ヶ浦     1130021   1130016               12
# 7             木更津北          木更津ＪＣＴ     1130021   1130026               12
# 8           木更津ＪＣＴ            木更津北     1130026   1130021               12
# 9           木更津ＪＣＴ         木更津南ＪＣＴ     1130026   1130031               12
# 10         木更津南ＪＣＴ          木更津ＪＣＴ     1130031   1130026               12
# 11         木更津南ＪＣＴ              君津     1130031   1130036               12
# 12              君津         木更津南ＪＣＴ     1130036   1130031               12
# 13            君津ＰＡ            富津中央     1130039   1130041               12
# 14            富津中央            君津ＰＡ     1130041   1130039               12
# 15            富津中央            富津竹岡     1130041   1130046               12
# 16            富津竹岡            富津中央     1130046   1130041               12
# 17              所沢           大泉ＪＣＴ     1800006   1110210               11
# 18              所沢            三芳ＰＡ     1800006   1800011               11
# 19            三芳ＰＡ              所沢     1800011   1800006               11
# 20            三芳ＰＡ              川越     1800011   1800016               11
# 21              川越            三芳ＰＡ     1800016   1800011               11
# 22              川越          鶴ヶ島ＪＣＴ     1800016   1800021               11
# 23          鶴ヶ島ＪＣＴ              川越     1800021   1800016               11
# 24          鶴ヶ島ＪＣＴ             鶴ヶ島     1800021   1800026               11
# 25             鶴ヶ島          鶴ヶ島ＪＣＴ     1800026   1800021               11
# 26             鶴ヶ島         坂戸西スマート     1800026   1800028               11
# 27         坂戸西スマート             鶴ヶ島     1800028   1800026               11
# 28         坂戸西スマート             東松山     1800028   1800036               11
# 29             東松山         坂戸西スマート     1800036   1800028               11
# 30             東松山            嵐山小川     1800036   1800041               11
# 31            嵐山小川             東松山     1800041   1800036               11
# 32            嵐山小川              花園     1800041   1800051               11
# 33              花園            嵐山小川     1800051   1800041               11
# 34              花園            寄居ＰＡ     1800051   1800056               11
# 35            寄居ＰＡ              花園     1800056   1800051               11
# 36            寄居ＰＡ            本庄児玉     1800056   1800061               11
# 37            本庄児玉            寄居ＰＡ     1800061   1800056               11
# 38            本庄児玉            上里ＳＡ     1800061   1800066               11
# 39            上里ＳＡ            本庄児玉     1800066   1800061               11
# 40            上里ＳＡ           藤岡ＪＣＴ     1800066   1800071               11
# 41           藤岡ＪＣＴ            上里ＳＡ     1800071   1800066               10
# 42           藤岡ＪＣＴ        高崎玉村スマート     1800071   1800072               10
# 43        高崎玉村スマート           藤岡ＪＣＴ     1800072   1800071               10
# 44           高崎ＪＣＴ        高崎玉村スマート     1800073   1800072               10
# 45           高崎ＪＣＴ              高崎     1800073   1800076               10
# 46              高崎           高崎ＪＣＴ     1800076   1800073               10
# 47              高崎              前橋     1800076   1800081               10
# 48              前橋              高崎     1800081   1800076               10
# 49              前橋            駒寄ＰＡ     1800081   1800086               10
# 50            駒寄ＰＡ              前橋     1800086   1800081               10
# 51            駒寄ＰＡ           渋川伊香保     1800086   1800091               10
# 52           渋川伊香保            駒寄ＰＡ     1800091   1800086               10
# 53           渋川伊香保              赤城     1800091   1800096               10
# 54              赤城           渋川伊香保     1800096   1800091               10
# 55              赤城              昭和     1800096   1800106               10
# 56              昭和              赤城     1800106   1800096               10
# 57              昭和         沼田(関越道)     1800106   1800111               10
# 58         沼田(関越道)              昭和     1800111   1800106               10
# 59         沼田(関越道)             月夜野     1800111   1800116               10
# 60             月夜野         沼田(関越道)     1800116   1800111               10
# 61             月夜野              水上     1800116   1800121               10
# 62              水上             月夜野     1800121   1800116               10
# 63              水上         湯沢(関越道)     1800121   1800131               10
# 64         湯沢(関越道)              水上     1800131   1800121               15
# 65         湯沢(関越道)            塩沢石打     1800131   1800141               15
# 66            塩沢石打         湯沢(関越道)     1800141   1800131               15
# 65         2.0  174.512        下り   167.117  175.612           80       1800
# 66         2.0  174.514        上り   175.612  167.117           80       1800
# 67         2.0  179.148        下り   175.612  187.504           80       1800
# 68         2.0  179.148        上り   187.504  175.612           80       1800
# 69         2.0  203.381        下り   198.420  204.479           80       1800
# 70         2.0  203.385        上り   204.479  198.420           80       1800
# 71         2.0  205.426        下り   204.479  212.030           80       1800
# 72         2.0  205.426        上り   212.030  204.479           80       1800
# 73         2.0  218.538        下り   212.030  221.000           80       1800
# 74         2.0  218.545        上り   221.000  212.030           80       1800
# 75         2.0  222.250        下り   221.000  228.923           80       1800
# 76         2.0  222.240        上り   228.923  221.000           80       1800
# 77         2.0  237.700        下り   228.923  238.600           80       1800
# 78         2.0  237.700        上り   238.600  228.923           80       1800
#
#             section
# 0   1110210_1800006
# 1   1130001_1130006
# 2   1130006_1130001
# 3   1130006_1130016
# 4   1130016_1130006
# 5   1130016_1130021
# 6   1130021_1130016
# 7   1130021_1130026
# 8   1130026_1130021
# 9   1130026_1130031
# 10  1130031_1130026
# 11  1130031_1130036
# 12  1130036_1130031
# 13  1130039_1130041
# 14  1130041_1130039
# 15  1130041_1130046
# 16  1130046_1130041
# 17  1800006_1110210
# 18  1800006_1800011
# 19  1800011_1800006
# 20  1800011_1800016
# 21  1800016_1800011
# 22  1800016_1800021
# 23  1800021_1800016
# 24  1800021_1800026
# 25  1800026_1800021
# 26  1800026_1800028
# 27  1800028_1800026
# 28  1800028_1800036
# 29  1800036_1800028
# 30  1800036_1800041
# 31  1800041_1800036
# 32  1800041_1800051
# 33  1800051_1800041
# 34  1800051_1800056
# 35  1800056_1800051
# 36  1800056_1800061
# 37  1800061_1800056
# 38  1800061_1800066
# 39  1800066_1800061
# 40  1800066_1800071
# 41  1800071_1800066
# 42  1800071_1800072
# 43  1800072_1800071
# 44  1800073_1800072
# 45  1800073_1800076
# 46  1800076_1800073
# 47  1800076_1800081
# 48  1800081_1800076
# 49  1800081_1800086
# 50  1800086_1800081
# 51  1800086_1800091
# 52  1800091_1800086
# 53  1800091_1800096
# 54  1800096_1800091
# 55  1800096_1800106
# 56  1800106_1800096
# 57  1800106_1800111
# 58  1800111_1800106
# 59  1800111_1800116
# 60  1800116_1800111
# 61  1800116_1800121
# 62  1800121_1800116
# 63  1800121_1800131
# 64  1800131_1800121
# 65  1800131_1800141
# 66  1800141_1800131
# 67  1800141_1800146
# 68  1800146_1800141
# 69  1800151_1800156
# 70  1800156_1800151
# 71  1800156_1800161
# 72  1800161_1800156
# 73  1800161_1800171
# 74  1800171_1800161
# 75  1800171_1800176
# 76  1800176_1800171
# 77  1800176_1800183
# 78  1800183_1800176

# %%
# 道路コード(関越道:1800, 館山道:1130)
kanetsu_road = road_df[road_df['road_code']==1800].sort_values('KP')
tateyama_road = road_df[road_df['road_code']==1130].sort_values('KP')

# %%
kanetsu_road
# Out:
#    start_name   end_name  start_code  end_code  start_pref_code  \
# 0       大泉ＪＣＴ         所沢     1110210   1800006               13
# 17         所沢      大泉ＪＣＴ     1800006   1110210               11
# 19       三芳ＰＡ         所沢     1800011   1800006               11
# 18         所沢       三芳ＰＡ     1800006   1800011               11
# 20       三芳ＰＡ         川越     1800011   1800016               11
# 21         川越       三芳ＰＡ     1800016   1800011               11
# 22         川越     鶴ヶ島ＪＣＴ     1800016   1800021               11
# 23     鶴ヶ島ＪＣＴ         川越     1800021   1800016               11
# 25        鶴ヶ島     鶴ヶ島ＪＣＴ     1800026   1800021               11
# 24     鶴ヶ島ＪＣＴ        鶴ヶ島     1800021   1800026               11
# 26        鶴ヶ島    坂戸西スマート     1800026   1800028               11
# 27    坂戸西スマート        鶴ヶ島     1800028   1800026               11
# 28    坂戸西スマート        東松山     1800028   1800036               11
# 29        東松山    坂戸西スマート     1800036   1800028               11
# 30        東松山       嵐山小川     1800036   1800041               11
# 31       嵐山小川        東松山     1800041   1800036               11
# 33         花園       嵐山小川     1800051   1800041               11
# 32       嵐山小川         花園     1800041   1800051               11
# 34         花園       寄居ＰＡ     1800051   1800056               11
# 35       寄居ＰＡ         花園     1800056   1800051               11
# 37       本庄児玉       寄居ＰＡ     1800061   1800056               11
# 36       寄居ＰＡ       本庄児玉     1800056   1800061               11
# 38       本庄児玉       上里ＳＡ     1800061   1800066               11
# 39       上里ＳＡ       本庄児玉     1800066   1800061               11
# 40       上里ＳＡ      藤岡ＪＣＴ     1800066   1800071               11
# 41      藤岡ＪＣＴ       上里ＳＡ     1800071   1800066               10
# 43   高崎玉村スマート      藤岡ＪＣＴ     1800072   1800071               10
# 42      藤岡ＪＣＴ   高崎玉村スマート     1800071   1800072               10
# 44      高崎ＪＣＴ   高崎玉村スマート     1800073   1800072               10
# 45      高崎ＪＣＴ         高崎     1800073   1800076               10
# 46         高崎      高崎ＪＣＴ     1800076   1800073               10
# 48         前橋         高崎     1800081   1800076               10
# 47         高崎         前橋     1800076   1800081               10
# 49         前橋       駒寄ＰＡ     1800081   1800086               10
# 50       駒寄ＰＡ         前橋     1800086   1800081               10
# 51       駒寄ＰＡ      渋川伊香保     1800086   1800091               10
# 52      渋川伊香保       駒寄ＰＡ     1800091   1800086               10
# 53      渋川伊香保         赤城     1800091   1800096               10
# 54         赤城      渋川伊香保     1800096   1800091               10
# 56         昭和         赤城     1800106   1800096               10
# 55         赤城         昭和     1800096   1800106               10
# 57         昭和    沼田(関越道)     1800106   1800111               10
# 58    沼田(関越道)         昭和     1800111   1800106               10
# 59    沼田(関越道)        月夜野     1800111   1800116               10
# 60        月夜野    沼田(関越道)     1800116   1800111               10
# 61        月夜野         水上     1800116   1800121               10
# 62         水上        月夜野     1800121   1800116               10
# 63         水上    湯沢(関越道)     1800121   1800131               10
# 64    湯沢(関越道)         水上     1800131   1800121               15
# 65    湯沢(関越道)       塩沢石打     1800131   1800141               15
# 66       塩沢石打    湯沢(関越道)     1800141   1800131               15
# 67       塩沢石打        六日町     1800141   1800146               15
# 68        六日町       塩沢石打     1800146   1800141               15
# 10         4.0  64.420        上り      66.4    62.5          100       1130
# 11         2.0  69.710        下り      66.4    70.4          100       1130
# 12         3.0  69.710        上り      70.4    66.4          100       1130
# 13         2.0  75.490        下り      74.8    79.7          100       1130
# 14         2.0  75.548        上り      79.7    74.8          100       1130
# 16         2.0  83.025        上り      87.2    79.7          100       1130
# 15         2.0  83.070        下り      79.7    87.2          100       1130
#
#             section
# 1   1130001_1130006
# 2   1130006_1130001
# 3   1130006_1130016
# 4   1130016_1130006
# 5   1130016_1130021
# 6   1130021_1130016
# 7   1130021_1130026
# 8   1130026_1130021
# 9   1130026_1130031
# 10  1130031_1130026
# 11  1130031_1130036
# 12  1130036_1130031
# 13  1130039_1130041
# 14  1130041_1130039
# 16  1130046_1130041
# 15  1130041_1130046

# %%
# 関越道上り
kanetsu_nobori = kanetsu_road[kanetsu_road['direction']=='上り'].reset_index()
# 関越道上り
kanetsu_kudari = kanetsu_road[kanetsu_road['direction']=='下り'].reset_index()

# 館山道上り
tateyama_nobori = tateyama_road[tateyama_road['direction']=='上り'].reset_index()
# 関越道上り
tateyama_kudari = tateyama_road[tateyama_road['direction']=='下り'].reset_index()

# %%
# 関越道上り
kanetsu_nobori
# Out:
#     index start_name  end_name  start_code  end_code  start_pref_code  \
# 0      17         所沢     大泉ＪＣＴ     1800006   1110210               11
# 1      19       三芳ＰＡ        所沢     1800011   1800006               11
# 2      21         川越      三芳ＰＡ     1800016   1800011               11
# 3      23     鶴ヶ島ＪＣＴ        川越     1800021   1800016               11
# 4      25        鶴ヶ島    鶴ヶ島ＪＣＴ     1800026   1800021               11
# 5      27    坂戸西スマート       鶴ヶ島     1800028   1800026               11
# 6      29        東松山   坂戸西スマート     1800036   1800028               11
# 7      31       嵐山小川       東松山     1800041   1800036               11
# 8      33         花園      嵐山小川     1800051   1800041               11
# 9      35       寄居ＰＡ        花園     1800056   1800051               11
# 10     37       本庄児玉      寄居ＰＡ     1800061   1800056               11
# 11     39       上里ＳＡ      本庄児玉     1800066   1800061               11
# 12     41      藤岡ＪＣＴ      上里ＳＡ     1800071   1800066               10
# 13     43   高崎玉村スマート     藤岡ＪＣＴ     1800072   1800071               10
# 14     44      高崎ＪＣＴ  高崎玉村スマート     1800073   1800072               10
# 15     46         高崎     高崎ＪＣＴ     1800076   1800073               10
# 16     48         前橋        高崎     1800081   1800076               10
# 17     50       駒寄ＰＡ        前橋     1800086   1800081               10
# 18     52      渋川伊香保      駒寄ＰＡ     1800091   1800086               10
# 19     54         赤城     渋川伊香保     1800096   1800091               10
# 20     56         昭和        赤城     1800106   1800096               10
# 21     58    沼田(関越道)        昭和     1800111   1800106               10
# 22     60        月夜野   沼田(関越道)     1800116   1800111               10
# 23     62         水上       月夜野     1800121   1800116               10
# 24     64    湯沢(関越道)        水上     1800131   1800121               15
# 25     66       塩沢石打   湯沢(関越道)     1800141   1800131               15
# 26     68        六日町      塩沢石打     1800146   1800141               15
# 27     70         小出      大和ＰＡ     1800156   1800151               15
# 13         3.0   81.000        上り    82.800   78.700          100       1800
# 14         2.0   83.044        上り    84.800   82.800          100       1800
# 15         3.0   86.400        上り    87.100   84.800          100       1800
# 16         2.0   88.200        上り    92.200   87.100          100       1800
# 17         2.0   96.700        上り    98.600   92.200           80       1800
# 18         2.0  100.850        上り   103.600   98.600           80       1800
# 19         2.0  108.000        上り   111.300  103.600           80       1800
# 20         2.0  112.610        上り   120.700  111.300           80       1800
# 21         2.0  123.850        上り   125.900  120.700           80       1800
# 22         2.0  128.730        上り   131.200  125.900           80       1800
# 23         2.0  132.390        上り   141.163  131.200           80       1800
# 24         2.0  141.975        上り   167.117  141.163           80       1800
# 25         2.0  174.514        上り   175.612  167.117           80       1800
# 26         2.0  179.148        上り   187.504  175.612           80       1800
# 27         2.0  203.385        上り   204.479  198.420           80       1800
# 28         2.0  205.426        上り   212.030  204.479           80       1800
# 29         2.0  218.545        上り   221.000  212.030           80       1800
# 30         2.0  222.240        上り   228.923  221.000           80       1800
# 31         2.0  237.700        上り   238.600  228.923           80       1800
#
#             section
# 0   1800006_1110210
# 1   1800011_1800006
# 2   1800016_1800011
# 3   1800021_1800016
# 4   1800026_1800021
# 5   1800028_1800026
# 6   1800036_1800028
# 7   1800041_1800036
# 8   1800051_1800041
# 9   1800056_1800051
# 10  1800061_1800056
# 11  1800066_1800061
# 12  1800071_1800066
# 13  1800072_1800071
# 14  1800073_1800072
# 15  1800076_1800073
# 16  1800081_1800076
# 17  1800086_1800081
# 18  1800091_1800086
# 19  1800096_1800091
# 20  1800106_1800096
# 21  1800111_1800106
# 22  1800116_1800111
# 23  1800121_1800116
# 24  1800131_1800121
# 25  1800141_1800131
# 26  1800146_1800141
# 27  1800156_1800151
# 28  1800161_1800156
# 29  1800171_1800161
# 30  1800176_1800171
# 31  1800183_1800176

# %%
# 関越道上り
kanetsu_kudari
# Out:
#     index start_name   end_name  start_code  end_code  start_pref_code  \
# 0       0      大泉ＪＣＴ         所沢     1110210   1800006               13
# 1      18         所沢       三芳ＰＡ     1800006   1800011               11
# 2      20       三芳ＰＡ         川越     1800011   1800016               11
# 3      22         川越     鶴ヶ島ＪＣＴ     1800016   1800021               11
# 4      24     鶴ヶ島ＪＣＴ        鶴ヶ島     1800021   1800026               11
# 5      26        鶴ヶ島    坂戸西スマート     1800026   1800028               11
# 6      28    坂戸西スマート        東松山     1800028   1800036               11
# 7      30        東松山       嵐山小川     1800036   1800041               11
# 8      32       嵐山小川         花園     1800041   1800051               11
# 9      34         花園       寄居ＰＡ     1800051   1800056               11
# 10     36       寄居ＰＡ       本庄児玉     1800056   1800061               11
# 11     38       本庄児玉       上里ＳＡ     1800061   1800066               11
# 12     40       上里ＳＡ      藤岡ＪＣＴ     1800066   1800071               11
# 13     42      藤岡ＪＣＴ   高崎玉村スマート     1800071   1800072               10
# 14     45      高崎ＪＣＴ         高崎     1800073   1800076               10
# 15     47         高崎         前橋     1800076   1800081               10
# 16     49         前橋       駒寄ＰＡ     1800081   1800086               10
# 5          2.0   31.500        下り    29.600   32.500          100       1800
# 6          2.0   33.290        下り    32.500   39.500          100       1800
# 7          2.0   41.540        下り    39.500   47.500          100       1800
# 8          2.0   51.090        下り    47.500   56.200          100       1800
# 9          2.0   59.110        下り    56.200   63.700          100       1800
# 10         2.0   66.850        下り    63.700   69.700          100       1800
# 11         2.0   70.030        下り    69.700   75.500          100       1800
# 12         3.0   76.000        下り    75.500   78.700          100       1800
# 13         2.0   82.400        下り    78.700   82.800          100       1800
# 14         2.0   86.400        下り    84.800   87.100          100       1800
# 15         2.0   88.200        下り    87.100   92.200          100       1800
# 16         2.0   96.600        下り    92.200   98.600          100       1800
# 17         2.0  100.830        下り    98.600  103.600          100       1800
# 18         2.0  104.340        下り   103.600  111.300           80       1800
# 19         2.0  113.580        下り   111.300  120.700           80       1800
# 20         2.0  123.850        下り   120.700  125.900           80       1800
# 21         2.0  128.120        下り   125.900  131.200           80       1800
# 22         2.0  132.370        下り   131.200  141.163           80       1800
# 23         2.0  141.965        下り   141.163  167.117           80       1800
# 24         2.0  174.512        下り   167.117  175.612           80       1800
# 25         2.0  179.148        下り   175.612  187.504           80       1800
# 26         2.0  203.381        下り   198.420  204.479           80       1800
# 27         2.0  205.426        下り   204.479  212.030           80       1800
# 28         2.0  218.538        下り   212.030  221.000           80       1800
# 29         2.0  222.250        下り   221.000  228.923           80       1800
# 30         2.0  237.700        下り   228.923  238.600           80       1800
#
#             section
# 0   1110210_1800006
# 1   1800006_1800011
# 2   1800011_1800016
# 3   1800016_1800021
# 4   1800021_1800026
# 5   1800026_1800028
# 6   1800028_1800036
# 7   1800036_1800041
# 8   1800041_1800051
# 9   1800051_1800056
# 10  1800056_1800061
# 11  1800061_1800066
# 12  1800066_1800071
# 13  1800071_1800072
# 14  1800073_1800076
# 15  1800076_1800081
# 16  1800081_1800086
# 17  1800086_1800091
# 18  1800091_1800096
# 19  1800096_1800106
# 20  1800106_1800111
# 21  1800111_1800116
# 22  1800116_1800121
# 23  1800121_1800131
# 24  1800131_1800141
# 25  1800141_1800146
# 26  1800151_1800156
# 27  1800156_1800161
# 28  1800161_1800171
# 29  1800171_1800176
# 30  1800176_1800183

# %%
# 館山道上り
tateyama_nobori
# Out:
#    index start_name        end_name  start_code  end_code  start_pref_code  \
# 0      2         市原  京葉道路・館山自動車道接続部     1130006   1130001               12
# 1      4      姉崎袖ヶ浦              市原     1130016   1130006               12
# 2      6       木更津北           姉崎袖ヶ浦     1130021   1130016               12
# 3      8     木更津ＪＣＴ            木更津北     1130026   1130021               12
# 4     10    木更津南ＪＣＴ          木更津ＪＣＴ     1130031   1130026               12
# 5     12         君津         木更津南ＪＣＴ     1130036   1130031               12
# 6     14       富津中央            君津ＰＡ     1130041   1130039               12
# 7     16       富津竹岡            富津中央     1130046   1130041               12
#
#    end_pref_code  start_lat   end_lat   start_lng     end_lng  start_degree  \
# 0             12   35.49471  35.55136  140.094986  140.143014           2.0
